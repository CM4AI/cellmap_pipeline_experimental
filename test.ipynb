# %%
pip install ndex2
# Out:
# Requirement already satisfied: ndex2 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: six in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (1.17.0)
# Requirement already satisfied: ijson in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (3.4.0)
# Requirement already satisfied: requests in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (2.32.4)
# Requirement already satisfied: requests-toolbelt in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (1.0.0)
# Requirement already satisfied: networkx in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (2.8.8)
# Requirement already satisfied: urllib3>=1.16 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (2.5.0)
# Requirement already satisfied: pandas in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (2.3.1)
# Requirement already satisfied: numpy in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from ndex2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from pandas->ndex2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from pandas->ndex2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from pandas->ndex2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from requests->ndex2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from requests->ndex2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sl3223/miniconda3/envs/cellmaps_dev/lib/python3.10/site-packages (from requests->ndex2) (2025.7.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ndex2
from ndex2.nice_cx_network import NiceCXNetwork
import json
import pandas as pd
from collections import defaultdict
import os

# %%
UUID = "95bc75d5-d1d1-11ee-8a40-005056ae23aa"
server = "http://public.ndexbio.org"

nice_cx = ndex2.create_nice_cx_from_server(server, uuid=UUID)

#To download .cx as a local file
#client = ndex2.client.Ndex2()
#cx_stream = client.get_network_as_cx_stream(UUID)
#with open('network.cx', 'wb') as f:
#    for chunk in cx_stream:
#        f.write(chunk)

# %%
#To download .cx as a local file
client = ndex2.client.Ndex2()
cx_stream = client.get_network_as_cx_stream(UUID)
with open('network.cx', 'wb') as f:
    for chunk in cx_stream:
        f.write(chunk)

# %%
#Extract edge list

edges = []
for edge_id, edge_data in nice_cx.get_edges():
    source = nice_cx.get_node(edge_data['s'])['n']
    target = nice_cx.get_node(edge_data['t'])['n']
    edges.append({'geneA': source, 'geneB': target})

edge_list= pd.DataFrame(edges)
edge_list.head()
print (f"Identified {edge_list.shape[0]} edges from the network")
# Out:
# Identified 36842 edges from the network

# %%
# Node Attributes
nodes = nice_cx.nodes
node_attrs = nice_cx.nodeAttributes

attr_by_node_id = defaultdict(dict)

for node_id, attr_list in node_attrs.items():
    for attr in attr_list:
        attr_name = attr['n']
        attr_value = attr['v']
        attr_by_node_id[node_id][attr_name] = attr_value

nodes_combined = []
for node_id, node_data in nodes.items():
    node_id = node_id
    name = node_data.get('n')
    represents = node_data.get('r', None)
    bait_str = attr_by_node_id[node_id].get('bait', None)
    antibody = attr_by_node_id[node_id].get('antibody', None)
    
    if bait_str == 'true':
        bait = True
    elif bait_str == 'false':
        bait = False
    else:
        bait = None
    
    nodes_combined.append({
        'node_id': node_id,
        'name': name,
        'represents': represents,
        'bait': bait,
        'antibody': antibody
    })

node_attrs_list = pd.DataFrame(nodes_combined)
print(f"Node attributes of {node_attrs_list.shape[0]} genes identified")
# Out:
# Node attributes of 7543 genes identified

# %%
# Original code:

import re
import csv
import logging
import mygene
from tqdm import tqdm

from cellmaps_ppidownloader.exceptions import CellMapsPPIDownloaderError

logger = logging.getLogger(__name__)


class GeneQuery(object):
    """
    Gets information about genes from mygene
    """

    def __init__(self, mygeneinfo=mygene.MyGeneInfo()):
        """
        Constructor
        """
        self._mg = mygeneinfo

    def querymany(self, queries, species=None,
                  scopes=None,
                  fields=None):
        """
        Simple wrapper that calls MyGene querymany
        returning the results

        :param queries: list of gene ids/symbols to query
        :type queries: list
        :param species:
        :type species: str
        :param scopes:
        :type scopes: str
        :param fields:
        :type fields: list
        :return: dict from MyGene usually in format of
        :rtype: list
        """
        mygene_out = self._mg.querymany(queries,
                                        scopes=scopes,
                                        fields=fields,
                                        species=species)
        return mygene_out

    def get_symbols_for_genes(self, genelist=None,
                              scopes='_id'):
        """
        Queries for genes via GeneQuery() object passed in via
        constructor

        :param genelist: genes to query for valid symbols and ensembl ids
        :type genelist: list
        :param scopes: field to query on _id for gene id, ensemble.gene
                       for ENSEMBLE IDs
        :type scopes: str
        :return: result from mygene which is a list of dict objects where
                 each dict is of format:

                 .. code-block::

                     { 'query': 'ID',
                       '_id': 'ID', '_score': #.##,
                       'ensembl': { 'gene': 'ENSEMBLEID' },
                       'symbol': 'GENESYMBOL' }
        :rtype: list
        """
        res = self.querymany(genelist,
                             species='human',
                             scopes=scopes,
                             fields=['ensembl.gene', 'symbol'])
        return res


class GeneNodeAttributeGenerator(object):
    """
    Base class for GeneNodeAttribute Generator
    """

    def __init__(self):
        """
        Constructor
        """
        pass

    @staticmethod
    def add_geneids_to_set(gene_set=None,
                           ambiguous_gene_dict=None,
                           geneid=None):
        """
        Examines **geneid** passed in and if a comma exists
        in value split by comma and assume multiple genes.
        Adds those genes into **gene_set** and add entry
        to **ambiguous_gene_dict** with key set to each gene
        name and value set to original **geneid** value

        :param gene_set: unique set of genes
        :type gene_set: set
        :param geneid: name of gene or comma delimited string of genes
        :type geneid: str
        :return: genes found in **geneid** or None if **gene_set**
                 or **geneid** is ``None``
        :rtype: list
        """
        if gene_set is None:
            return None
        if geneid is None:
            return None

        split_str = re.split('\W*,\W*', geneid)
        gene_set.update(split_str)
        if ambiguous_gene_dict is not None:
            if len(split_str) > 1:
                for entry in split_str:
                    ambiguous_gene_dict[entry] = geneid
        return split_str

    def get_gene_node_attributes(self):
        """
        Should be implemented by subclasses

        :raises NotImplementedError: Always
        """
        raise NotImplementedError('Subclasses should implement')
    
class NdexGeneNodeAttributeGenerator(GeneNodeAttributeGenerator):
    """
    Creates APMS Gene Node Attributes table and edgelist table from NDEx network data (.cx)
    """

    def __init__(self, apms_edgelist=None,
                 genequery=GeneQuery(), uuid, ndexserver):
        """
        Constructor

        :param apms_edgelist: list of dict elements where each
                              dict is of format:

                              .. code-block::

                                  {'Bait': VAL,
                                   'Prey': VAL,
                                   'logOddsScore': VAL,
                                   'FoldChange.x': VAL,
                                   'BFDR.x': VAL}
        :type apms_edgelist: list
        :param genequery:
        """
        super().__init__()
        self._raw_apms_edgelist = apms_edgelist
        self._apms_edgelist = None
        self._genequery = genequery
        self.uuid = uuid
        self.ndexserver = "http://public.ndexbio.org"
        self.node_attrs_list = self.get_gene_node_attributes ()


    @staticmethod
    def get_apms_edgelist_from_tsvfile(tsvfile=None,
                                       bait_col='Bait',
                                       prey_col='Prey',
                                       bfdr_col=None,
                                       foldchange_col=None,
                                       foldchange_cutoff=0.0,
                                       bfdr_maxcutoff=0.05):
        """
        Generates list of dicts by parsing TSV file specified
        by **tsvfile** with the
        format header column and corresponding values:

        .. code-block::

            Bait\tPrey\tBFDR.x\tFoldChange.x

        .. note::

           If BFDR.x column does not exist, no BFDR filtering will occur
           Same goes if FoldChange.x column does not exist

        :param tsvfile: Path to TSV file with above format
        :type tsvfile: str
        :param bait_col: Name of bait column
        :type bait_col: str
        :param prey_col: Name of prey column
        :type prey_col: str
        :param bfdr_col: Name of BFDR aka false discovery rate column
                         If ``None`` no BFDR filtering will occur
        :type bfdr_col: str
        :param foldchange_col: Name of FoldChange column
                               If ``None`` no FoldChange filtering will occur
        :type foldchange_col: str
        :param foldchange_cutoff: Foldchange cutoff. Only keep rows with
                                  values greater then this value.
                                  If this value is ``None`` no filtering
                                  will occur
        :type foldchange_cutoff: float
        :param bfdr_maxcutoff: BFDR cutoff. Only keep rows with BFDR
                               less then or equal to this value.
                               If this value is ``None`` no filtering will
                               occur
        :type bfdr_maxcutoff: float
        :return: list of dicts, with each dict of format:

                 .. code-block::

                      {'Bait': VAL,
                       'Prey': VAL}
        :rtype: list
        """
        edgelist = []
        with open(tsvfile, 'r') as f:
            reader = csv.DictReader(f, delimiter='\t')
            for row in reader:
                if bfdr_col is not None and bfdr_col in row \
                    and row[bfdr_col] > bfdr_maxcutoff:
                    continue
                if foldchange_col is not None and foldchange_col in row \
                    and row[foldchange_col] <= foldchange_cutoff:
                    continue
                edgelist.append({'Bait': row[bait_col],
                                 'Prey': row[prey_col]})
        return edgelist

    def _get_unique_set_from_raw_edgelist(self, colname=None):
        """
        Given a column name **colname** extract unique set of values from
        raw apms edgelist passed in via constructor

        :return:
        :rtype: set
        """
        col_set = set()
        for entry in self._raw_apms_edgelist:
            col_set.add(entry[colname])
        return col_set

    def _get_baits_to_ensemblsymbolmap(self):
        """
        Get unique set of bait names from raw apms edgelist
        and query mygene to get symbols and ensembl gene ids

        :return: original bait name to mapped to tuple
                 (id, symbol, ensembl gene id)
        :rtype: dict
        """
        bait_set = self._get_unique_set_from_raw_edgelist('Bait')
        res = self._genequery.get_symbols_for_genes(list(bait_set),
                                                    scopes='symbol')
        bait_to_id = {}
        for entry in res:
            bait_to_id[entry['query']] = (entry['_id'],
                                          entry['symbol'],
                                          entry['ensembl']['gene'])
        return bait_to_id

    def _get_prey_to_ensemblsymbolmap(self):
        """
        Get unique set of prey names from raw apms edgelist
        and query mygene to get symbols and ensembl gene ids

        :return: original bait name to mapped to tuple
                 (id, symbol, ensembl gene id)
        :rtype: dict
        """
        prey_set = self._get_unique_set_from_raw_edgelist('Prey')
        res = self._genequery.get_symbols_for_genes(list(prey_set),
                                                    scopes='uniprot')
        prey_to_id = {}
        for entry in res:
            ensemblstr = ''
            if 'ensembl' not in entry:
                logger.error(str(entry) + ' no ensembl found')
                continue
            if isinstance(entry['ensembl'], list):
                ensemblstr += ';'.join([g['gene'] for g in entry['ensembl']])
            else:
                ensemblstr = entry['ensembl']['gene']
            prey_to_id[entry['query']] = (entry['_id'],
                                          entry['symbol'],
                                          ensemblstr)
        return prey_to_id

    def get_apms_edgelist(self):
        """
        Gets apms edgelist

        :return:
        :rtype: list
        """
        if self._apms_edgelist is not None:
            return self._apms_edgelist

        # we need to generate this list
        baits_to_idmap = self._get_baits_to_ensemblsymbolmap()

        prey_set = self._get_unique_set_from_raw_edgelist('Prey')

        prey_to_idmap = self._get_prey_to_ensemblsymbolmap()
        self._apms_edgelist = []
        for row in self._raw_apms_edgelist:
            if row['Bait'] not in baits_to_idmap:
                logger.warning('Bait ' + str(row['Bait']) + ' not in map. Skipping')
                continue
            if row['Prey'] not in prey_to_idmap:
                logger.warning('Prey ' + str(row['Prey'] + ' not in map. Skipping'))
                continue
            bait_tuple = baits_to_idmap[row['Bait']]
            prey_tuple = prey_to_idmap[row['Prey']]
            self._apms_edgelist.append({'GeneID1': bait_tuple[0],
                                        'Symbol1': bait_tuple[1],
                                        'Ensembl1': bait_tuple[2],
                                        'GeneID2': prey_tuple[0],
                                        'Symbol2': prey_tuple[1],
                                        'Ensembl2': prey_tuple[2]})
        return self._apms_edgelist

    def _get_apms_bait_set(self):
        """
        Gets unique set of baits

        :return:
        :rtype: set
        """
        bait_set = set()
        for entry in self._apms_baitlist:
            bait_set.add(entry['GeneID'])
        return bait_set

    def get_gene_node_attributes(self):
        """
        Gene gene node attributes which is output as a list of
        dicts in this format:

        .. code-block::

            { 'GENEID': { 'name': 'GENESYMBOL',
                          'represents': 'ensemble:ENSEMBLID1;ENSEMBLID2..',
                          'ambiguous': 'ALTERNATE GENEs',
                          'bait': True or False}
            }



        :return: (list of dicts containing gene node attributes,
                  list of str describing any errors encountered)
        :rtype: tuple
        """
        self.get_apms_edgelist()
        errors = []
        gene_node_attrs = {}
        for i in ['1', '2']:
            if i == '1':
                bait = True
            else:
                bait = False
            for x in self._apms_edgelist:
                if x['GeneID' + i] in gene_node_attrs:
                    continue
                ensemblstr = 'ensembl:' + x['Ensembl' + i]
                gene_node_attrs[x['GeneID' + i]] = {'name': x['Symbol' + i],
                                                    'represents': ensemblstr,
                                                    'ambiguous': '',
                                                    'bait': bait}

        return gene_node_attrs, errors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Original code:
# ----> 3 class NdexGeneNodeAttributeGenerator(GeneNodeAttributeGenerator):
#       4     """
#       5     Creates APMS Gene Node Attributes table and edgelist table from NDEx network data (.cx)
#       6     """
#       8     def __init__(self, apms_edgelist=None,
#       9                  genequery=GeneQuery()):
#
# NameError: name 'GeneNodeAttributeGenerator' is not defined

# %%
def get_gene_node_attributes(nice_cx):
    nodes = nice_cx.nodes
    node_attrs = nice_cx.nodeAttributes

    attr_by_node_id = defaultdict(dict)
    for node_id,attr_list in node_attrs.items():
        for attr in attr_list:
            attr_name = attr['n']
            attr_value = attr['v']
            attr_by_node_id[node_id][attr_name] = attr_value

    gene_node_attrs = {}
    errors = []

    for node_id, node_data in nodes.items():
        node_id = node_id
        name = node_data.get('n')

        if name is None:
            errors.append(f"Node {node_id} has no 'name'")
            continue
        
        represents = node_data.get('r', None)
        bait = attr_by_node_id[node_id].get('bait', None)
        antibody = attr_by_node_id[node_id].get('antibody', None)
        ambiguous = attr_by_node_id[node_id].get('ambiguous', None)


        gene_node_attrs[str(node_id)] = {
            'name': name,
            'represents': represents,
            'ambiguous' : ambiguous,
            'bait': bait,
            'antibody': antibody
            
        }
    return gene_node_attrs, errors

# %%
test_list, errors = get_gene_node_attributes(nice_cx)
test_list
# Out:
# {635898: {'name': 'TMEM88',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  635852: {'name': 'COL10A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  635816: {'name': 'NT5DC3',
#   'represents': 'ensembl:ENSG00000111696',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041634'},
#  635680: {'name': 'CYCS',
#   'represents': 'ensembl:ENSG00000172115',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'CAB004222'},
#  635458: {'name': 'PHF20',
#   'represents': 'ensembl:ENSG00000025293',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA029620'},
#  635454: {'name': 'ZNF580',
#   'represents': 'ensembl:ENSG00000213015',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA054058'},
#  635420: {'name': 'WTIP',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  635416: {'name': 'ADD2',
#   'represents': 'ensembl:ENSG00000075340',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA034510'},
#  635392: {'name': 'SLC25A39',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  635388: {'name': 'DPH1',
#   'represents': 'ensembl:ENSG00000108963',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA069750'},
#  635370: {'name': 'ANKRD9',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  635336: {'name': 'B3GNTL1',
#   'represents': 'ensembl:ENSG00000175711;ENSG00000277033',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024547'},
#  635332: {'name': 'WDR25',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  635312: {'name': 'STK19',
#   'represents': 'ensembl:ENSG00000236250;ENSG00000206342;ENSG00000234947;ENSG00000204344;ENSG00000226257;ENSG00000226033',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA068559'},
#  635306: {'name': 'IMPDH2',
#   'represents': 'ensembl:ENSG00000178035',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB020717'},
#  635296: {'name': 'IMPDH1',
#   'represents': 'ensembl:ENSG00000106348',
#   'ambiguous': 'ENSG00000106348,ENSG00000178035,ENSG00000290315',
#   'bait': 'true',
#   'antibody': 'HPA001400'},
#  635242: {'name': 'TTC12',
#   'represents': 'ensembl:ENSG00000149292',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA038543'},
#  635224: {'name': 'DCUN1D5',
#   'represents': 'ensembl:ENSG00000137692',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA050863'},
#  635194: {'name': 'IP6K1',
#   'represents': 'ensembl:ENSG00000176095',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA040825'},
#  635044: {'name': 'HUS1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  635010: {'name': 'KCNK1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  635006: {'name': 'VSIG1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  634956: {'name': 'CENPE',
#   'represents': 'ensembl:ENSG00000138778',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA011110'},
#  634946: {'name': 'SYCE3',
#   'represents': 'ensembl:ENSG00000217442',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA047813'},
#  634596: {'name': 'IL22RA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  634530: {'name': 'KIF21A',
#   'represents': 'ensembl:ENSG00000139116',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA058432'},
#  634468: {'name': 'ZBTB7B',
#   'represents': 'ensembl:ENSG00000160685',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA006811'},
#  634460: {'name': 'P4HA3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  634436: {'name': 'KMT2C',
#   'represents': 'ensembl:ENSG00000055609',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA074736'},
#  634418: {'name': 'NCOA6',
#   'represents': 'ensembl:ENSG00000198646',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA004198'},
#  634394: {'name': 'GPBP1L1',
#   'represents': 'ensembl:ENSG00000159592',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA028593'},
#  634348: {'name': 'DHCR24',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  634282: {'name': 'FKBP1A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  634232: {'name': 'TRPM3',
#   'represents': 'ensembl:ENSG00000083067',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA072650'},
#  634224: {'name': 'PPARGC1B',
#   'represents': 'ensembl:ENSG00000155846',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA050543'},
#  634212: {'name': 'ESRRA',
#   'represents': 'ensembl:ENSG00000173153',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA053785'},
#  634208: {'name': 'ESRRG',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  634200: {'name': 'MAGEL2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  634146: {'name': 'FYN',
#   'represents': 'ensembl:ENSG00000010810',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA023887'},
#  634130: {'name': 'ISX',
#   'represents': 'ensembl:ENSG00000175329',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA060328'},
#  634112: {'name': 'ANAPC13',
#   'represents': 'ensembl:ENSG00000129055',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA046114'},
#  634100: {'name': 'NEK2',
#   'represents': 'ensembl:ENSG00000117650',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB017530'},
#  634006: {'name': 'NSF',
#   'represents': 'ensembl:ENSG00000276262;ENSG00000073969;ENSG00000278174',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003154'},
#  633974: {'name': 'GOSR2',
#   'represents': 'ensembl:ENSG00000108433',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA048956'},
#  633946: {'name': 'ZSCAN31',
#   'represents': 'ensembl:ENSG00000235109',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA007124'},
#  633922: {'name': 'TGIF1',
#   'represents': 'ensembl:ENSG00000177426',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA062160'},
#  633912: {'name': 'ZSCAN20',
#   'represents': 'ensembl:ENSG00000121903',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA017933'},
#  633902: {'name': 'ZNF500',
#   'represents': 'ensembl:ENSG00000103199',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA035498'},
#  633898: {'name': 'TGIF2',
#   'represents': 'ensembl:ENSG00000118707',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA053786'},
#  633818: {'name': 'AGAP2',
#   'represents': 'ensembl:ENSG00000135439',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA075831'},
#  633790: {'name': 'PPRC1',
#   'represents': 'ensembl:ENSG00000148840',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA038511'},
#  633736: {'name': 'PCDHA4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  633676: {'name': 'ARL5B',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  633580: {'name': 'ASIC1',
#   'represents': 'ensembl:ENSG00000110881',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA058870'},
#  633560: {'name': 'SLC2A4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  633556: {'name': 'FURIN',
#   'represents': 'ensembl:ENSG00000140564',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB009499'},
#  633300: {'name': 'SMAD3',
#   'represents': 'ensembl:ENSG00000166949',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB008094'},
#  633252: {'name': 'PPWD1',
#   'represents': 'ensembl:ENSG00000113593',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA019360'},
#  633228: {'name': 'PARP12',
#   'represents': 'ensembl:ENSG00000059378',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA063872'},
#  633198: {'name': 'RBM38',
#   'represents': 'ensembl:ENSG00000132819',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB017036'},
#  633186: {'name': 'NDUFAF2',
#   'represents': 'ensembl:ENSG00000164182',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA048082'},
#  633170: {'name': 'CD53',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  633166: {'name': 'SNAPC5',
#   'represents': 'ensembl:ENSG00000174446',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024379'},
#  633160: {'name': 'WAC',
#   'represents': 'ensembl:ENSG00000095787',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA042609'},
#  633138: {'name': 'SNTB1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  633132: {'name': 'SNTA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  633074: {'name': 'UGCG',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632970: {'name': 'CALR',
#   'represents': 'ensembl:ENSG00000179218',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB079775'},
#  632960: {'name': 'WSB1',
#   'represents': 'ensembl:ENSG00000109046',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003293'},
#  632954: {'name': 'GPR75-ASB3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632940: {'name': 'TULP4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632932: {'name': 'ASB7',
#   'represents': 'ensembl:ENSG00000183475',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003300'},
#  632924: {'name': 'RAB40C',
#   'represents': 'ensembl:ENSG00000197562',
#   'ambiguous': 'ENSG00000102128,ENSG00000141542,ENSG00000172476,ENSG00000197562',
#   'bait': 'false',
#   'antibody': 'HPA076172'},
#  632920: {'name': 'PCMTD1',
#   'represents': 'ensembl:ENSG00000168300',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA061444'},
#  632914: {'name': 'SOCS4',
#   'represents': 'ensembl:ENSG00000180008',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA057961'},
#  632898: {'name': 'SOCS5',
#   'represents': 'ensembl:ENSG00000171150',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA020884'},
#  632892: {'name': 'SOCS6',
#   'represents': 'ensembl:ENSG00000170677',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB010189'},
#  632888: {'name': 'SOCS7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632882: {'name': 'LARS2',
#   'represents': 'ensembl:ENSG00000011376',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA066085'},
#  632878: {'name': 'NF2',
#   'represents': 'ensembl:ENSG00000186575',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003097'},
#  632874: {'name': 'MSN',
#   'represents': 'ensembl:ENSG00000147065',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA011135'},
#  632870: {'name': 'EZR',
#   'represents': 'ensembl:ENSG00000092820',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB004035'},
#  632866: {'name': 'RDX',
#   'represents': 'ensembl:ENSG00000137710',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA000763'},
#  632834: {'name': 'GRAMD4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632804: {'name': 'UBXN8',
#   'represents': 'ensembl:ENSG00000104691',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA077538'},
#  632744: {'name': 'ZNF729',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632720: {'name': 'ZNF74',
#   'represents': 'ensembl:ENSG00000185252',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA003354'},
#  632702: {'name': 'SYTL3',
#   'represents': 'ensembl:ENSG00000164674',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA030586'},
#  632698: {'name': 'IKBKE',
#   'represents': 'ensembl:ENSG00000263528',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB025983'},
#  632686: {'name': 'PRDX1',
#   'represents': 'ensembl:ENSG00000117450',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA007730'},
#  632680: {'name': 'PRDX3',
#   'represents': 'ensembl:ENSG00000165672',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA063551'},
#  632676: {'name': 'TLN2',
#   'represents': 'ensembl:ENSG00000171914',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB017194'},
#  632672: {'name': 'TLN1',
#   'represents': 'ensembl:ENSG00000137076',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA004748'},
#  632650: {'name': 'KANK4',
#   'represents': 'ensembl:ENSG00000132854',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA014030'},
#  632608: {'name': 'CSTF1',
#   'represents': 'ensembl:ENSG00000101138',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB019270'},
#  632566: {'name': 'FGF17',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  632562: {'name': 'TXLNG',
#   'represents': 'ensembl:ENSG00000086712',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA000841'},
#  632558: {'name': 'NACA2',
#   'represents': 'ensembl:ENSG00000253506',
#   'ambiguous': 'ENSG00000196531,ENSG00000253506',
#   'bait': 'false',
#   'antibody': 'HPA073648'},
#  632548: {'name': 'TXLNA',
#   'represents': 'ensembl:ENSG00000084652',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA045383'},
#  632546: {'name': 'BTF3L4',
#   'represents': 'ensembl:ENSG00000134717',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA067026'},
#  632438: {'name': 'SOHLH1',
#   'represents': 'ensembl:ENSG00000165643',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA059439'},
#  632410: {'name': 'APOL2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632342: {'name': 'HLA-F',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632318: {'name': 'ITGB3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632294: {'name': 'ATPAF2',
#   'represents': 'ensembl:ENSG00000171953',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA023329'},
#  632286: {'name': 'ATPAF1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632278: {'name': 'ATP5ME',
#   'represents': 'ensembl:ENSG00000169020',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA035010'},
#  632274: {'name': 'ATP5PO',
#   'represents': 'ensembl:ENSG00000241837',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB016209'},
#  632270: {'name': 'ATP5F1C',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632244: {'name': 'MAFF',
#   'represents': 'ensembl:ENSG00000185022',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA055371'},
#  632238: {'name': 'CREBZF',
#   'represents': 'ensembl:ENSG00000137504',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA063652'},
#  632232: {'name': 'MAGEE1',
#   'represents': 'ensembl:ENSG00000198934',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003047'},
#  632208: {'name': 'MAFG',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  632186: {'name': 'RTN4R',
#   'represents': 'ensembl:ENSG00000040608',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB012443'},
#  632078: {'name': 'ASIC4',
#   'represents': 'ensembl:ENSG00000072182',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA036042'},
#  631994: {'name': 'LIMS1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  631990: {'name': 'RSU1',
#   'represents': 'ensembl:ENSG00000148484',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA025927'},
#  631982: {'name': 'SLC2A14',
#   'represents': 'ensembl:ENSG00000173262',
#   'ambiguous': 'ENSG00000059804,ENSG00000173262',
#   'bait': 'false',
#   'antibody': 'HPA006539'},
#  631976: {'name': 'SLC2A3',
#   'represents': 'ensembl:ENSG00000059804',
#   'ambiguous': 'ENSG00000059804,ENSG00000173262',
#   'bait': 'true',
#   'antibody': 'HPA006539'},
#  631968: {'name': 'CPEB4',
#   'represents': 'ensembl:ENSG00000113742',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA038394'},
#  631966: {'name': 'HOMEZ',
#   'represents': 'ensembl:ENSG00000290292',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA036316'},
#  631946: {'name': 'UBE2I',
#   'represents': 'ensembl:ENSG00000103275',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB079920'},
#  631942: {'name': 'SUMO1',
#   'represents': 'ensembl:ENSG00000116030',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA056956'},
#  631938: {'name': 'RAN',
#   'represents': 'ensembl:ENSG00000132341',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA063353'},
#  631826: {'name': 'HNRNPM',
#   'represents': 'ensembl:ENSG00000099783',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024344'},
#  631738: {'name': 'SGCE',
#   'represents': 'ensembl:ENSG00000127990',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA074790'},
#  631694: {'name': 'TGOLN2',
#   'represents': 'ensembl:ENSG00000152291',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA012723'},
#  631678: {'name': 'DBF4B',
#   'represents': 'ensembl:ENSG00000161692',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA048465'},
#  631616: {'name': 'SPARC',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  631558: {'name': 'VAMP5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  631504: {'name': 'FAN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  631500: {'name': 'MLH3',
#   'represents': 'ensembl:ENSG00000119684',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA060570'},
#  631482: {'name': 'HPS4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  631462: {'name': 'ALAD',
#   'represents': 'ensembl:ENSG00000148218',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA021023'},
#  631452: {'name': 'ARHGEF35',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  631406: {'name': 'DDX47',
#   'represents': 'ensembl:ENSG00000213782',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA014855'},
#  631374: {'name': 'SLIRP',
#   'represents': 'ensembl:ENSG00000119705',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA020291'},
#  631310: {'name': 'KIF22',
#   'represents': 'ensembl:ENSG00000079616',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA048213'},
#  631210: {'name': 'GGNBP2',
#   'represents': 'ensembl:ENSG00000278311;ENSG00000275099',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA073392'},
#  631130: {'name': 'TAPT1',
#   'represents': 'ensembl:ENSG00000169762',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA042567'},
#  631120: {'name': 'ESD',
#   'represents': 'ensembl:ENSG00000139684',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA039700'},
#  631108: {'name': 'FSD2',
#   'represents': 'ensembl:ENSG00000186628',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA046263'},
#  631060: {'name': 'PNRC2',
#   'represents': 'ensembl:ENSG00000189266',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA045837'},
#  631044: {'name': 'FAM185A',
#   'represents': 'ensembl:ENSG00000222011',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA029883'},
#  631032: {'name': 'NDUFA6',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  631020: {'name': 'NDUFB7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  631002: {'name': 'NDUFB4',
#   'represents': 'ensembl:ENSG00000065518',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA051739'},
#  630990: {'name': 'NDUFS5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  630974: {'name': 'KIAA0753',
#   'represents': 'ensembl:ENSG00000198920',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA023494'},
#  630960: {'name': 'KERA',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  630900: {'name': 'TXNL1',
#   'represents': 'ensembl:ENSG00000091164',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA002828'},
#  630896: {'name': 'PSMD3',
#   'represents': 'ensembl:ENSG00000108344',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB017038'},
#  630844: {'name': 'GNG2',
#   'represents': 'ensembl:ENSG00000186469',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA003534'},
#  630680: {'name': 'FBLN2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  630660: {'name': 'NTN5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  630652: {'name': 'LRWD1',
#   'represents': 'ensembl:ENSG00000161036',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA021320'},
#  630638: {'name': 'NEDD8',
#   'represents': 'ensembl:ENSG00000129559;ENSG00000285246',
#   'ambiguous': 'ENSG00000129559,ENSG00000255526',
#   'bait': 'false',
#   'antibody': 'HPA060254'},
#  630634: {'name': 'KISS1',
#   'represents': 'ensembl:ENSG00000170498',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA035542'},
#  630596: {'name': 'PPP2R5B',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  630586: {'name': 'SET',
#   'represents': 'ensembl:ENSG00000119335',
#   'ambiguous': 'ENSG00000119335,ENSG00000230667',
#   'bait': 'false',
#   'antibody': 'HPA063683'},
#  630578: {'name': 'SETSIP',
#   'represents': 'ensembl:ENSG00000230667',
#   'ambiguous': 'ENSG00000119335,ENSG00000230667',
#   'bait': 'false',
#   'antibody': 'HPA063683'},
#  630550: {'name': 'ZDHHC18',
#   'represents': 'ensembl:ENSG00000204160',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA040234'},
#  630528: {'name': 'SPNS1',
#   'represents': 'ensembl:ENSG00000169682',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041995'},
#  630458: {'name': 'SLC20A2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  630428: {'name': 'TMEM169',
#   'represents': 'ensembl:ENSG00000163449',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA070657'},
#  630388: {'name': 'HOXD4',
#   'represents': 'ensembl:ENSG00000170166',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA070349'},
#  630370: {'name': 'ANKMY2',
#   'represents': 'ensembl:ENSG00000106524',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA067100'},
#  630360: {'name': 'ADCY9',
#   'represents': 'ensembl:ENSG00000162104',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA041328'},
#  630324: {'name': 'ZNF407',
#   'represents': 'ensembl:ENSG00000215421',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041673'},
#  630318: {'name': 'CHRDL1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  630288: {'name': 'ZNF354C',
#   'represents': 'ensembl:ENSG00000177932',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA068570'},
#  630274: {'name': 'ZNF672',
#   'represents': 'ensembl:ENSG00000171161',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA055779'},
#  630198: {'name': 'NTN1',
#   'represents': 'ensembl:ENSG00000065320',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056419'},
#  630190: {'name': 'ZNF324',
#   'represents': 'ensembl:ENSG00000083812',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA039774'},
#  630176: {'name': 'CCN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  630154: {'name': 'ITFG2',
#   'represents': 'ensembl:ENSG00000111203',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA074606'},
#  630134: {'name': 'VWCE',
#   'represents': 'ensembl:ENSG00000167992',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA043921'},
#  630108: {'name': 'ZDHHC7',
#   'represents': 'ensembl:ENSG00000153786',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA059642'},
#  630020: {'name': 'PRKDC',
#   'represents': 'ensembl:ENSG00000253729',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA035174'},
#  629994: {'name': 'EPHA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  629952: {'name': 'KRBA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  629932: {'name': 'ESYT1',
#   'represents': 'ensembl:ENSG00000139641',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA076926'},
#  629922: {'name': 'ALPK2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  629884: {'name': 'NHLH2',
#   'represents': 'ensembl:ENSG00000177551',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA055238'},
#  629810: {'name': 'SCO2',
#   'represents': 'ensembl:ENSG00000284194',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA046943'},
#  629730: {'name': 'GRAMD1B',
#   'represents': 'ensembl:ENSG00000023171',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA075204'},
#  629716: {'name': 'PHF2',
#   'represents': 'ensembl:ENSG00000197724',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA010831'},
#  629704: {'name': 'ZC3HAV1',
#   'represents': 'ensembl:ENSG00000105939',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA059096'},
#  629692: {'name': 'ULBP3',
#   'represents': 'ensembl:ENSG00000131019',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056541'},
#  629646: {'name': 'TNFSF8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  629630: {'name': 'VMA21',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  629598: {'name': 'NFE2L3',
#   'represents': 'ensembl:ENSG00000050344',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA055889'},
#  629536: {'name': 'ZNF467',
#   'represents': 'ensembl:ENSG00000181444',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA042907'},
#  629532: {'name': 'ACSF3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  629478: {'name': 'SNX19',
#   'represents': 'ensembl:ENSG00000120451',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA013447'},
#  629374: {'name': 'FZD10',
#   'represents': 'ensembl:ENSG00000111432',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA014485'},
#  629370: {'name': 'NUDT8',
#   'represents': 'ensembl:ENSG00000167799',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041252'},
#  629358: {'name': 'DNAJC15',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  629294: {'name': 'RNF167',
#   'represents': 'ensembl:ENSG00000108523',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA049810'},
#  629276: {'name': 'HIGD2A',
#   'represents': 'ensembl:ENSG00000146066',
#   'ambiguous': 'ENSG00000146066,ENSG00000175202',
#   'bait': 'false',
#   'antibody': 'HPA042715'},
#  629264: {'name': 'AIFM2',
#   'represents': 'ensembl:ENSG00000042286',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA075576'},
#  629150: {'name': 'C3orf33',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  629144: {'name': 'SLC27A4',
#   'represents': 'ensembl:ENSG00000167114',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA007293'},
#  629118: {'name': 'PTGIS',
#   'represents': 'ensembl:ENSG00000124212',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA052244'},
#  629088: {'name': 'MGAT2',
#   'represents': 'ensembl:ENSG00000168282',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056824'},
#  629076: {'name': 'ALDH3A2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  629058: {'name': 'EPHA2',
#   'represents': 'ensembl:ENSG00000142627',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB010464'},
#  628982: {'name': 'EI24',
#   'represents': 'ensembl:ENSG00000149547',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA051029'},
#  628958: {'name': 'SSBP1',
#   'represents': 'ensembl:ENSG00000262771;ENSG00000106028',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA002866'},
#  628954: {'name': 'CLEC4C',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  628910: {'name': 'STOML2',
#   'represents': 'ensembl:ENSG00000165283',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB015944'},
#  628798: {'name': 'DUOXA2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  628786: {'name': 'DDR2',
#   'represents': 'ensembl:ENSG00000162733',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA070112'},
#  628772: {'name': 'LRRC52',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  628754: {'name': 'DAZAP1',
#   'represents': 'ensembl:ENSG00000071626',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA004201'},
#  628724: {'name': 'LRRC73',
#   'represents': 'ensembl:ENSG00000204052',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA046698'},
#  628708: {'name': 'FBXO16',
#   'represents': 'ensembl:ENSG00000214050',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA058676'},
#  628676: {'name': 'TBC1D22B',
#   'represents': 'ensembl:ENSG00000065491',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA027910'},
#  628638: {'name': 'TUBB6',
#   'represents': 'ensembl:ENSG00000176014',
#   'ambiguous': 'ENSG00000101162,ENSG00000104833,ENSG00000137267,ENSG00000137285,ENSG00000173213,ENSG00000176014,ENSG00000188229,ENSG00000196230,ENSG00000198211,ENSG00000258947,ENSG00000261456',
#   'bait': 'false',
#   'antibody': 'HPA046280'},
#  628540: {'name': 'KPNB1',
#   'represents': 'ensembl:ENSG00000108424',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA029878'},
#  628526: {'name': 'TUBA1B',
#   'represents': 'ensembl:ENSG00000123416',
#   'ambiguous': 'ENSG00000075886,ENSG00000123416,ENSG00000127824,ENSG00000152086,ENSG00000167552,ENSG00000167553,ENSG00000183785,ENSG00000198033',
#   'bait': 'false',
#   'antibody': 'HPA043684'},
#  628496: {'name': 'RCBTB2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  628470: {'name': 'CD80',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  628370: {'name': 'LHFPL2',
#   'represents': 'ensembl:ENSG00000145685',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA076743'},
#  628362: {'name': 'DOP1B',
#   'represents': 'ensembl:ENSG00000142197',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA072065'},
#  628334: {'name': 'AP5S1',
#   'represents': 'ensembl:ENSG00000125843',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA048244'},
#  628324: {'name': 'GBA2',
#   'represents': 'ensembl:ENSG00000070610',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024026'},
#  628286: {'name': 'EVI5L',
#   'represents': 'ensembl:ENSG00000142459',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA043563'},
#  628276: {'name': 'ATRIP',
#   'represents': 'ensembl:ENSG00000164053',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA047590'},
#  628184: {'name': 'XPOT',
#   'represents': 'ensembl:ENSG00000184575',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA048067'},
#  628146: {'name': 'PPP1R12A',
#   'represents': 'ensembl:ENSG00000058272',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041296'},
#  628048: {'name': 'SLC2A12',
#   'represents': 'ensembl:ENSG00000146411',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA031593'},
#  628008: {'name': 'TAF7L',
#   'represents': 'ensembl:ENSG00000102387',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA072008'},
#  627996: {'name': 'TBC1D32',
#   'represents': 'ensembl:ENSG00000146350',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA013413'},
#  627982: {'name': 'FOXJ1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  627968: {'name': 'GTF3C4',
#   'represents': 'ensembl:ENSG00000125484',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA069369'},
#  627946: {'name': 'BAZ1A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  627908: {'name': 'RRP36',
#   'represents': 'ensembl:ENSG00000124541',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA029905'},
#  627712: {'name': 'KDM8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  627678: {'name': 'EIF2S3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  627674: {'name': 'EIF2S2',
#   'represents': 'ensembl:ENSG00000125977',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041262'},
#  627656: {'name': 'LRRC27',
#   'represents': 'ensembl:ENSG00000148814',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA037595'},
#  627634: {'name': 'MILR1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  627616: {'name': 'ABCE1',
#   'represents': 'ensembl:ENSG00000164163',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA036846'},
#  627612: {'name': 'LTO1',
#   'represents': 'ensembl:ENSG00000149716',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA062696'},
#  627604: {'name': 'ZNF784',
#   'represents': 'ensembl:ENSG00000179922',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA059676'},
#  627574: {'name': 'MAPK11',
#   'represents': 'ensembl:ENSG00000185386',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA073133'},
#  627542: {'name': 'MPP1',
#   'represents': 'ensembl:ENSG00000130830',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA076675'},
#  627306: {'name': 'DPY19L3',
#   'represents': 'ensembl:ENSG00000178904',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA008325'},
#  627296: {'name': 'TEX261',
#   'represents': 'ensembl:ENSG00000144043',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA016631'},
#  627248: {'name': 'MEN1',
#   'represents': 'ensembl:ENSG00000133895',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA030342'},
#  627242: {'name': 'CD226',
#   'represents': 'ensembl:ENSG00000150637',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA015865'},
#  627232: {'name': 'MICB',
#   'represents': 'ensembl:ENSG00000234218;ENSG00000224378;ENSG00000206449;ENSG00000204516;ENSG00000231372;ENSG00000227772;ENSG00000231179;ENSG00000238289',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA064618'},
#  627192: {'name': 'ZAR1L',
#   'represents': 'ensembl:ENSG00000189167',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA039540'},
#  627146: {'name': 'HFE',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  627130: {'name': 'SMURF1',
#   'represents': 'ensembl:ENSG00000198742;ENSG00000284126',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA019671'},
#  627108: {'name': 'ZNF114',
#   'represents': 'ensembl:ENSG00000178150',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA025019'},
#  627048: {'name': 'PROCR',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  627028: {'name': 'DPP7',
#   'represents': 'ensembl:ENSG00000176978',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA059381'},
#  627002: {'name': 'TMEM30A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626988: {'name': 'SLAMF7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626982: {'name': 'SIAE',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626958: {'name': 'ABCA2',
#   'represents': 'ensembl:ENSG00000107331',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA042886'},
#  626892: {'name': 'HM13',
#   'represents': 'ensembl:ENSG00000101294',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056062'},
#  626866: {'name': 'LARGE2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626846: {'name': 'DPY19L4',
#   'represents': 'ensembl:ENSG00000156162',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024780'},
#  626810: {'name': 'GALNT18',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626776: {'name': 'KLHL40',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626710: {'name': 'MXRA7',
#   'represents': 'ensembl:ENSG00000182534',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA044819'},
#  626702: {'name': 'CXADR',
#   'represents': 'ensembl:ENSG00000154639',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB005103'},
#  626650: {'name': 'ITGA3',
#   'represents': 'ensembl:ENSG00000005884',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB018594'},
#  626632: {'name': 'SMPD1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626584: {'name': 'ITGB1',
#   'represents': 'ensembl:ENSG00000150093',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB003434'},
#  626524: {'name': 'TLR3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  626450: {'name': 'OSTM1',
#   'represents': 'ensembl:ENSG00000081087',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA010851'},
#  626302: {'name': 'HSP90B1',
#   'represents': 'ensembl:ENSG00000166598',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003901'},
#  626244: {'name': 'C9orf40',
#   'represents': 'ensembl:ENSG00000135045',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA042167'},
#  626132: {'name': 'NR1D1',
#   'represents': 'ensembl:ENSG00000126368',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA007935'},
#  626118: {'name': 'RTN4',
#   'represents': 'ensembl:ENSG00000115310',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA023977'},
#  626110: {'name': 'RTN1',
#   'represents': 'ensembl:ENSG00000139970',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA040945'},
#  625950: {'name': 'RTKN2',
#   'represents': 'ensembl:ENSG00000182010',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA037946'},
#  625900: {'name': 'COPG1',
#   'represents': 'ensembl:ENSG00000181789',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA037866'},
#  625880: {'name': 'STXBP4',
#   'represents': 'ensembl:ENSG00000166263',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA022888'},
#  625842: {'name': 'RHPN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  625784: {'name': 'ADGRL3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  625732: {'name': 'ZNF274',
#   'represents': 'ensembl:ENSG00000171606',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA028880'},
#  625710: {'name': 'ACSF2',
#   'represents': 'ensembl:ENSG00000167107',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA024693'},
#  625638: {'name': 'CEP295',
#   'represents': 'ensembl:ENSG00000166004',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA038596'},
#  625616: {'name': 'UNC13B',
#   'represents': 'ensembl:ENSG00000198722',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024493'},
#  625614: {'name': 'CEP72',
#   'represents': 'ensembl:ENSG00000112877;ENSG00000280688',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA074879'},
#  625570: {'name': 'ZNF622',
#   'represents': 'ensembl:ENSG00000173545',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA036515'},
#  625558: {'name': 'RNASEH2C',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  625500: {'name': 'PLCB2',
#   'represents': 'ensembl:ENSG00000137841',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041298'},
#  625430: {'name': 'SYT16',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  625410: {'name': 'GUF1',
#   'represents': 'ensembl:ENSG00000151806',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024222'},
#  625354: {'name': 'GLUD2',
#   'represents': 'ensembl:ENSG00000182890;ENSG00000288118',
#   'ambiguous': 'ENSG00000148672,ENSG00000182890',
#   'bait': 'false',
#   'antibody': 'HPA044839'},
#  625342: {'name': 'GLUD1',
#   'represents': 'ensembl:ENSG00000148672',
#   'ambiguous': 'ENSG00000148672,ENSG00000182890',
#   'bait': 'false',
#   'antibody': 'HPA044839'},
#  625338: {'name': 'PARN',
#   'represents': 'ensembl:ENSG00000140694;ENSG00000274829',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA006314'},
#  625286: {'name': 'PIGB',
#   'represents': 'ensembl:ENSG00000069943',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA039929'},
#  625226: {'name': 'GLRB',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  625220: {'name': 'GABRB3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  625182: {'name': 'CYTH1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  625124: {'name': 'CCDC120',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  625118: {'name': 'SLC46A1',
#   'represents': 'ensembl:ENSG00000076351',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB011614'},
#  625092: {'name': 'STX10',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  625008: {'name': 'STX16',
#   'represents': 'ensembl:ENSG00000124222',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041019'},
#  624922: {'name': 'KCTD15',
#   'represents': 'ensembl:ENSG00000153885',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA042522'},
#  624822: {'name': 'BCHE',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  624766: {'name': 'KBTBD8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  624712: {'name': 'TMPRSS13',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  624708: {'name': 'WDR12',
#   'represents': 'ensembl:ENSG00000138442',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA036389'},
#  624702: {'name': 'DDX27',
#   'represents': 'ensembl:ENSG00000124228',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA047087'},
#  624694: {'name': 'BOP1',
#   'represents': 'ensembl:ENSG00000285301;ENSG00000261236',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA066764'},
#  624654: {'name': 'RBM12B',
#   'represents': 'ensembl:ENSG00000183808',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA053050'},
#  624590: {'name': 'ZNF276',
#   'represents': 'ensembl:ENSG00000158805',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA021309'},
#  624586: {'name': 'BLMH',
#   'represents': 'ensembl:ENSG00000108578',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA039548'},
#  624538: {'name': 'CCT8L2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  624522: {'name': 'SLC41A3',
#   'represents': 'ensembl:ENSG00000114544',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA045847'},
#  624426: {'name': 'RBM8A',
#   'represents': 'ensembl:ENSG00000265241',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA018403'},
#  624420: {'name': 'NOP16',
#   'represents': 'ensembl:ENSG00000048162',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA036506'},
#  624378: {'name': 'MAGOHB',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  624326: {'name': 'RPS15',
#   'represents': 'ensembl:ENSG00000115268',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA054510'},
#  624322: {'name': 'RPS16',
#   'represents': 'ensembl:ENSG00000105193',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA064222'},
#  624318: {'name': 'RPS5',
#   'represents': 'ensembl:ENSG00000083845',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA055878'},
#  624310: {'name': 'RPS17',
#   'represents': 'ensembl:ENSG00000182774;ENSG00000278229',
#   'ambiguous': 'ENSG00000182774,ENSG00000260836',
#   'bait': 'false',
#   'antibody': 'HPA055060'},
#  624248: {'name': 'ABLIM2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  624242: {'name': 'IFNAR1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  624190: {'name': 'LOXL1',
#   'represents': 'ensembl:ENSG00000129038',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA063583'},
#  624162: {'name': 'P4HB',
#   'represents': 'ensembl:ENSG00000185624',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA018884'},
#  624096: {'name': 'CHP1',
#   'represents': 'ensembl:ENSG00000187446',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA006616'},
#  624074: {'name': 'MFF',
#   'represents': 'ensembl:ENSG00000168958',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA074625'},
#  624060: {'name': 'TMEM209',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  624006: {'name': 'SLC25A3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  623984: {'name': 'SLC25A5',
#   'represents': 'ensembl:ENSG00000005022',
#   'ambiguous': 'ENSG00000005022,ENSG00000151475,ENSG00000151729,ENSG00000169100',
#   'bait': 'false',
#   'antibody': 'HPA046835'},
#  623974: {'name': 'SLC1A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  623948: {'name': 'UGGT1',
#   'represents': 'ensembl:ENSG00000136731',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA015127'},
#  623934: {'name': 'ALG9',
#   'represents': 'ensembl:ENSG00000086848',
#   'ambiguous': 'ENSG00000086848,ENSG00000258529',
#   'bait': 'false',
#   'antibody': 'HPA038575'},
#  623918: {'name': 'TMUB1',
#   'represents': 'ensembl:ENSG00000164897',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA029429'},
#  623910: {'name': 'CGRRF1',
#   'represents': 'ensembl:ENSG00000100532',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA002930'},
#  623902: {'name': 'SLC38A2',
#   'represents': 'ensembl:ENSG00000134294',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA069672'},
#  623888: {'name': 'SLC25A46',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  623850: {'name': 'KCNJ8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  623834: {'name': 'ABCG1',
#   'represents': 'ensembl:ENSG00000160179',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA031470'},
#  623796: {'name': 'ADGRG5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  623770: {'name': 'GDAP2',
#   'represents': 'ensembl:ENSG00000196505',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA046185'},
#  623766: {'name': 'MYO10',
#   'represents': 'ensembl:ENSG00000145555',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA024223'},
#  623678: {'name': 'HNRNPA3',
#   'represents': 'ensembl:ENSG00000170144',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA066381'},
#  623674: {'name': 'CDC34',
#   'represents': 'ensembl:ENSG00000099804',
#   'ambiguous': 'ENSG00000099804,ENSG00000107341',
#   'bait': 'false',
#   'antibody': 'HPA074334'},
#  623662: {'name': 'HNRNPA2B1',
#   'represents': 'ensembl:ENSG00000122566',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB012403'},
#  623656: {'name': 'HNRNPL',
#   'represents': 'ensembl:ENSG00000104824;ENSG00000282947',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA052661'},
#  623636: {'name': 'HNRNPR',
#   'represents': 'ensembl:ENSG00000125944;ENSG00000282958',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA026092'},
#  623632: {'name': 'HNRNPDL',
#   'represents': 'ensembl:ENSG00000152795',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056820'},
#  623572: {'name': 'RIOX1',
#   'represents': 'ensembl:ENSG00000170468',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003730'},
#  623540: {'name': 'RPLP2',
#   'represents': 'ensembl:ENSG00000177600',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA075365'},
#  623532: {'name': 'ZSCAN5A',
#   'represents': 'ensembl:ENSG00000131848',
#   'ambiguous': 'ENSG00000131848,ENSG00000197213,ENSG00000204532',
#   'bait': 'true',
#   'antibody': 'HPA060667'},
#  623528: {'name': 'GDF5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  623520: {'name': 'CTTN',
#   'represents': 'ensembl:ENSG00000085733;ENSG00000288401',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA057242'},
#  623506: {'name': 'MPLKIP',
#   'represents': 'ensembl:ENSG00000168303',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA065463'},
#  623486: {'name': 'CCNJ',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
# ...
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA040213'},
#  608550: {'name': 'SEC24D',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  608516: {'name': 'TM9SF2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  608506: {'name': 'TACR1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608486: {'name': 'P2RY1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608482: {'name': 'TYSND1',
#   'represents': 'ensembl:ENSG00000156521',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA030304'},
#  608478: {'name': 'DNAAF2',
#   'represents': 'ensembl:ENSG00000165506',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA004113'},
#  608476: {'name': 'UBE3D',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608464: {'name': 'AVPR2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608456: {'name': 'GINS1',
#   'represents': 'ensembl:ENSG00000101003',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA051185'},
#  608448: {'name': 'EFCAB11',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608444: {'name': 'BHLHE22',
#   'represents': 'ensembl:ENSG00000180828',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA067500'},
#  608434: {'name': 'BHLHE23',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608426: {'name': 'RFX3',
#   'represents': 'ensembl:ENSG00000080298',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA035689'},
#  608416: {'name': 'TM7SF3',
#   'represents': 'ensembl:ENSG00000064115',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA057640'},
#  608400: {'name': 'SCAMP4',
#   'represents': 'ensembl:ENSG00000227500',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA043284'},
#  608390: {'name': 'TMEM104',
#   'represents': 'ensembl:ENSG00000109066',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA044330'},
#  608362: {'name': 'KDELR2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  608358: {'name': 'KDELR1',
#   'represents': 'ensembl:ENSG00000105438',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB017455'},
#  608348: {'name': 'GPR12',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608334: {'name': 'CBX5',
#   'represents': 'ensembl:ENSG00000094916',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA016699'},
#  608324: {'name': 'FGF11',
#   'represents': 'ensembl:ENSG00000161958;ENSG00000283903',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA066605'},
#  608318: {'name': 'DAD1',
#   'represents': 'ensembl:ENSG00000129562',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA028882'},
#  608312: {'name': 'HES1',
#   'represents': 'ensembl:ENSG00000114315',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA066929'},
#  608308: {'name': 'HES6',
#   'represents': 'ensembl:ENSG00000144485',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA073997'},
#  608302: {'name': 'NMT1',
#   'represents': 'ensembl:ENSG00000136448',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA022949'},
#  608298: {'name': 'ACBD6',
#   'represents': 'ensembl:ENSG00000230124',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA028457'},
#  608282: {'name': 'RPL22',
#   'represents': 'ensembl:ENSG00000116251',
#   'ambiguous': 'ENSG00000116251,ENSG00000163584',
#   'bait': 'true',
#   'antibody': 'HPA068294'},
#  608274: {'name': 'SNF8',
#   'represents': 'ensembl:ENSG00000159210',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA059320'},
#  608262: {'name': 'C19orf38',
#   'represents': 'ensembl:ENSG00000214212',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA055027'},
#  608246: {'name': 'PHLDA3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  608234: {'name': 'HPF1',
#   'represents': 'ensembl:ENSG00000056050',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA043467'},
#  608142: {'name': 'DNAJC25',
#   'represents': 'ensembl:ENSG00000059769',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA019122'},
#  608096: {'name': 'FOXM1',
#   'represents': 'ensembl:ENSG00000111206',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB017832'},
#  608078: {'name': 'CTLA4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  608030: {'name': 'TSPAN10',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  608026: {'name': 'ZNF669',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  608020: {'name': 'ZNF444',
#   'represents': 'ensembl:ENSG00000167685',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056895'},
#  608004: {'name': 'ZNF35',
#   'represents': 'ensembl:ENSG00000281306;ENSG00000169981',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA054738'},
#  607992: {'name': 'FAM81A',
#   'represents': 'ensembl:ENSG00000157470',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA065797'},
#  607974: {'name': 'CACYBP',
#   'represents': 'ensembl:ENSG00000116161',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA025753'},
#  607942: {'name': 'PRKD1',
#   'represents': 'ensembl:ENSG00000184304',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA029834'},
#  607924: {'name': 'PLCB3',
#   'represents': 'ensembl:ENSG00000149782',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB009257'},
#  607884: {'name': 'PTPN4',
#   'represents': 'ensembl:ENSG00000088179',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA019351'},
#  607856: {'name': 'COLGALT1',
#   'represents': 'ensembl:ENSG00000130309',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA047821'},
#  607852: {'name': 'COL21A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607822: {'name': 'CD28',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607810: {'name': 'PIWIL1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607806: {'name': 'TDRKH',
#   'represents': 'ensembl:ENSG00000182134',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA019625'},
#  607802: {'name': 'PIWIL4',
#   'represents': 'ensembl:ENSG00000134627',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA036587'},
#  607790: {'name': 'CDK1',
#   'represents': 'ensembl:ENSG00000170312',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'CAB079974'},
#  607788: {'name': 'SPDYC',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607772: {'name': 'IGFN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607760: {'name': 'C7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607750: {'name': 'TTC16',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607734: {'name': 'RALYL',
#   'represents': 'ensembl:ENSG00000184672',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA055868'},
#  607732: {'name': 'RALY',
#   'represents': 'ensembl:ENSG00000125970',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA040971'},
#  607680: {'name': 'ADCY5',
#   'represents': 'ensembl:ENSG00000173175',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA077682'},
#  607670: {'name': 'CACNG5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607666: {'name': 'PFKP',
#   'represents': 'ensembl:ENSG00000067057',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA056484'},
#  607660: {'name': 'EML4',
#   'represents': 'ensembl:ENSG00000143924',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA036688'},
#  607648: {'name': 'CREB1',
#   'represents': 'ensembl:ENSG00000118260',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA019150'},
#  607604: {'name': 'H1-7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607592: {'name': 'IL12A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607548: {'name': 'SCLT1',
#   'represents': 'ensembl:ENSG00000151466',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA036561'},
#  607540: {'name': 'KIZ',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607496: {'name': 'SLC39A12',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607482: {'name': 'LIMK1',
#   'represents': 'ensembl:ENSG00000106683',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA028516'},
#  607442: {'name': 'WDR11',
#   'represents': 'ensembl:ENSG00000120008',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA038980'},
#  607424: {'name': 'HNRNPH1',
#   'represents': 'ensembl:ENSG00000169045;ENSG00000284254',
#   'ambiguous': 'ENSG00000126945,ENSG00000169045',
#   'bait': 'false',
#   'antibody': 'HPA000914'},
#  607410: {'name': 'PMEL',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607404: {'name': 'TAF4B',
#   'represents': 'ensembl:ENSG00000141384',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA028937'},
#  607392: {'name': 'DYNLT4',
#   'represents': 'ensembl:ENSG00000188396',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA050116'},
#  607374: {'name': 'SPATA25',
#   'represents': 'ensembl:ENSG00000149634',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA041386'},
#  607364: {'name': 'RPS6KA6',
#   'represents': 'ensembl:ENSG00000072133',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA003904'},
#  607344: {'name': 'ZNF106',
#   'represents': 'ensembl:ENSG00000103994',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA054267'},
#  607324: {'name': 'RP9',
#   'represents': 'ensembl:ENSG00000164610',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA050778'},
#  607312: {'name': 'SMG6',
#   'represents': 'ensembl:ENSG00000070366',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA042932'},
#  607272: {'name': 'EIF3J',
#   'represents': 'ensembl:ENSG00000104131',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA050977'},
#  607266: {'name': 'NMT2',
#   'represents': 'ensembl:ENSG00000152465',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA001303'},
#  607254: {'name': 'IFNA7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  607250: {'name': 'IFNA14',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607240: {'name': 'PXDC1',
#   'represents': 'ensembl:ENSG00000168994',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA019246'},
#  607232: {'name': 'APBA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  607216: {'name': 'IFNA8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607202: {'name': 'RNF138',
#   'represents': 'ensembl:ENSG00000134758',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA041101'},
#  607196: {'name': 'COA6',
#   'represents': 'ensembl:ENSG00000168275',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA028588'},
#  607192: {'name': 'SNAPC1',
#   'represents': 'ensembl:ENSG00000023608',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA067076'},
#  607184: {'name': 'NAP1L5',
#   'represents': 'ensembl:ENSG00000177432',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA058227'},
#  607164: {'name': 'PRICKLE2',
#   'represents': 'ensembl:ENSG00000163637',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA035493'},
#  607144: {'name': 'ADCYAP1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  607116: {'name': 'EXOSC7',
#   'represents': 'ensembl:ENSG00000075914',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA057980'},
#  607038: {'name': 'ZNF398',
#   'represents': 'ensembl:ENSG00000197024',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA073151'},
#  607032: {'name': 'TCF20',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  607028: {'name': 'CFDP1',
#   'represents': 'ensembl:ENSG00000153774',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA048242'},
#  606978: {'name': 'MRE11',
#   'represents': 'ensembl:ENSG00000020922',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA002691'},
#  606974: {'name': 'FAM219A',
#   'represents': 'ensembl:ENSG00000164970',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA019338'},
#  606966: {'name': 'LECT2',
#   'represents': 'ensembl:ENSG00000145826',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA058246'},
#  606948: {'name': 'POLR2I',
#   'represents': 'ensembl:ENSG00000105258',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA045156'},
#  606856: {'name': 'FNBP4',
#   'represents': 'ensembl:ENSG00000285182;ENSG00000109920',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA039485'},
#  606820: {'name': 'IRF9',
#   'represents': 'ensembl:ENSG00000213928;ENSG00000285048',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA001862'},
#  606816: {'name': 'STAT1',
#   'represents': 'ensembl:ENSG00000115415',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA000931'},
#  606810: {'name': 'BCS1L',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  606802: {'name': 'FIBCD1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  606766: {'name': 'CDC6',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  606738: {'name': 'PCDH20',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  606732: {'name': 'KLHL36',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  606726: {'name': 'GPAT3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': None},
#  606722: {'name': 'SLC6A15',
#   'represents': 'ensembl:ENSG00000072041',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA008609'},
#  606698: {'name': 'SERF2',
#   'represents': 'ensembl:ENSG00000140264',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA056613'},
#  606674: {'name': 'SUPT16H',
#   'represents': 'ensembl:ENSG00000092201',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA049787'},
#  606666: {'name': 'CCDC82',
#   'represents': 'ensembl:ENSG00000149231',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA070631'},
#  606660: {'name': 'MCM2',
#   'represents': 'ensembl:ENSG00000073111',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA031496'},
#  606646: {'name': 'L3MBTL1',
#   'represents': 'ensembl:ENSG00000185513',
#   'ambiguous': 'ENSG00000185513,ENSG00000288000',
#   'bait': 'true',
#   'antibody': 'HPA059648'},
#  606586: {'name': 'LRRN2',
#   'represents': 'ensembl:ENSG00000170382',
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': 'HPA029124'},
#  606582: {'name': 'LAS1L',
#   'represents': 'ensembl:ENSG00000001497',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA044431'},
#  606574: {'name': 'SENP3',
#   'represents': 'ensembl:ENSG00000161956',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA060290'},
#  606572: {'name': 'NOL9',
#   'represents': None,
#   'ambiguous': None,
#   'bait': 'true',
#   'antibody': None},
#  606518: {'name': 'HEBP1',
#   'represents': 'ensembl:ENSG00000013583',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA075277'},
#  606430: {'name': 'RPEL1',
#   'represents': 'ensembl:ENSG00000235376',
#   'ambiguous': 'ENSG00000197713,ENSG00000235376',
#   'bait': 'false',
#   'antibody': 'HPA036499'},
#  606368: {'name': 'YARS1',
#   'represents': 'ensembl:ENSG00000134684',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA018954'},
#  606332: {'name': 'USP5',
#   'represents': 'ensembl:ENSG00000111667',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA006756'},
#  606260: {'name': 'ASNS',
#   'represents': 'ensembl:ENSG00000070669',
#   'ambiguous': None,
#   'bait': 'false',
#   'antibody': 'HPA004924'},
#  ...}

# %%
nodes_comb = get_gene_node_attributes(nice_cx)

# %%
nodes_comb
# Out:
# [{'name': 'TMEM88',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'COL10A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'NT5DC3',
#   'represents': 'ensembl:ENSG00000111696',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041634'},
#  {'name': 'CYCS',
#   'represents': 'ensembl:ENSG00000172115',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'CAB004222'},
#  {'name': 'PHF20',
#   'represents': 'ensembl:ENSG00000025293',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA029620'},
#  {'name': 'ZNF580',
#   'represents': 'ensembl:ENSG00000213015',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA054058'},
#  {'name': 'WTIP',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ADD2',
#   'represents': 'ensembl:ENSG00000075340',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA034510'},
#  {'name': 'SLC25A39',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'DPH1',
#   'represents': 'ensembl:ENSG00000108963',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA069750'},
#  {'name': 'ANKRD9',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'B3GNTL1',
#   'represents': 'ensembl:ENSG00000175711;ENSG00000277033',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024547'},
#  {'name': 'WDR25',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'STK19',
#   'represents': 'ensembl:ENSG00000236250;ENSG00000206342;ENSG00000234947;ENSG00000204344;ENSG00000226257;ENSG00000226033',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA068559'},
#  {'name': 'IMPDH2',
#   'represents': 'ensembl:ENSG00000178035',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB020717'},
#  {'name': 'IMPDH1',
#   'represents': 'ensembl:ENSG00000106348',
#   'ambiguous': 'ENSG00000106348,ENSG00000178035,ENSG00000290315',
#   'bait': True,
#   'antibody': 'HPA001400'},
#  {'name': 'TTC12',
#   'represents': 'ensembl:ENSG00000149292',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA038543'},
#  {'name': 'DCUN1D5',
#   'represents': 'ensembl:ENSG00000137692',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA050863'},
#  {'name': 'IP6K1',
#   'represents': 'ensembl:ENSG00000176095',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA040825'},
#  {'name': 'HUS1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'KCNK1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'VSIG1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CENPE',
#   'represents': 'ensembl:ENSG00000138778',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA011110'},
#  {'name': 'SYCE3',
#   'represents': 'ensembl:ENSG00000217442',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA047813'},
#  {'name': 'IL22RA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'KIF21A',
#   'represents': 'ensembl:ENSG00000139116',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA058432'},
#  {'name': 'ZBTB7B',
#   'represents': 'ensembl:ENSG00000160685',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA006811'},
#  {'name': 'P4HA3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'KMT2C',
#   'represents': 'ensembl:ENSG00000055609',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA074736'},
#  {'name': 'NCOA6',
#   'represents': 'ensembl:ENSG00000198646',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA004198'},
#  {'name': 'GPBP1L1',
#   'represents': 'ensembl:ENSG00000159592',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA028593'},
#  {'name': 'DHCR24',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'FKBP1A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TRPM3',
#   'represents': 'ensembl:ENSG00000083067',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA072650'},
#  {'name': 'PPARGC1B',
#   'represents': 'ensembl:ENSG00000155846',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA050543'},
#  {'name': 'ESRRA',
#   'represents': 'ensembl:ENSG00000173153',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA053785'},
#  {'name': 'ESRRG',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'MAGEL2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'FYN',
#   'represents': 'ensembl:ENSG00000010810',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA023887'},
#  {'name': 'ISX',
#   'represents': 'ensembl:ENSG00000175329',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA060328'},
#  {'name': 'ANAPC13',
#   'represents': 'ensembl:ENSG00000129055',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA046114'},
#  {'name': 'NEK2',
#   'represents': 'ensembl:ENSG00000117650',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB017530'},
#  {'name': 'NSF',
#   'represents': 'ensembl:ENSG00000276262;ENSG00000073969;ENSG00000278174',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003154'},
#  {'name': 'GOSR2',
#   'represents': 'ensembl:ENSG00000108433',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA048956'},
#  {'name': 'ZSCAN31',
#   'represents': 'ensembl:ENSG00000235109',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA007124'},
#  {'name': 'TGIF1',
#   'represents': 'ensembl:ENSG00000177426',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA062160'},
#  {'name': 'ZSCAN20',
#   'represents': 'ensembl:ENSG00000121903',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA017933'},
#  {'name': 'ZNF500',
#   'represents': 'ensembl:ENSG00000103199',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA035498'},
#  {'name': 'TGIF2',
#   'represents': 'ensembl:ENSG00000118707',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA053786'},
#  {'name': 'AGAP2',
#   'represents': 'ensembl:ENSG00000135439',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA075831'},
#  {'name': 'PPRC1',
#   'represents': 'ensembl:ENSG00000148840',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA038511'},
#  {'name': 'PCDHA4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ARL5B',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ASIC1',
#   'represents': 'ensembl:ENSG00000110881',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA058870'},
#  {'name': 'SLC2A4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'FURIN',
#   'represents': 'ensembl:ENSG00000140564',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB009499'},
#  {'name': 'SMAD3',
#   'represents': 'ensembl:ENSG00000166949',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB008094'},
#  {'name': 'PPWD1',
#   'represents': 'ensembl:ENSG00000113593',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA019360'},
#  {'name': 'PARP12',
#   'represents': 'ensembl:ENSG00000059378',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA063872'},
#  {'name': 'RBM38',
#   'represents': 'ensembl:ENSG00000132819',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB017036'},
#  {'name': 'NDUFAF2',
#   'represents': 'ensembl:ENSG00000164182',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA048082'},
#  {'name': 'CD53',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SNAPC5',
#   'represents': 'ensembl:ENSG00000174446',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024379'},
#  {'name': 'WAC',
#   'represents': 'ensembl:ENSG00000095787',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042609'},
#  {'name': 'SNTB1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SNTA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'UGCG',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CALR',
#   'represents': 'ensembl:ENSG00000179218',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB079775'},
#  {'name': 'WSB1',
#   'represents': 'ensembl:ENSG00000109046',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003293'},
#  {'name': 'GPR75-ASB3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TULP4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ASB7',
#   'represents': 'ensembl:ENSG00000183475',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003300'},
#  {'name': 'RAB40C',
#   'represents': 'ensembl:ENSG00000197562',
#   'ambiguous': 'ENSG00000102128,ENSG00000141542,ENSG00000172476,ENSG00000197562',
#   'bait': False,
#   'antibody': 'HPA076172'},
#  {'name': 'PCMTD1',
#   'represents': 'ensembl:ENSG00000168300',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA061444'},
#  {'name': 'SOCS4',
#   'represents': 'ensembl:ENSG00000180008',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA057961'},
#  {'name': 'SOCS5',
#   'represents': 'ensembl:ENSG00000171150',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA020884'},
#  {'name': 'SOCS6',
#   'represents': 'ensembl:ENSG00000170677',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB010189'},
#  {'name': 'SOCS7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'LARS2',
#   'represents': 'ensembl:ENSG00000011376',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA066085'},
#  {'name': 'NF2',
#   'represents': 'ensembl:ENSG00000186575',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003097'},
#  {'name': 'MSN',
#   'represents': 'ensembl:ENSG00000147065',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA011135'},
#  {'name': 'EZR',
#   'represents': 'ensembl:ENSG00000092820',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB004035'},
#  {'name': 'RDX',
#   'represents': 'ensembl:ENSG00000137710',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA000763'},
#  {'name': 'GRAMD4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'UBXN8',
#   'represents': 'ensembl:ENSG00000104691',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA077538'},
#  {'name': 'ZNF729',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ZNF74',
#   'represents': 'ensembl:ENSG00000185252',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA003354'},
#  {'name': 'SYTL3',
#   'represents': 'ensembl:ENSG00000164674',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA030586'},
#  {'name': 'IKBKE',
#   'represents': 'ensembl:ENSG00000263528',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB025983'},
#  {'name': 'PRDX1',
#   'represents': 'ensembl:ENSG00000117450',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA007730'},
#  {'name': 'PRDX3',
#   'represents': 'ensembl:ENSG00000165672',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA063551'},
#  {'name': 'TLN2',
#   'represents': 'ensembl:ENSG00000171914',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB017194'},
#  {'name': 'TLN1',
#   'represents': 'ensembl:ENSG00000137076',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA004748'},
#  {'name': 'KANK4',
#   'represents': 'ensembl:ENSG00000132854',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA014030'},
#  {'name': 'CSTF1',
#   'represents': 'ensembl:ENSG00000101138',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB019270'},
#  {'name': 'FGF17',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TXLNG',
#   'represents': 'ensembl:ENSG00000086712',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA000841'},
#  {'name': 'NACA2',
#   'represents': 'ensembl:ENSG00000253506',
#   'ambiguous': 'ENSG00000196531,ENSG00000253506',
#   'bait': False,
#   'antibody': 'HPA073648'},
#  {'name': 'TXLNA',
#   'represents': 'ensembl:ENSG00000084652',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA045383'},
#  {'name': 'BTF3L4',
#   'represents': 'ensembl:ENSG00000134717',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA067026'},
#  {'name': 'SOHLH1',
#   'represents': 'ensembl:ENSG00000165643',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA059439'},
#  {'name': 'APOL2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'HLA-F',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ITGB3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ATPAF2',
#   'represents': 'ensembl:ENSG00000171953',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA023329'},
#  {'name': 'ATPAF1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ATP5ME',
#   'represents': 'ensembl:ENSG00000169020',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA035010'},
#  {'name': 'ATP5PO',
#   'represents': 'ensembl:ENSG00000241837',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB016209'},
#  {'name': 'ATP5F1C',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'MAFF',
#   'represents': 'ensembl:ENSG00000185022',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA055371'},
#  {'name': 'CREBZF',
#   'represents': 'ensembl:ENSG00000137504',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA063652'},
#  {'name': 'MAGEE1',
#   'represents': 'ensembl:ENSG00000198934',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003047'},
#  {'name': 'MAFG',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'RTN4R',
#   'represents': 'ensembl:ENSG00000040608',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB012443'},
#  {'name': 'ASIC4',
#   'represents': 'ensembl:ENSG00000072182',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA036042'},
#  {'name': 'LIMS1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'RSU1',
#   'represents': 'ensembl:ENSG00000148484',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA025927'},
#  {'name': 'SLC2A14',
#   'represents': 'ensembl:ENSG00000173262',
#   'ambiguous': 'ENSG00000059804,ENSG00000173262',
#   'bait': False,
#   'antibody': 'HPA006539'},
#  {'name': 'SLC2A3',
#   'represents': 'ensembl:ENSG00000059804',
#   'ambiguous': 'ENSG00000059804,ENSG00000173262',
#   'bait': True,
#   'antibody': 'HPA006539'},
#  {'name': 'CPEB4',
#   'represents': 'ensembl:ENSG00000113742',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA038394'},
#  {'name': 'HOMEZ',
#   'represents': 'ensembl:ENSG00000290292',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA036316'},
#  {'name': 'UBE2I',
#   'represents': 'ensembl:ENSG00000103275',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB079920'},
#  {'name': 'SUMO1',
#   'represents': 'ensembl:ENSG00000116030',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA056956'},
#  {'name': 'RAN',
#   'represents': 'ensembl:ENSG00000132341',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA063353'},
#  {'name': 'HNRNPM',
#   'represents': 'ensembl:ENSG00000099783',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024344'},
#  {'name': 'SGCE',
#   'represents': 'ensembl:ENSG00000127990',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA074790'},
#  {'name': 'TGOLN2',
#   'represents': 'ensembl:ENSG00000152291',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA012723'},
#  {'name': 'DBF4B',
#   'represents': 'ensembl:ENSG00000161692',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA048465'},
#  {'name': 'SPARC',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'VAMP5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'FAN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'MLH3',
#   'represents': 'ensembl:ENSG00000119684',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA060570'},
#  {'name': 'HPS4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ALAD',
#   'represents': 'ensembl:ENSG00000148218',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA021023'},
#  {'name': 'ARHGEF35',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'DDX47',
#   'represents': 'ensembl:ENSG00000213782',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA014855'},
#  {'name': 'SLIRP',
#   'represents': 'ensembl:ENSG00000119705',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA020291'},
#  {'name': 'KIF22',
#   'represents': 'ensembl:ENSG00000079616',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA048213'},
#  {'name': 'GGNBP2',
#   'represents': 'ensembl:ENSG00000278311;ENSG00000275099',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA073392'},
#  {'name': 'TAPT1',
#   'represents': 'ensembl:ENSG00000169762',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042567'},
#  {'name': 'ESD',
#   'represents': 'ensembl:ENSG00000139684',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA039700'},
#  {'name': 'FSD2',
#   'represents': 'ensembl:ENSG00000186628',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA046263'},
#  {'name': 'PNRC2',
#   'represents': 'ensembl:ENSG00000189266',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA045837'},
#  {'name': 'FAM185A',
#   'represents': 'ensembl:ENSG00000222011',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA029883'},
#  {'name': 'NDUFA6',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'NDUFB7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'NDUFB4',
#   'represents': 'ensembl:ENSG00000065518',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA051739'},
#  {'name': 'NDUFS5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'KIAA0753',
#   'represents': 'ensembl:ENSG00000198920',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA023494'},
#  {'name': 'KERA',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TXNL1',
#   'represents': 'ensembl:ENSG00000091164',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA002828'},
#  {'name': 'PSMD3',
#   'represents': 'ensembl:ENSG00000108344',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB017038'},
#  {'name': 'GNG2',
#   'represents': 'ensembl:ENSG00000186469',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA003534'},
#  {'name': 'FBLN2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'NTN5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'LRWD1',
#   'represents': 'ensembl:ENSG00000161036',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA021320'},
#  {'name': 'NEDD8',
#   'represents': 'ensembl:ENSG00000129559;ENSG00000285246',
#   'ambiguous': 'ENSG00000129559,ENSG00000255526',
#   'bait': False,
#   'antibody': 'HPA060254'},
#  {'name': 'KISS1',
#   'represents': 'ensembl:ENSG00000170498',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA035542'},
#  {'name': 'PPP2R5B',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SET',
#   'represents': 'ensembl:ENSG00000119335',
#   'ambiguous': 'ENSG00000119335,ENSG00000230667',
#   'bait': False,
#   'antibody': 'HPA063683'},
#  {'name': 'SETSIP',
#   'represents': 'ensembl:ENSG00000230667',
#   'ambiguous': 'ENSG00000119335,ENSG00000230667',
#   'bait': False,
#   'antibody': 'HPA063683'},
#  {'name': 'ZDHHC18',
#   'represents': 'ensembl:ENSG00000204160',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA040234'},
#  {'name': 'SPNS1',
#   'represents': 'ensembl:ENSG00000169682',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041995'},
#  {'name': 'SLC20A2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TMEM169',
#   'represents': 'ensembl:ENSG00000163449',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA070657'},
#  {'name': 'HOXD4',
#   'represents': 'ensembl:ENSG00000170166',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA070349'},
#  {'name': 'ANKMY2',
#   'represents': 'ensembl:ENSG00000106524',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA067100'},
#  {'name': 'ADCY9',
#   'represents': 'ensembl:ENSG00000162104',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA041328'},
#  {'name': 'ZNF407',
#   'represents': 'ensembl:ENSG00000215421',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041673'},
#  {'name': 'CHRDL1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ZNF354C',
#   'represents': 'ensembl:ENSG00000177932',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA068570'},
#  {'name': 'ZNF672',
#   'represents': 'ensembl:ENSG00000171161',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA055779'},
#  {'name': 'NTN1',
#   'represents': 'ensembl:ENSG00000065320',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056419'},
#  {'name': 'ZNF324',
#   'represents': 'ensembl:ENSG00000083812',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA039774'},
#  {'name': 'CCN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ITFG2',
#   'represents': 'ensembl:ENSG00000111203',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA074606'},
#  {'name': 'VWCE',
#   'represents': 'ensembl:ENSG00000167992',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA043921'},
#  {'name': 'ZDHHC7',
#   'represents': 'ensembl:ENSG00000153786',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA059642'},
#  {'name': 'PRKDC',
#   'represents': 'ensembl:ENSG00000253729',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA035174'},
#  {'name': 'EPHA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'KRBA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'ESYT1',
#   'represents': 'ensembl:ENSG00000139641',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA076926'},
#  {'name': 'ALPK2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'NHLH2',
#   'represents': 'ensembl:ENSG00000177551',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA055238'},
#  {'name': 'SCO2',
#   'represents': 'ensembl:ENSG00000284194',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA046943'},
#  {'name': 'GRAMD1B',
#   'represents': 'ensembl:ENSG00000023171',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA075204'},
#  {'name': 'PHF2',
#   'represents': 'ensembl:ENSG00000197724',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA010831'},
#  {'name': 'ZC3HAV1',
#   'represents': 'ensembl:ENSG00000105939',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA059096'},
#  {'name': 'ULBP3',
#   'represents': 'ensembl:ENSG00000131019',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056541'},
#  {'name': 'TNFSF8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'VMA21',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'NFE2L3',
#   'represents': 'ensembl:ENSG00000050344',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA055889'},
#  {'name': 'ZNF467',
#   'represents': 'ensembl:ENSG00000181444',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA042907'},
#  {'name': 'ACSF3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SNX19',
#   'represents': 'ensembl:ENSG00000120451',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA013447'},
#  {'name': 'FZD10',
#   'represents': 'ensembl:ENSG00000111432',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA014485'},
#  {'name': 'NUDT8',
#   'represents': 'ensembl:ENSG00000167799',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041252'},
#  {'name': 'DNAJC15',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'RNF167',
#   'represents': 'ensembl:ENSG00000108523',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA049810'},
#  {'name': 'HIGD2A',
#   'represents': 'ensembl:ENSG00000146066',
#   'ambiguous': 'ENSG00000146066,ENSG00000175202',
#   'bait': False,
#   'antibody': 'HPA042715'},
#  {'name': 'AIFM2',
#   'represents': 'ensembl:ENSG00000042286',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA075576'},
#  {'name': 'C3orf33',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SLC27A4',
#   'represents': 'ensembl:ENSG00000167114',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA007293'},
#  {'name': 'PTGIS',
#   'represents': 'ensembl:ENSG00000124212',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA052244'},
#  {'name': 'MGAT2',
#   'represents': 'ensembl:ENSG00000168282',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056824'},
#  {'name': 'ALDH3A2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'EPHA2',
#   'represents': 'ensembl:ENSG00000142627',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB010464'},
#  {'name': 'EI24',
#   'represents': 'ensembl:ENSG00000149547',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA051029'},
#  {'name': 'SSBP1',
#   'represents': 'ensembl:ENSG00000262771;ENSG00000106028',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA002866'},
#  {'name': 'CLEC4C',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'STOML2',
#   'represents': 'ensembl:ENSG00000165283',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB015944'},
#  {'name': 'DUOXA2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'DDR2',
#   'represents': 'ensembl:ENSG00000162733',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA070112'},
#  {'name': 'LRRC52',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'DAZAP1',
#   'represents': 'ensembl:ENSG00000071626',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA004201'},
#  {'name': 'LRRC73',
#   'represents': 'ensembl:ENSG00000204052',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA046698'},
#  {'name': 'FBXO16',
#   'represents': 'ensembl:ENSG00000214050',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA058676'},
#  {'name': 'TBC1D22B',
#   'represents': 'ensembl:ENSG00000065491',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA027910'},
#  {'name': 'TUBB6',
#   'represents': 'ensembl:ENSG00000176014',
#   'ambiguous': 'ENSG00000101162,ENSG00000104833,ENSG00000137267,ENSG00000137285,ENSG00000173213,ENSG00000176014,ENSG00000188229,ENSG00000196230,ENSG00000198211,ENSG00000258947,ENSG00000261456',
#   'bait': False,
#   'antibody': 'HPA046280'},
#  {'name': 'KPNB1',
#   'represents': 'ensembl:ENSG00000108424',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA029878'},
#  {'name': 'TUBA1B',
#   'represents': 'ensembl:ENSG00000123416',
#   'ambiguous': 'ENSG00000075886,ENSG00000123416,ENSG00000127824,ENSG00000152086,ENSG00000167552,ENSG00000167553,ENSG00000183785,ENSG00000198033',
#   'bait': False,
#   'antibody': 'HPA043684'},
#  {'name': 'RCBTB2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CD80',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'LHFPL2',
#   'represents': 'ensembl:ENSG00000145685',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA076743'},
#  {'name': 'DOP1B',
#   'represents': 'ensembl:ENSG00000142197',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA072065'},
#  {'name': 'AP5S1',
#   'represents': 'ensembl:ENSG00000125843',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA048244'},
#  {'name': 'GBA2',
#   'represents': 'ensembl:ENSG00000070610',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024026'},
#  {'name': 'EVI5L',
#   'represents': 'ensembl:ENSG00000142459',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA043563'},
#  {'name': 'ATRIP',
#   'represents': 'ensembl:ENSG00000164053',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA047590'},
#  {'name': 'XPOT',
#   'represents': 'ensembl:ENSG00000184575',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA048067'},
#  {'name': 'PPP1R12A',
#   'represents': 'ensembl:ENSG00000058272',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041296'},
#  {'name': 'SLC2A12',
#   'represents': 'ensembl:ENSG00000146411',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA031593'},
#  {'name': 'TAF7L',
#   'represents': 'ensembl:ENSG00000102387',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA072008'},
#  {'name': 'TBC1D32',
#   'represents': 'ensembl:ENSG00000146350',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA013413'},
#  {'name': 'FOXJ1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'GTF3C4',
#   'represents': 'ensembl:ENSG00000125484',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA069369'},
#  {'name': 'BAZ1A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'RRP36',
#   'represents': 'ensembl:ENSG00000124541',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA029905'},
#  {'name': 'KDM8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'EIF2S3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'EIF2S2',
#   'represents': 'ensembl:ENSG00000125977',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041262'},
#  {'name': 'LRRC27',
#   'represents': 'ensembl:ENSG00000148814',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA037595'},
#  {'name': 'MILR1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'ABCE1',
#   'represents': 'ensembl:ENSG00000164163',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA036846'},
#  {'name': 'LTO1',
#   'represents': 'ensembl:ENSG00000149716',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA062696'},
#  {'name': 'ZNF784',
#   'represents': 'ensembl:ENSG00000179922',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA059676'},
#  {'name': 'MAPK11',
#   'represents': 'ensembl:ENSG00000185386',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA073133'},
#  {'name': 'MPP1',
#   'represents': 'ensembl:ENSG00000130830',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA076675'},
#  {'name': 'DPY19L3',
#   'represents': 'ensembl:ENSG00000178904',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA008325'},
#  {'name': 'TEX261',
#   'represents': 'ensembl:ENSG00000144043',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA016631'},
#  {'name': 'MEN1',
#   'represents': 'ensembl:ENSG00000133895',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA030342'},
#  {'name': 'CD226',
#   'represents': 'ensembl:ENSG00000150637',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA015865'},
#  {'name': 'MICB',
#   'represents': 'ensembl:ENSG00000234218;ENSG00000224378;ENSG00000206449;ENSG00000204516;ENSG00000231372;ENSG00000227772;ENSG00000231179;ENSG00000238289',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA064618'},
#  {'name': 'ZAR1L',
#   'represents': 'ensembl:ENSG00000189167',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA039540'},
#  {'name': 'HFE',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SMURF1',
#   'represents': 'ensembl:ENSG00000198742;ENSG00000284126',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA019671'},
#  {'name': 'ZNF114',
#   'represents': 'ensembl:ENSG00000178150',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA025019'},
#  {'name': 'PROCR',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'DPP7',
#   'represents': 'ensembl:ENSG00000176978',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA059381'},
#  {'name': 'TMEM30A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SLAMF7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SIAE',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ABCA2',
#   'represents': 'ensembl:ENSG00000107331',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042886'},
#  {'name': 'HM13',
#   'represents': 'ensembl:ENSG00000101294',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056062'},
#  {'name': 'LARGE2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'DPY19L4',
#   'represents': 'ensembl:ENSG00000156162',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024780'},
#  {'name': 'GALNT18',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'KLHL40',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'MXRA7',
#   'represents': 'ensembl:ENSG00000182534',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA044819'},
#  {'name': 'CXADR',
#   'represents': 'ensembl:ENSG00000154639',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB005103'},
#  {'name': 'ITGA3',
#   'represents': 'ensembl:ENSG00000005884',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB018594'},
#  {'name': 'SMPD1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ITGB1',
#   'represents': 'ensembl:ENSG00000150093',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB003434'},
#  {'name': 'TLR3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'OSTM1',
#   'represents': 'ensembl:ENSG00000081087',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA010851'},
#  {'name': 'HSP90B1',
#   'represents': 'ensembl:ENSG00000166598',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003901'},
#  {'name': 'C9orf40',
#   'represents': 'ensembl:ENSG00000135045',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA042167'},
#  {'name': 'NR1D1',
#   'represents': 'ensembl:ENSG00000126368',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA007935'},
#  {'name': 'RTN4',
#   'represents': 'ensembl:ENSG00000115310',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA023977'},
#  {'name': 'RTN1',
#   'represents': 'ensembl:ENSG00000139970',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA040945'},
#  {'name': 'RTKN2',
#   'represents': 'ensembl:ENSG00000182010',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA037946'},
#  {'name': 'COPG1',
#   'represents': 'ensembl:ENSG00000181789',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA037866'},
#  {'name': 'STXBP4',
#   'represents': 'ensembl:ENSG00000166263',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA022888'},
#  {'name': 'RHPN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'ADGRL3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ZNF274',
#   'represents': 'ensembl:ENSG00000171606',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA028880'},
#  {'name': 'ACSF2',
#   'represents': 'ensembl:ENSG00000167107',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA024693'},
#  {'name': 'CEP295',
#   'represents': 'ensembl:ENSG00000166004',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA038596'},
#  {'name': 'UNC13B',
#   'represents': 'ensembl:ENSG00000198722',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024493'},
#  {'name': 'CEP72',
#   'represents': 'ensembl:ENSG00000112877;ENSG00000280688',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA074879'},
#  {'name': 'ZNF622',
#   'represents': 'ensembl:ENSG00000173545',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA036515'},
#  {'name': 'RNASEH2C',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'PLCB2',
#   'represents': 'ensembl:ENSG00000137841',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041298'},
#  {'name': 'SYT16',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'GUF1',
#   'represents': 'ensembl:ENSG00000151806',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024222'},
#  {'name': 'GLUD2',
#   'represents': 'ensembl:ENSG00000182890;ENSG00000288118',
#   'ambiguous': 'ENSG00000148672,ENSG00000182890',
#   'bait': False,
#   'antibody': 'HPA044839'},
#  {'name': 'GLUD1',
#   'represents': 'ensembl:ENSG00000148672',
#   'ambiguous': 'ENSG00000148672,ENSG00000182890',
#   'bait': False,
#   'antibody': 'HPA044839'},
#  {'name': 'PARN',
#   'represents': 'ensembl:ENSG00000140694;ENSG00000274829',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA006314'},
#  {'name': 'PIGB',
#   'represents': 'ensembl:ENSG00000069943',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA039929'},
#  {'name': 'GLRB',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'GABRB3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CYTH1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CCDC120',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SLC46A1',
#   'represents': 'ensembl:ENSG00000076351',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB011614'},
#  {'name': 'STX10',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'STX16',
#   'represents': 'ensembl:ENSG00000124222',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041019'},
#  {'name': 'KCTD15',
#   'represents': 'ensembl:ENSG00000153885',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042522'},
#  {'name': 'BCHE',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'KBTBD8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TMPRSS13',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'WDR12',
#   'represents': 'ensembl:ENSG00000138442',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA036389'},
#  {'name': 'DDX27',
#   'represents': 'ensembl:ENSG00000124228',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA047087'},
#  {'name': 'BOP1',
#   'represents': 'ensembl:ENSG00000285301;ENSG00000261236',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA066764'},
#  {'name': 'RBM12B',
#   'represents': 'ensembl:ENSG00000183808',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA053050'},
#  {'name': 'ZNF276',
#   'represents': 'ensembl:ENSG00000158805',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA021309'},
#  {'name': 'BLMH',
#   'represents': 'ensembl:ENSG00000108578',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA039548'},
#  {'name': 'CCT8L2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SLC41A3',
#   'represents': 'ensembl:ENSG00000114544',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA045847'},
#  {'name': 'RBM8A',
#   'represents': 'ensembl:ENSG00000265241',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA018403'},
#  {'name': 'NOP16',
#   'represents': 'ensembl:ENSG00000048162',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA036506'},
#  {'name': 'MAGOHB',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'RPS15',
#   'represents': 'ensembl:ENSG00000115268',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA054510'},
#  {'name': 'RPS16',
#   'represents': 'ensembl:ENSG00000105193',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA064222'},
#  {'name': 'RPS5',
#   'represents': 'ensembl:ENSG00000083845',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA055878'},
#  {'name': 'RPS17',
#   'represents': 'ensembl:ENSG00000182774;ENSG00000278229',
#   'ambiguous': 'ENSG00000182774,ENSG00000260836',
#   'bait': False,
#   'antibody': 'HPA055060'},
#  {'name': 'ABLIM2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'IFNAR1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'LOXL1',
#   'represents': 'ensembl:ENSG00000129038',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA063583'},
#  {'name': 'P4HB',
#   'represents': 'ensembl:ENSG00000185624',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA018884'},
#  {'name': 'CHP1',
#   'represents': 'ensembl:ENSG00000187446',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA006616'},
#  {'name': 'MFF',
#   'represents': 'ensembl:ENSG00000168958',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA074625'},
#  {'name': 'TMEM209',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SLC25A3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SLC25A5',
#   'represents': 'ensembl:ENSG00000005022',
#   'ambiguous': 'ENSG00000005022,ENSG00000151475,ENSG00000151729,ENSG00000169100',
#   'bait': False,
#   'antibody': 'HPA046835'},
#  {'name': 'SLC1A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'UGGT1',
#   'represents': 'ensembl:ENSG00000136731',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA015127'},
#  {'name': 'ALG9',
#   'represents': 'ensembl:ENSG00000086848',
#   'ambiguous': 'ENSG00000086848,ENSG00000258529',
#   'bait': False,
#   'antibody': 'HPA038575'},
#  {'name': 'TMUB1',
#   'represents': 'ensembl:ENSG00000164897',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA029429'},
#  {'name': 'CGRRF1',
#   'represents': 'ensembl:ENSG00000100532',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA002930'},
#  {'name': 'SLC38A2',
#   'represents': 'ensembl:ENSG00000134294',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA069672'},
#  {'name': 'SLC25A46',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'KCNJ8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ABCG1',
#   'represents': 'ensembl:ENSG00000160179',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA031470'},
#  {'name': 'ADGRG5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'GDAP2',
#   'represents': 'ensembl:ENSG00000196505',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA046185'},
#  {'name': 'MYO10',
#   'represents': 'ensembl:ENSG00000145555',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA024223'},
#  {'name': 'HNRNPA3',
#   'represents': 'ensembl:ENSG00000170144',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA066381'},
#  {'name': 'CDC34',
#   'represents': 'ensembl:ENSG00000099804',
#   'ambiguous': 'ENSG00000099804,ENSG00000107341',
#   'bait': False,
#   'antibody': 'HPA074334'},
#  {'name': 'HNRNPA2B1',
#   'represents': 'ensembl:ENSG00000122566',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB012403'},
#  {'name': 'HNRNPL',
#   'represents': 'ensembl:ENSG00000104824;ENSG00000282947',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA052661'},
#  {'name': 'HNRNPR',
#   'represents': 'ensembl:ENSG00000125944;ENSG00000282958',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA026092'},
#  {'name': 'HNRNPDL',
#   'represents': 'ensembl:ENSG00000152795',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056820'},
#  {'name': 'RIOX1',
#   'represents': 'ensembl:ENSG00000170468',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003730'},
#  {'name': 'RPLP2',
#   'represents': 'ensembl:ENSG00000177600',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA075365'},
#  {'name': 'ZSCAN5A',
#   'represents': 'ensembl:ENSG00000131848',
#   'ambiguous': 'ENSG00000131848,ENSG00000197213,ENSG00000204532',
#   'bait': True,
#   'antibody': 'HPA060667'},
#  {'name': 'GDF5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CTTN',
#   'represents': 'ensembl:ENSG00000085733;ENSG00000288401',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA057242'},
#  {'name': 'MPLKIP',
#   'represents': 'ensembl:ENSG00000168303',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA065463'},
#  {'name': 'CCNJ',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'GCN1',
#   'represents': 'ensembl:ENSG00000089154',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA018799'},
#  {'name': 'GPD1L',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ORC5',
#   'represents': 'ensembl:ENSG00000164815',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA019730'},
#  {'name': 'XPO1',
#   'represents': 'ensembl:ENSG00000082898',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042933'},
#  {'name': 'UMAD1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SCN2B',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CDS1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CDS2',
#   'represents': 'ensembl:ENSG00000101290',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA019698'},
#  {'name': 'DBF4',
#   'represents': 'ensembl:ENSG00000006634',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042923'},
#  {'name': 'IWS1',
#   'represents': 'ensembl:ENSG00000163166',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA061866'},
#  {'name': 'CDCA7L',
#   'represents': 'ensembl:ENSG00000164649',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA027169'},
#  {'name': 'ANKRD11',
#   'represents': 'ensembl:ENSG00000167522',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041593'},
#  {'name': 'GRK6',
#   'represents': 'ensembl:ENSG00000198055',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA018903'},
#  {'name': 'CAVIN2',
#   'represents': 'ensembl:ENSG00000168497',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA039325'},
#  {'name': 'BANF1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CHRNA3',
#   'represents': 'ensembl:ENSG00000080644',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA029430'},
#  {'name': 'RBCK1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CLTA',
#   'represents': 'ensembl:ENSG00000122705',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB002665'},
#  {'name': 'ZNF223',
#   'represents': 'ensembl:ENSG00000178386',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA067823'},
#  {'name': 'SLC18A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CLPP',
#   'represents': 'ensembl:ENSG00000125656',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA010649'},
#  {'name': 'SLC49A4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'GMCL1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SLC35F2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TMEM65',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'GJC1',
#   'represents': 'ensembl:ENSG00000182963',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA014005'},
#  {'name': 'BSCL2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CTIF',
#   'represents': 'ensembl:ENSG00000134030;ENSG00000282825',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA016865'},
#  {'name': 'KHNYN',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'MAST4',
#   'represents': 'ensembl:ENSG00000069020',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA000544'},
#  {'name': 'PLEKHA6',
#   'represents': 'ensembl:ENSG00000143850',
#   'ambiguous': None,
#   'bait': False,
# ...
#   'antibody': 'HPA018425'},
#  {'name': 'G3BP1',
#   'represents': 'ensembl:ENSG00000145907',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA004052'},
#  {'name': 'ARHGEF5',
#   'represents': 'ensembl:ENSG00000050327;ENSG00000284933',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA020980'},
#  {'name': 'RAD1',
#   'represents': 'ensembl:ENSG00000113456',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA006692'},
#  {'name': 'HUS1B',
#   'represents': 'ensembl:ENSG00000188996',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA034511'},
#  {'name': 'CLEC12B',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'VIL1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'AVIL',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'NCR3LG1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'MPDZ',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'DTNB',
#   'represents': 'ensembl:ENSG00000138101',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA061357'},
#  {'name': 'SEC24C',
#   'represents': 'ensembl:ENSG00000176986',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA040213'},
#  {'name': 'SEC24D',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TM9SF2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'TACR1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'P2RY1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TYSND1',
#   'represents': 'ensembl:ENSG00000156521',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA030304'},
#  {'name': 'DNAAF2',
#   'represents': 'ensembl:ENSG00000165506',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA004113'},
#  {'name': 'UBE3D',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'AVPR2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'GINS1',
#   'represents': 'ensembl:ENSG00000101003',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA051185'},
#  {'name': 'EFCAB11',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'BHLHE22',
#   'represents': 'ensembl:ENSG00000180828',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA067500'},
#  {'name': 'BHLHE23',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'RFX3',
#   'represents': 'ensembl:ENSG00000080298',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA035689'},
#  {'name': 'TM7SF3',
#   'represents': 'ensembl:ENSG00000064115',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA057640'},
#  {'name': 'SCAMP4',
#   'represents': 'ensembl:ENSG00000227500',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA043284'},
#  {'name': 'TMEM104',
#   'represents': 'ensembl:ENSG00000109066',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA044330'},
#  {'name': 'KDELR2',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'KDELR1',
#   'represents': 'ensembl:ENSG00000105438',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB017455'},
#  {'name': 'GPR12',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CBX5',
#   'represents': 'ensembl:ENSG00000094916',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA016699'},
#  {'name': 'FGF11',
#   'represents': 'ensembl:ENSG00000161958;ENSG00000283903',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA066605'},
#  {'name': 'DAD1',
#   'represents': 'ensembl:ENSG00000129562',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA028882'},
#  {'name': 'HES1',
#   'represents': 'ensembl:ENSG00000114315',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA066929'},
#  {'name': 'HES6',
#   'represents': 'ensembl:ENSG00000144485',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA073997'},
#  {'name': 'NMT1',
#   'represents': 'ensembl:ENSG00000136448',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA022949'},
#  {'name': 'ACBD6',
#   'represents': 'ensembl:ENSG00000230124',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA028457'},
#  {'name': 'RPL22',
#   'represents': 'ensembl:ENSG00000116251',
#   'ambiguous': 'ENSG00000116251,ENSG00000163584',
#   'bait': True,
#   'antibody': 'HPA068294'},
#  {'name': 'SNF8',
#   'represents': 'ensembl:ENSG00000159210',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA059320'},
#  {'name': 'C19orf38',
#   'represents': 'ensembl:ENSG00000214212',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA055027'},
#  {'name': 'PHLDA3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'HPF1',
#   'represents': 'ensembl:ENSG00000056050',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA043467'},
#  {'name': 'DNAJC25',
#   'represents': 'ensembl:ENSG00000059769',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA019122'},
#  {'name': 'FOXM1',
#   'represents': 'ensembl:ENSG00000111206',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB017832'},
#  {'name': 'CTLA4',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TSPAN10',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ZNF669',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'ZNF444',
#   'represents': 'ensembl:ENSG00000167685',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056895'},
#  {'name': 'ZNF35',
#   'represents': 'ensembl:ENSG00000281306;ENSG00000169981',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA054738'},
#  {'name': 'FAM81A',
#   'represents': 'ensembl:ENSG00000157470',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA065797'},
#  {'name': 'CACYBP',
#   'represents': 'ensembl:ENSG00000116161',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA025753'},
#  {'name': 'PRKD1',
#   'represents': 'ensembl:ENSG00000184304',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA029834'},
#  {'name': 'PLCB3',
#   'represents': 'ensembl:ENSG00000149782',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB009257'},
#  {'name': 'PTPN4',
#   'represents': 'ensembl:ENSG00000088179',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA019351'},
#  {'name': 'COLGALT1',
#   'represents': 'ensembl:ENSG00000130309',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA047821'},
#  {'name': 'COL21A1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'CD28',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'PIWIL1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TDRKH',
#   'represents': 'ensembl:ENSG00000182134',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA019625'},
#  {'name': 'PIWIL4',
#   'represents': 'ensembl:ENSG00000134627',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA036587'},
#  {'name': 'CDK1',
#   'represents': 'ensembl:ENSG00000170312',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'CAB079974'},
#  {'name': 'SPDYC',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'IGFN1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'C7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TTC16',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'RALYL',
#   'represents': 'ensembl:ENSG00000184672',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA055868'},
#  {'name': 'RALY',
#   'represents': 'ensembl:ENSG00000125970',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA040971'},
#  {'name': 'ADCY5',
#   'represents': 'ensembl:ENSG00000173175',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA077682'},
#  {'name': 'CACNG5',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'PFKP',
#   'represents': 'ensembl:ENSG00000067057',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA056484'},
#  {'name': 'EML4',
#   'represents': 'ensembl:ENSG00000143924',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA036688'},
#  {'name': 'CREB1',
#   'represents': 'ensembl:ENSG00000118260',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA019150'},
#  {'name': 'H1-7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'IL12A',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SCLT1',
#   'represents': 'ensembl:ENSG00000151466',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA036561'},
#  {'name': 'KIZ',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'SLC39A12',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'LIMK1',
#   'represents': 'ensembl:ENSG00000106683',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA028516'},
#  {'name': 'WDR11',
#   'represents': 'ensembl:ENSG00000120008',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA038980'},
#  {'name': 'HNRNPH1',
#   'represents': 'ensembl:ENSG00000169045;ENSG00000284254',
#   'ambiguous': 'ENSG00000126945,ENSG00000169045',
#   'bait': False,
#   'antibody': 'HPA000914'},
#  {'name': 'PMEL',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'TAF4B',
#   'represents': 'ensembl:ENSG00000141384',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA028937'},
#  {'name': 'DYNLT4',
#   'represents': 'ensembl:ENSG00000188396',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA050116'},
#  {'name': 'SPATA25',
#   'represents': 'ensembl:ENSG00000149634',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA041386'},
#  {'name': 'RPS6KA6',
#   'represents': 'ensembl:ENSG00000072133',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA003904'},
#  {'name': 'ZNF106',
#   'represents': 'ensembl:ENSG00000103994',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA054267'},
#  {'name': 'RP9',
#   'represents': 'ensembl:ENSG00000164610',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA050778'},
#  {'name': 'SMG6',
#   'represents': 'ensembl:ENSG00000070366',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA042932'},
#  {'name': 'EIF3J',
#   'represents': 'ensembl:ENSG00000104131',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA050977'},
#  {'name': 'NMT2',
#   'represents': 'ensembl:ENSG00000152465',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA001303'},
#  {'name': 'IFNA7',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'IFNA14',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'PXDC1',
#   'represents': 'ensembl:ENSG00000168994',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA019246'},
#  {'name': 'APBA1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'IFNA8',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'RNF138',
#   'represents': 'ensembl:ENSG00000134758',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA041101'},
#  {'name': 'COA6',
#   'represents': 'ensembl:ENSG00000168275',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA028588'},
#  {'name': 'SNAPC1',
#   'represents': 'ensembl:ENSG00000023608',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA067076'},
#  {'name': 'NAP1L5',
#   'represents': 'ensembl:ENSG00000177432',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA058227'},
#  {'name': 'PRICKLE2',
#   'represents': 'ensembl:ENSG00000163637',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA035493'},
#  {'name': 'ADCYAP1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'EXOSC7',
#   'represents': 'ensembl:ENSG00000075914',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA057980'},
#  {'name': 'ZNF398',
#   'represents': 'ensembl:ENSG00000197024',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA073151'},
#  {'name': 'TCF20',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CFDP1',
#   'represents': 'ensembl:ENSG00000153774',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA048242'},
#  {'name': 'MRE11',
#   'represents': 'ensembl:ENSG00000020922',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA002691'},
#  {'name': 'FAM219A',
#   'represents': 'ensembl:ENSG00000164970',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA019338'},
#  {'name': 'LECT2',
#   'represents': 'ensembl:ENSG00000145826',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA058246'},
#  {'name': 'POLR2I',
#   'represents': 'ensembl:ENSG00000105258',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA045156'},
#  {'name': 'FNBP4',
#   'represents': 'ensembl:ENSG00000285182;ENSG00000109920',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA039485'},
#  {'name': 'IRF9',
#   'represents': 'ensembl:ENSG00000213928;ENSG00000285048',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA001862'},
#  {'name': 'STAT1',
#   'represents': 'ensembl:ENSG00000115415',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA000931'},
#  {'name': 'BCS1L',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'FIBCD1',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'CDC6',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'PCDH20',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'KLHL36',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'GPAT3',
#   'represents': None,
#   'ambiguous': None,
#   'bait': False,
#   'antibody': None},
#  {'name': 'SLC6A15',
#   'represents': 'ensembl:ENSG00000072041',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA008609'},
#  {'name': 'SERF2',
#   'represents': 'ensembl:ENSG00000140264',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA056613'},
#  {'name': 'SUPT16H',
#   'represents': 'ensembl:ENSG00000092201',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA049787'},
#  {'name': 'CCDC82',
#   'represents': 'ensembl:ENSG00000149231',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA070631'},
#  {'name': 'MCM2',
#   'represents': 'ensembl:ENSG00000073111',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA031496'},
#  {'name': 'L3MBTL1',
#   'represents': 'ensembl:ENSG00000185513',
#   'ambiguous': 'ENSG00000185513,ENSG00000288000',
#   'bait': True,
#   'antibody': 'HPA059648'},
#  {'name': 'LRRN2',
#   'represents': 'ensembl:ENSG00000170382',
#   'ambiguous': None,
#   'bait': True,
#   'antibody': 'HPA029124'},
#  {'name': 'LAS1L',
#   'represents': 'ensembl:ENSG00000001497',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA044431'},
#  {'name': 'SENP3',
#   'represents': 'ensembl:ENSG00000161956',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA060290'},
#  {'name': 'NOL9',
#   'represents': None,
#   'ambiguous': None,
#   'bait': True,
#   'antibody': None},
#  {'name': 'HEBP1',
#   'represents': 'ensembl:ENSG00000013583',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA075277'},
#  {'name': 'RPEL1',
#   'represents': 'ensembl:ENSG00000235376',
#   'ambiguous': 'ENSG00000197713,ENSG00000235376',
#   'bait': False,
#   'antibody': 'HPA036499'},
#  {'name': 'YARS1',
#   'represents': 'ensembl:ENSG00000134684',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA018954'},
#  {'name': 'USP5',
#   'represents': 'ensembl:ENSG00000111667',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA006756'},
#  {'name': 'ASNS',
#   'represents': 'ensembl:ENSG00000070669',
#   'ambiguous': None,
#   'bait': False,
#   'antibody': 'HPA004924'},
#  ...]

# %%
def get_apms_edgelist (nice_cx, node_attrs_list):

    node_attrs_by_id = {}
    for _, row in node_attrs_list.iterrows():
        node_attrs_by_id[row['node_id']] = row.to_dict()

    edges = nice_cx.edges
    edge_attrs = nice_cx.edgeAttributes

    attr_by_edge_id = defaultdict(dict)
    for edge_id, attr_list in edge_attrs.items():
        for attr in attr_list:
            attr_name = attr['n']
            attr_value = attr['v']
            if attr_name == 'name':
                continue
            attr_by_edge_id[edge_id][attr_name] = attr_value

    edge_list = []
    for edge_id, edge_data in edges.items():
        source = edge_data.get('s')
        target = edge_data.get('t')

        source_info = node_attrs_by_id.get(source, {})
        target_info = node_attrs_by_id.get(target, {})

        #ensembl1_raw = source_info.get('represents')
        #ensembl1 = ensembl1_raw[len('ensembl:'):] if ensembl1_raw and ensembl1_raw.startswith('ensembl:') else ensembl1_raw

        #ensembl2_raw = target_info.get('represents')
        #ensembl2 = ensembl2_raw[len('ensembl:'):] if ensembl2_raw and ensembl2_raw.startswith('ensembl:') else ensembl2_raw

        edge_dict = {
            'geneA': str(source_info.get('node_id')), 
            'symbolA': source_info.get('name'),
            #'ensemblA': ensembl1,
            'geneB': str(target_info.get('node_id')),
            'symbolB': target_info.get('name'),
            #'ensemblB': ensembl2,
        }

        edge_dict.update(attr_by_edge_id.get(edge_id, {}))
        edge_list.append(edge_dict)
    

    return edge_list

# %%
apms_edgelist = get_apms_edgelist(nice_cx, nodes_comb)

# %%
apms_edgelist
# Out:
# [{'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '551222',
#   'symbolB': 'SLC30A1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '568644',
#   'symbolB': 'TNPO3'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '553938',
#   'symbolB': 'SLC12A4'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '552516',
#   'symbolB': 'MYO6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '551198',
#   'symbolB': 'SLC39A10'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555820',
#   'symbolB': 'SLC12A6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555224',
#   'symbolB': 'VPS18'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '548774',
#   'symbolB': 'TMEM160'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555242',
#   'symbolB': 'CUEDC1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555116',
#   'symbolB': 'CYRIB'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '562860',
#   'symbolB': 'UFSP2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '568212',
#   'symbolB': 'FIRRM'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '567094',
#   'symbolB': 'CNNM1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '582816',
#   'symbolB': 'ATP13A3'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '570926',
#   'symbolB': 'PCNX3'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '551490',
#   'symbolB': 'LRRC1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '552738',
#   'symbolB': 'OSMR'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555414',
#   'symbolB': 'CCDC115'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '610744',
#   'symbolB': 'GLMN'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '557614',
#   'symbolB': 'PIEZO1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '588718',
#   'symbolB': 'TRPM4'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '602580',
#   'symbolB': 'SLC30A5'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '594304',
#   'symbolB': 'RETREG2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555406',
#   'symbolB': 'TMEM199'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '561750',
#   'symbolB': 'ANKRD13A'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '576788',
#   'symbolB': 'LAPTM4B'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '559728',
#   'symbolB': 'TOM1L2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '610658',
#   'symbolB': 'SLC30A6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560984',
#   'symbolB': 'TWF2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '556314',
#   'symbolB': 'ODR4'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555742',
#   'symbolB': 'ANO6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '549416',
#   'symbolB': 'ATP6V1F'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '547914',
#   'symbolB': 'RAD23A'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560288',
#   'symbolB': 'ADGRE5'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560284',
#   'symbolB': 'HRH1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '557406',
#   'symbolB': 'PTPRF'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560254',
#   'symbolB': 'ABHD16A'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '567158',
#   'symbolB': 'MLYCD'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560220',
#   'symbolB': 'FADS1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '548290',
#   'symbolB': 'COX7A2L'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '552878',
#   'symbolB': 'IL36G'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548284',
#   'symbolB': 'BIRC6'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '579254',
#   'symbolB': 'C11orf54'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548160',
#   'symbolB': 'SDR9C7'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548156',
#   'symbolB': 'SERPINA12'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '558074',
#   'symbolB': 'P3H2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '567360',
#   'symbolB': 'C1QL4'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548148',
#   'symbolB': 'NCCRP1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '576520',
#   'symbolB': 'PLBD1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '551042',
#   'symbolB': 'KLHL22'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548124',
#   'symbolB': 'ECM1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548272',
#   'symbolB': 'BIRC2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '566024',
#   'symbolB': 'TRAF1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548268',
#   'symbolB': 'TRAF2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548080',
#   'symbolB': 'HAL'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '549486',
#   'symbolB': 'COL8A1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '567320',
#   'symbolB': 'COL5A1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548052',
#   'symbolB': 'IL1RN'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '554794',
#   'symbolB': 'SERPINB2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '547984',
#   'symbolB': 'ALOX12B'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '595416',
#   'symbolB': 'TGM5'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '602214',
#   'symbolB': 'P4HA2'},
#  {'geneA': '635680', 'symbolA': 'CYCS', 'geneB': '556120', 'symbolB': 'SIRT1'},
#  {'geneA': '635680', 'symbolA': 'CYCS', 'geneB': '564802', 'symbolB': 'FANCB'},
#  {'geneA': '635680', 'symbolA': 'CYCS', 'geneB': '564840', 'symbolB': 'ATAD2'},
#  {'geneA': '635680',
#   'symbolA': 'CYCS',
#   'geneB': '564798',
#   'symbolB': 'FAAP100'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '552470',
#   'symbolB': 'KANSL3'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '555294',
#   'symbolB': 'KANSL2'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '611544',
#   'symbolB': 'RSRC1'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '555288',
#   'symbolB': 'MCRS1'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '555276',
#   'symbolB': 'KANSL1'},
#  {'geneA': '635416', 'symbolA': 'ADD2', 'geneB': '619670', 'symbolB': 'ADD1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '579900',
#   'symbolB': 'AMDHD2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '577664',
#   'symbolB': 'MTCH1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562472',
#   'symbolB': 'SMARCAL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559142',
#   'symbolB': 'FBXL12'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553498',
#   'symbolB': 'ABHD10'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553228',
#   'symbolB': 'ABCB10'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '580860',
#   'symbolB': 'WDR54'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '547654',
#   'symbolB': 'WDR76'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '585488',
#   'symbolB': 'SLC25A32'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '619066',
#   'symbolB': 'TRIM6'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635392',
#   'symbolB': 'SLC25A39'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635388',
#   'symbolB': 'DPH1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562382',
#   'symbolB': 'ST6GALNAC5'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '588514',
#   'symbolB': 'TMEM70'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '561326',
#   'symbolB': 'TSEN34'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '596670',
#   'symbolB': 'NUDT16L1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562302',
#   'symbolB': 'AURKB'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559112',
#   'symbolB': 'FBXO17'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '596934',
#   'symbolB': 'MTMR8'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635370',
#   'symbolB': 'ANKRD9'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '558136',
#   'symbolB': 'NXPE3'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559328',
#   'symbolB': 'DCAKD'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '547228',
#   'symbolB': 'DCAF4'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562268',
#   'symbolB': 'SMCR8'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '577896',
#   'symbolB': 'CFAP251'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '618996',
#   'symbolB': 'ENDOV'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562232',
#   'symbolB': 'ARHGEF39'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553118',
#   'symbolB': 'GALNT16'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '556360',
#   'symbolB': 'PUSL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '596916',
#   'symbolB': 'KLHDC8B'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '568760',
#   'symbolB': 'MAP4K3'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '558430',
#   'symbolB': 'CTU1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '584710',
#   'symbolB': 'MAVS'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '572324',
#   'symbolB': 'SH2D5'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '624248',
#   'symbolB': 'ABLIM2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635336',
#   'symbolB': 'B3GNTL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635332',
#   'symbolB': 'WDR25'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '565496',
#   'symbolB': 'IBA57'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562094',
#   'symbolB': 'ZRANB3'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '561378',
#   'symbolB': 'HSDL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '560320',
#   'symbolB': 'PGS1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553330',
#   'symbolB': 'TAF1C'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '583700',
#   'symbolB': 'HLTF'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559006',
#   'symbolB': 'SKP2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562020',
#   'symbolB': 'DNAH14'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635312',
#   'symbolB': 'STK19'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '550834',
#   'symbolB': 'PRKACB'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635306',
#   'symbolB': 'IMPDH2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '549242',
#   'symbolB': 'NDUFC2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '552912',
#   'symbolB': 'DUSP14'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '549248',
#   'symbolB': 'NDUFB5'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '560576',
#   'symbolB': 'BCAT2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '558708',
#   'symbolB': 'MAP3K4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '593022', 'symbolB': 'ALG5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568644',
#   'symbolB': 'TNPO3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '557672',
#   'symbolB': 'PLXND1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559338',
#   'symbolB': 'PTRH2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553294', 'symbolB': 'COG6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559434',
#   'symbolB': 'EXOC6B'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '565196',
#   'symbolB': 'EXOC7'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553288', 'symbolB': 'COG5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '576286',
#   'symbolB': 'VPS51'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577682', 'symbolB': 'XPO7'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568228',
#   'symbolB': 'TUBGCP4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '555668', 'symbolB': 'NCDN'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559424',
#   'symbolB': 'ATXN10'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '575732', 'symbolB': 'SACS'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '562994',
#   'symbolB': 'ACTR10'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '548774',
#   'symbolB': 'TMEM160'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '562860',
#   'symbolB': 'UFSP2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '561852', 'symbolB': 'MDN1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '628676',
#   'symbolB': 'TBC1D22B'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '572694', 'symbolB': 'EPG5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '554336', 'symbolB': 'NEK6'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '579248', 'symbolB': 'XPO5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553280', 'symbolB': 'COG4'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '561842',
#   'symbolB': 'ZWILCH'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635242',
#   'symbolB': 'TTC12'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568200',
#   'symbolB': 'HEATR1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553206',
#   'symbolB': 'GHITM'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559332',
#   'symbolB': 'SLC25A51'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '612176',
#   'symbolB': 'CYRIA'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568196',
#   'symbolB': 'INTS2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '559416', 'symbolB': 'XPO4'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568626',
#   'symbolB': 'NUP85'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635224',
#   'symbolB': 'DCUN1D5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '616894',
#   'symbolB': 'NCAPG'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577612', 'symbolB': 'XPO6'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '580340', 'symbolB': 'SMG1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553276', 'symbolB': 'COG8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568794',
#   'symbolB': 'ELMO2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553272', 'symbolB': 'COG3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568612',
#   'symbolB': 'INTS4'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559408',
#   'symbolB': 'SAAL1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '583860',
#   'symbolB': 'ISOC1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '561410',
#   'symbolB': 'TBRG4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577602', 'symbolB': 'MUL1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '610744', 'symbolB': 'GLMN'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568598',
#   'symbolB': 'SYMPK'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635194',
#   'symbolB': 'IP6K1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '572664', 'symbolB': 'GBF1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '550736',
#   'symbolB': 'GEMIN6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572918',
#   'symbolB': 'RUFY2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553268', 'symbolB': 'COG1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580320',
#   'symbolB': 'SFXN5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580314',
#   'symbolB': 'EXOC6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '575692',
#   'symbolB': 'MROH1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '571766', 'symbolB': 'CCNY'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '558102', 'symbolB': 'SMG8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '599250',
#   'symbolB': 'DAGLB'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553000',
#   'symbolB': 'GOLM1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '571758',
#   'symbolB': 'CCNYL1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553118',
#   'symbolB': 'GALNT16'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '610962',
#   'symbolB': 'ARMC10'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '557240',
#   'symbolB': 'SLC39A11'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '557234',
#   'symbolB': 'WDFY3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '592154',
#   'symbolB': 'FAM200C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559398',
#   'symbolB': 'EXOC8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '622712',
#   'symbolB': 'SLC35F2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577548',
#   'symbolB': 'DNAAF5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '569786',
#   'symbolB': 'NLRX1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559392',
#   'symbolB': 'HEATR3'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '568578', 'symbolB': 'MON2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '567446', 'symbolB': 'SETX'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '569880', 'symbolB': 'DYM'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572634',
#   'symbolB': 'USP34'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580290',
#   'symbolB': 'NBEAL1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568166',
#   'symbolB': 'THADA'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '551840',
#   'symbolB': 'SLC30A9'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '572626', 'symbolB': 'TTI2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '558026',
#   'symbolB': 'MYORG'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '624248',
#   'symbolB': 'ABLIM2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '567964',
#   'symbolB': 'HEATR6'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '564836', 'symbolB': 'RIF1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '571612', 'symbolB': 'FRY'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '564394', 'symbolB': 'COQ5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '567786',
#   'symbolB': 'YIF1B'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572612',
#   'symbolB': 'PDS5A'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '594726',
#   'symbolB': 'PPP2R5E'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '549412',
#   'symbolB': 'ATP6AP1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '585448',
#   'symbolB': 'MSMO1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568150',
#   'symbolB': 'UBE3C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559388',
#   'symbolB': 'PPP2R5A'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '551834',
#   'symbolB': 'KIF14'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553256', 'symbolB': 'COG2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580260',
#   'symbolB': 'PPP2R5D'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568744',
#   'symbolB': 'DOCK1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '570684',
#   'symbolB': 'UBE4A'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577462', 'symbolB': 'ATR'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '593680', 'symbolB': 'MTX1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '591496',
#   'symbolB': 'PPP2R5C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580252',
#   'symbolB': 'NUP160'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '563868',
#   'symbolB': 'WASHC5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '576642', 'symbolB': 'KDSR'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553262', 'symbolB': 'COG7'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '550666',
#   'symbolB': 'GEMIN4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577442', 'symbolB': 'PEX3'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '547442', 'symbolB': 'RRP1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572592',
#   'symbolB': 'KNTC1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '568874', 'symbolB': 'MTOR'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '564380',
#   'symbolB': 'FDFT1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '556654', 'symbolB': 'ARL2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '549392',
#   'symbolB': 'ATP6V0C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '555692',
#   'symbolB': 'LGALS1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577412',
#   'symbolB': 'PEX11B'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '623164', 'symbolB': 'CDS2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '560246',
#   'symbolB': 'GOSR1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580888',
#   'symbolB': 'CCNB2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559288',
#   'symbolB': 'TSPAN9'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577392',
#   'symbolB': 'ZMPSTE24'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '551802',
#   'symbolB': 'ATP6AP2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '555532',
#   'symbolB': 'CAND2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '574636',
#   'symbolB': 'HIP1R'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '635044', 'symbolB': 'HUS1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553988',
#   'symbolB': 'EXOC3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568096',
#   'symbolB': 'RANBP6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568536',
#   'symbolB': 'GSDME'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '547422', 'symbolB': 'URB1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '554480',
#   'symbolB': 'SPAG9'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577382',
#   'symbolB': 'SLC25A17'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '620230',
#   'symbolB': 'RAD51C'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '554368', 'symbolB': 'ZW10'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '568532', 'symbolB': 'TTI1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '548464',
#   'symbolB': 'PLXNB2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568524',
#   'symbolB': 'TNPO2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '565984', 'symbolB': 'ENC1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580192',
#   'symbolB': 'EXOC5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '559360', 'symbolB': 'IPO5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '561348',
#   'symbolB': 'LGALS8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635010',
#   'symbolB': 'KCNK1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580184',
#   'symbolB': 'RIMOC1'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '548208',
#   'symbolB': 'KNSTRN'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '568452',
#   'symbolB': 'COMMD3'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '587466',
#   'symbolB': 'YIPF3'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '573642',
#   'symbolB': 'KIFC3'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '548180',
#   'symbolB': 'SPAG5'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '551576',
#   'symbolB': 'COPS6'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '564840',
#   'symbolB': 'ATAD2'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '634956',
#   'symbolB': 'CENPE'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '553070',
#   'symbolB': 'SOAT1'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '549334',
#   'symbolB': 'SNAPIN'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '569410',
#   'symbolB': 'ZWINT'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '565032',
#   'symbolB': 'CCDC22'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '549234',
#   'symbolB': 'MTCL1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '552478',
#   'symbolB': 'AGAP1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548798',
#   'symbolB': 'CEP131'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '578378',
#   'symbolB': 'KMT2B'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '557016',
#   'symbolB': 'ZMYND8'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '573874',
#   'symbolB': 'ZDHHC8'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '565348',
#   'symbolB': 'TRPS1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '564866',
#   'symbolB': 'ARHGAP23'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548778',
#   'symbolB': 'UGGT2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '555720',
#   'symbolB': 'DMAP1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '577044', 'symbolB': 'FBRS'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '553210',
#   'symbolB': 'PTGES2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562412',
#   'symbolB': 'PLEKHG2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '629264',
#   'symbolB': 'AIFM2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '571828',
#   'symbolB': 'ARHGEF17'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '552436',
#   'symbolB': 'AGAP3'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '582972',
#   'symbolB': 'SCARF2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '592418',
#   'symbolB': 'CASKIN2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '573550',
#   'symbolB': 'ARHGEF40'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '549104', 'symbolB': 'DLG5'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '561818',
#   'symbolB': 'GDAP1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '553140', 'symbolB': 'UXS1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '568768',
#   'symbolB': 'SYNPO'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '571098',
#   'symbolB': 'ZNF687'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '575218',
#   'symbolB': 'STK11IP'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '548720', 'symbolB': 'CHPF'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '555990',
#   'symbolB': 'CHSY1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '634530',
#   'symbolB': 'KIF21A'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '581606',
#   'symbolB': 'RSRC2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '558050',
#   'symbolB': 'CHSY3'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562144',
#   'symbolB': 'SRCAP'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '549004',
#   'symbolB': 'FAM171A1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '550236',
#   'symbolB': 'SYDE2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '553482',
#   'symbolB': 'DCAF10'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562090',
#   'symbolB': 'TIGD5'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '571582',
#   'symbolB': 'SHROOM1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '548664', 'symbolB': 'EXT1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562682',
#   'symbolB': 'VPS72'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '579994',
#   'symbolB': 'SCRIB'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '554420', 'symbolB': 'PLD1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '557970', 'symbolB': 'SCAP'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '563030',
#   'symbolB': 'DENND2B'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548940',
#   'symbolB': 'DCAF7'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '571448', 'symbolB': 'TSC2'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '584412', 'symbolB': 'HELZ'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '551920', 'symbolB': 'ETV6'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '551266',
#   'symbolB': 'TIMP3'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '568120', 'symbolB': 'NF1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '624162', 'symbolB': 'P4HB'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548500',
#   'symbolB': 'ITGAV'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '558354',
#   'symbolB': 'CEP43'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '548488', 'symbolB': 'UBR5'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '593204',
#   'symbolB': 'ADGRL1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '559628',
#   'symbolB': 'RPS6KA4'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '557366', 'symbolB': 'LRP6'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '554410',
#   'symbolB': 'PEX14'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '615874',
#   'symbolB': 'NUAK1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '634468',
#   'symbolB': 'ZBTB7B'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '554612',
#   'symbolB': 'FAM171A2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '559618',
#   'symbolB': 'PLEKHG3'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '564036',
#   'symbolB': 'ARHGAP10'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '575728',
#   'symbolB': 'ERAP1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '582816',
#   'symbolB': 'ATP13A3'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '563838',
#   'symbolB': 'C1orf198'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '592808',
#   'symbolB': 'BTBD9'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '564678',
#   'symbolB': 'ITCH'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '561062',
#   'symbolB': 'WBP2'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '588718',
#   'symbolB': 'TRPM4'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '553450',
#   'symbolB': 'NPLOC4'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '555196',
#   'symbolB': 'VPS8'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '580290',
#   'symbolB': 'NBEAL1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '570370',
#   'symbolB': 'DAZAP2'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '549404',
#   'symbolB': 'ATP6V0D1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '553446',
#   'symbolB': 'PPM1A'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '548288',
#   'symbolB': 'UQCRB'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '550158',
#   'symbolB': 'ENDOD1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '548290',
#   'symbolB': 'COX7A2L'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '548264',
#   'symbolB': 'PDE2A'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '588494',
#   'symbolB': 'CGGBP1'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '634232',
#   'symbolB': 'TRPM3'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '632920',
#   'symbolB': 'PCMTD1'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '575566',
#   'symbolB': 'ARK2N'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '634224',
#   'symbolB': 'PPARGC1B'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '555352', 'symbolB': 'MRM1'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '555696', 'symbolB': 'KGD4'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '615894',
#   'symbolB': 'NRIP1'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '555602', 'symbolB': 'CKB'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '634212',
#   'symbolB': 'ESRRA'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '551440', 'symbolB': 'TTR'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '566312', 'symbolB': 'MYRF'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '568840', 'symbolB': 'ASAP1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '634200', 'symbolB': 'MAGEL2'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '559266', 'symbolB': 'TNS1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '576838',
#   'symbolB': 'MARCHF7'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '570926', 'symbolB': 'PCNX3'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '574262', 'symbolB': 'MYADM'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '582972', 'symbolB': 'SCARF2'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '576794',
#   'symbolB': 'TMEM200A'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '563834', 'symbolB': 'DAAM2'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '549004',
#   'symbolB': 'FAM171A1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '552942', 'symbolB': 'CDC37'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '550424', 'symbolB': 'ITSN1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '574690',
#   'symbolB': 'RPS6KA1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '562876', 'symbolB': 'CBFB'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '580556', 'symbolB': 'RUNX2'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '577992', 'symbolB': 'FKBP5'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '551464', 'symbolB': 'PTPRS'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '567956', 'symbolB': 'RUNX1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '563030',
#   'symbolB': 'DENND2B'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '611852', 'symbolB': 'BCAR1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '569530',
#   'symbolB': 'RPS6KA3'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '576748', 'symbolB': 'TGFBR2'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '596066', 'symbolB': 'JAK1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '614410',
#   'symbolB': 'TNFRSF1A'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '557406', 'symbolB': 'PTPRF'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '564376', 'symbolB': 'YES1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '567288', 'symbolB': 'F13A1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '551410', 'symbolB': 'MYCBP2'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '556320', 'symbolB': 'ZYG11B'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '555280', 'symbolB': 'NHLRC2'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '552072', 'symbolB': 'CCDC80'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '555696', 'symbolB': 'KGD4'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '555886', 'symbolB': 'SEPHS1'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '550662', 'symbolB': 'COIL'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '551226', 'symbolB': 'MOCS3'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '579900',
#   'symbolB': 'AMDHD2'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '550982',
#   'symbolB': 'RCOR1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '549202',
#   'symbolB': 'ZMYM2'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '562486',
#   'symbolB': 'EIF2AK4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '549194',
#   'symbolB': 'RCOR3'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '590256',
#   'symbolB': 'ZNF446'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '549162', 'symbolB': 'GPHN'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '607660', 'symbolB': 'EML4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '550114',
#   'symbolB': 'SAP130'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '566980',
#   'symbolB': 'SIN3A'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633946',
#   'symbolB': 'ZSCAN31'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '554438',
#   'symbolB': 'PGBD1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '566278',
#   'symbolB': 'ZNF496'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '590248',
#   'symbolB': 'ZSCAN18'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '565306',
#   'symbolB': 'EPM2AIP1'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '550174', 'symbolB': 'GET4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '559870',
#   'symbolB': 'ZSCAN25'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '549010',
#   'symbolB': 'ZMYM4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '566258',
#   'symbolB': 'TMTC4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '556856',
#   'symbolB': 'ZKSCAN8'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '562564',
#   'symbolB': 'ZNF174'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633922',
#   'symbolB': 'TGIF1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '548434',
#   'symbolB': 'ZMYM3'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '602682',
#   'symbolB': 'SCAND1'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '550162', 'symbolB': 'BAG6'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633912',
#   'symbolB': 'ZSCAN20'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '559642',
#   'symbolB': 'ZKSCAN1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '590238',
#   'symbolB': 'ZNF24'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '548908',
#   'symbolB': 'KDM1A'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633902',
#   'symbolB': 'ZNF500'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '619544',
#   'symbolB': 'ZNF213'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '568514',
#   'symbolB': 'RNF114'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '598222',
#   'symbolB': 'MKRN2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '550752',
#   'symbolB': 'CRNKL1'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '552798',
#   'symbolB': 'ATXN2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '547768',
#   'symbolB': 'FYTTD1'},
#  {'geneA': '633228', 'symbolA': 'PARP12', 'geneB': '565428', 'symbolB': 'QKI'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '633252',
#   'symbolB': 'PPWD1'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '582232',
#   'symbolB': 'RNF166'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '562248',
#   'symbolB': 'DTX3L'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '562204',
#   'symbolB': 'PARP9'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '564438',
#   'symbolB': 'DTX2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '552072',
#   'symbolB': 'CCDC80'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '547752',
#   'symbolB': 'ZC3H14'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '593890',
#   'symbolB': 'DDI2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '568962',
#   'symbolB': 'NCBP3'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '566246',
#   'symbolB': 'ELAVL2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '570942',
#   'symbolB': 'SYF2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '547736',
#   'symbolB': 'CASC3'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '576642', 'symbolB': 'KDSR'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '554566', 'symbolB': 'RRAS2'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '560740', 'symbolB': 'GPX4'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '621272',
#   'symbolB': 'BMPR1A'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '611790', 'symbolB': 'COMT'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '555802',
#   'symbolB': 'LGALS3'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '551532', 'symbolB': 'RRAS'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '561348',
#   'symbolB': 'LGALS8'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '554612',
#   'symbolB': 'FAM171A2'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '554610',
#   'symbolB': 'PCDHGB1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '605576',
#   'symbolB': 'LRRC4B'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '601202',
#   'symbolB': 'CSNK1G1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '549676',
#   'symbolB': 'EPB41L5'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '633198', 'symbolB': 'RBM38'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '548450',
#   'symbolB': 'TMEM120A'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '553170',
#   'symbolB': 'FAM210B'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '561554',
#   'symbolB': 'TMEM186'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '552210', 'symbolB': 'RAB2B'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '633186',
#   'symbolB': 'NDUFAF2'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '576664',
#   'symbolB': 'RETREG3'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '549052',
#   'symbolB': 'TAX1BP1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '551518',
#   'symbolB': 'MBLAC2'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '592590', 'symbolB': 'WLS'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '547274', 'symbolB': 'GNA13'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '548108', 'symbolB': 'ASAH1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '563658',
#   'symbolB': 'CALCOCO2'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '633198',
#   'symbolB': 'RBM38'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '573992',
#   'symbolB': 'GNPNAT1'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '584988', 'symbolB': 'AMZ2'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '566734',
#   'symbolB': 'PDE12'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '552050', 'symbolB': 'SAFB'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '560934', 'symbolB': 'EEA1'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '559460',
#   'symbolB': 'SAFB2'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '548952',
#   'symbolB': 'TP53BP1'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '555424', 'symbolB': 'UBTF'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '607648',
#   'symbolB': 'CREB1'},
#  {'geneA': '632866',
#   'symbolA': 'RDX',
#   'geneB': '571828',
#   'symbolB': 'ARHGEF17'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632882', 'symbolB': 'LARS2'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632878', 'symbolB': 'NF2'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632874', 'symbolB': 'MSN'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632870', 'symbolB': 'EZR'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '551520', 'symbolB': 'RFPL4A'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '562998',
#   'symbolB': 'DCTN4'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '575298',
#   'symbolB': 'LTBP4'},
#  {'geneA': '632720', 'symbolA': 'ZNF74', 'geneB': '558074', 'symbolB': 'P3H2'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '548716',
#   'symbolB': 'FRAS1'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '548660',
#   'symbolB': 'LTBP2'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '579994',
#   'symbolB': 'SCRIB'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '594704',
#   'symbolB': 'TRIM28'},
#  {'geneA': '632720', 'symbolA': 'ZNF74', 'geneB': '548580', 'symbolB': 'FBN2'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '557476',
#   'symbolB': 'LAMA1'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '553526',
#   'symbolB': 'TRIM27'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '562970',
#   'symbolB': 'DCTN6'},
#  {'geneA': '632680',
#   'symbolA': 'PRDX3',
#   'geneB': '632686',
#   'symbolB': 'PRDX1'},
#  {'geneA': '632680',
#   'symbolA': 'PRDX3',
#   'geneB': '550102',
#   'symbolB': 'HERC2'},
#  {'geneA': '632680', 'symbolA': 'PRDX3', 'geneB': '587634', 'symbolB': 'OPA1'},
#  {'geneA': '632650', 'symbolA': 'KANK4', 'geneB': '632676', 'symbolB': 'TLN2'},
#  {'geneA': '632650', 'symbolA': 'KANK4', 'geneB': '632672', 'symbolB': 'TLN1'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '561536',
#   'symbolB': 'TRAPPC4'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '556956',
#   'symbolB': 'PIP5K1A'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '559736',
#   'symbolB': 'TRAPPC9'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '561514',
#   'symbolB': 'TRAPPC14'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '596312',
#   'symbolB': 'EHBP1'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '562222',
#   'symbolB': 'PLCD3'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '555746',
#   'symbolB': 'EHBP1L1'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '554300',
#   'symbolB': 'TRAPPC5'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '561490',
#   'symbolB': 'TRAPPC10'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '559710',
#   'symbolB': 'TRAPPC3'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '547722',
#   'symbolB': 'RRP7A'},
#  {'geneA': '632566', 'symbolA': 'FGF17', 'geneB': '552482', 'symbolB': 'HPSE'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '557010',
#   'symbolB': 'NOL12'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '615596',
#   'symbolB': 'ANKFY1'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '549676',
#   'symbolB': 'EPB41L5'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '547626',
#   'symbolB': 'NUSAP1'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '556956',
#   'symbolB': 'PIP5K1A'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '559890',
#   'symbolB': 'ASCC3'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '566362',
#   'symbolB': 'ANKHD1-EIF4EBP3'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '556876',
#   'symbolB': 'DHX57'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '564514',
#   'symbolB': 'TRIP4'},
#  {'geneA': '632566', 'symbolA': 'FGF17', 'geneB': '609082', 'symbolB': 'FGF8'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '551428',
#   'symbolB': 'ANKRD17'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '632562',
#   'symbolB': 'TXLNG'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '632558',
#   'symbolB': 'NACA2'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '553476',
#   'symbolB': 'METAP1'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '551284',
#   'symbolB': 'PRIM2'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '550212',
#   'symbolB': 'PRIM1'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '632548',
#   'symbolB': 'TXLNA'},
#  {'geneA': '632438',
#   'symbolA': 'SOHLH1',
#   'geneB': '557132',
#   'symbolB': 'KCTD12'},
#  {'geneA': '632438',
#   'symbolA': 'SOHLH1',
#   'geneB': '571680',
#   'symbolB': 'KCTD8'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '557676',
#   'symbolB': 'ROBO1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '551990',
#   'symbolB': 'MAN1B1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '559150',
#   'symbolB': 'FBXO2'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '600078',
#   'symbolB': 'SEL1L'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '562860',
#   'symbolB': 'UFSP2'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '562850',
#   'symbolB': 'ATP13A1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '561138',
#   'symbolB': 'ACBD3'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '560468',
#   'symbolB': 'LMAN2L'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '619890',
#   'symbolB': 'SERAC1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '569814',
#   'symbolB': 'KIRREL1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '555902',
#   'symbolB': 'NGLY1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '572972',
#   'symbolB': 'PMEPA1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '560432',
#   'symbolB': 'POMGNT1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '575680',
#   'symbolB': 'ITPRIP'},
#  {'geneA': '632078', 'symbolA': 'ASIC4', 'geneB': '564660', 'symbolB': 'LSR'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '567970',
#   'symbolB': 'NFXL1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '551354',
#   'symbolB': 'ASPHD2'},
#  {'geneA': '632078', 'symbolA': 'ASIC4', 'geneB': '556314', 'symbolB': 'ODR4'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '600280',
# ...
#   'symbolB': 'METTL17'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '630154', 'symbolB': 'ITFG2'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '570612', 'symbolB': 'TNIP2'},
#  {'geneA': '630134',
#   'symbolA': 'VWCE',
#   'geneB': '554230',
#   'symbolB': 'NUFIP2'},
#  {'geneA': '630134',
#   'symbolA': 'VWCE',
#   'geneB': '567778',
#   'symbolB': 'ITPRIPL2'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '555738', 'symbolB': 'LAGE3'},
#  {'geneA': '630134',
#   'symbolA': 'VWCE',
#   'geneB': '600058',
#   'symbolB': 'SQSTM1'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '551266', 'symbolB': 'TIMP3'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '548568', 'symbolB': 'CCN2'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '548032', 'symbolB': 'IDE'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '604300', 'symbolB': 'HSPA5'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '578100',
#   'symbolB': 'AP3M1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568236',
#   'symbolB': 'DNAJC16'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559430',
#   'symbolB': 'MAPK8IP3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559424',
#   'symbolB': 'ATXN10'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '549186',
#   'symbolB': 'RELCH'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '555312',
#   'symbolB': 'TOR4A'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '630108',
#   'symbolB': 'ZDHHC7'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '628676',
#   'symbolB': 'TBC1D22B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '547902',
#   'symbolB': 'DIAPH3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '552966',
#   'symbolB': 'SMYD3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '555210',
#   'symbolB': 'VPS16'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '549142',
#   'symbolB': 'WDR13'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '579080', 'symbolB': 'SMG9'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '559416', 'symbolB': 'XPO4'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '551490',
#   'symbolB': 'LRRC1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '579548',
#   'symbolB': 'INPP5K'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '616894',
#   'symbolB': 'NCAPG'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568804',
#   'symbolB': 'TSG101'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '580340', 'symbolB': 'SMG1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568612',
#   'symbolB': 'INTS4'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '608274', 'symbolB': 'SNF8'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '560158',
#   'symbolB': 'HOOK2'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '555202',
#   'symbolB': 'VPS33A'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '553018',
#   'symbolB': 'PBXIP1'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '552866', 'symbolB': 'EXT2'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '572668', 'symbolB': 'RGP1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '569804',
#   'symbolB': 'TBC1D22A'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '554042',
#   'symbolB': 'TRPC4AP'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '571766', 'symbolB': 'CCNY'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '558102', 'symbolB': 'SMG8'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '557240',
#   'symbolB': 'SLC39A11'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '569884',
#   'symbolB': 'CAMK1D'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568386',
#   'symbolB': 'COMMD2'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '551382', 'symbolB': 'WAPL'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559392',
#   'symbolB': 'HEATR3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '594912',
#   'symbolB': 'ARMC9'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '567446', 'symbolB': 'SETX'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '572634',
#   'symbolB': 'USP34'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '570714',
#   'symbolB': 'NBEAL2'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '564400',
#   'symbolB': 'INTS3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '553996',
#   'symbolB': 'TBC1D9B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '550548',
#   'symbolB': 'PPP4R3B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '561806',
#   'symbolB': 'AARS2'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '572616', 'symbolB': 'RIC1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '556108',
#   'symbolB': 'ERCC6L'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '551834',
#   'symbolB': 'KIF14'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '559016', 'symbolB': 'CUL7'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '554530', 'symbolB': 'RIN1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '610870',
#   'symbolB': 'IFRD2'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '630020',
#   'symbolB': 'PRKDC'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '560826',
#   'symbolB': 'GSDMD'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '560774',
#   'symbolB': 'HSPA13'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559376',
#   'symbolB': 'PEX19'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '568120', 'symbolB': 'NF1'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '569326', 'symbolB': 'RB1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '616772',
#   'symbolB': 'TBC1D8'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '556090', 'symbolB': 'FRYL'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '587248',
#   'symbolB': 'STK17B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '574636',
#   'symbolB': 'HIP1R'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568536',
#   'symbolB': 'GSDME'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '554480',
#   'symbolB': 'SPAG9'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '565984', 'symbolB': 'ENC1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '550356',
#   'symbolB': 'DCAF1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '551194',
#   'symbolB': 'MKLN1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '551794',
#   'symbolB': 'CRIM1'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '554256', 'symbolB': 'WDR6'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '565828',
#   'symbolB': 'RMND5A'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '549742',
#   'symbolB': 'UBE2O'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '617228',
#   'symbolB': 'AP1M1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '569678',
#   'symbolB': 'ZMYND19'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '570612',
#   'symbolB': 'TNIP2'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '575298',
#   'symbolB': 'LTBP4'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '561814',
#   'symbolB': 'RPTOR'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '562212', 'symbolB': 'ASPM'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '558074', 'symbolB': 'P3H2'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '564588',
#   'symbolB': 'FAM83H'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '554554', 'symbolB': 'ABL2'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '565742', 'symbolB': 'TYK2'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '557476',
#   'symbolB': 'LAMA1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '553526',
#   'symbolB': 'TRIM27'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '554236',
#   'symbolB': 'TOMM40'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '554008', 'symbolB': 'TRIO'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '548216',
#   'symbolB': 'ARFGEF1'},
#  {'geneA': '629884', 'symbolA': 'NHLH2', 'geneB': '553244', 'symbolB': 'EXOG'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '555242',
#   'symbolB': 'CUEDC1'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '549742',
#   'symbolB': 'UBE2O'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '566282',
#   'symbolB': 'TCF12'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '586182',
#   'symbolB': 'ARL10'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '563822',
#   'symbolB': 'RAP1GDS1'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '563330',
#   'symbolB': 'CENPF'},
#  {'geneA': '629884', 'symbolA': 'NHLH2', 'geneB': '566236', 'symbolB': 'TCF3'},
#  {'geneA': '629884', 'symbolA': 'NHLH2', 'geneB': '566232', 'symbolB': 'TCF4'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '550098',
#   'symbolB': 'AP3B1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '564364',
#   'symbolB': 'TBL2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '568236',
#   'symbolB': 'DNAJC16'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '568208',
#   'symbolB': 'ST7'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '554442',
#   'symbolB': 'SYT11'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '587902',
#   'symbolB': 'PDCD2L'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '557250',
#   'symbolB': 'DNAJC1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '600070',
#   'symbolB': 'GRAMD1A'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '599930',
#   'symbolB': 'MIB2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '554888',
#   'symbolB': 'CSNK2A3'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '553122',
#   'symbolB': 'MACO1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '550178',
#   'symbolB': 'FRMD5'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '551378',
#   'symbolB': 'MAEA'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '557224',
#   'symbolB': 'ILDR2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '567356',
#   'symbolB': 'CCBE1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '570878',
#   'symbolB': 'CSNK2A1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '576976',
#   'symbolB': 'CSNK2B'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '550794',
#   'symbolB': 'DYNLL1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '551300',
#   'symbolB': 'YPEL5'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '554872',
#   'symbolB': 'CSNK2A2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '578818',
#   'symbolB': 'ERCC3'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '551410',
#   'symbolB': 'MYCBP2'},
#  {'geneA': '629704',
#   'symbolA': 'ZC3HAV1',
#   'geneB': '571066',
#   'symbolB': 'TJP1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '554698',
#   'symbolB': 'PCDHB13'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '627048',
#   'symbolB': 'PROCR'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '565584',
#   'symbolB': 'ITM2C'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558180',
#   'symbolB': 'CNNM2'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '629692',
#   'symbolB': 'ULBP3'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558158',
#   'symbolB': 'LRFN3'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '554328',
#   'symbolB': 'MXRA8'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '583204',
#   'symbolB': 'CYB5D2'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '554652',
#   'symbolB': 'ITFG1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558086',
#   'symbolB': 'DCBLD1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '563700',
#   'symbolB': 'DHRS13'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '567770',
#   'symbolB': 'OCLN'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '577462', 'symbolB': 'ATR'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '557550',
#   'symbolB': 'PTK7'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '563654',
#   'symbolB': 'HYAL2'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '575640',
#   'symbolB': 'EPHB4'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '560288',
#   'symbolB': 'ADGRE5'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '593958', 'symbolB': 'NMU'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '572952',
#   'symbolB': 'TNFSF9'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '548584',
#   'symbolB': 'TGFBR1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558526',
#   'symbolB': 'PTPN2'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '557432', 'symbolB': 'PVR'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '593916',
#   'symbolB': 'BMP4'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '548520', 'symbolB': 'MET'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '580220',
#   'symbolB': 'HAUS5'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '582918',
#   'symbolB': 'TOR1B'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '561348',
#   'symbolB': 'LGALS8'},
#  {'geneA': '629598',
#   'symbolA': 'NFE2L3',
#   'geneB': '553472',
#   'symbolB': 'HCFC2'},
#  {'geneA': '629598', 'symbolA': 'NFE2L3', 'geneB': '557872', 'symbolB': 'C4A'},
#  {'geneA': '629536',
#   'symbolA': 'ZNF467',
#   'geneB': '629532',
#   'symbolB': 'ACSF3'},
#  {'geneA': '629536',
#   'symbolA': 'ZNF467',
#   'geneB': '556852',
#   'symbolB': 'OASL'},
#  {'geneA': '629536',
#   'symbolA': 'ZNF467',
#   'geneB': '547482',
#   'symbolB': 'TARBP2'},
#  {'geneA': '629532',
#   'symbolA': 'ACSF3',
#   'geneB': '553338',
#   'symbolB': 'LONP1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '558708',
#   'symbolB': 'MAP3K4'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '557676',
#   'symbolB': 'ROBO1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '568644',
#   'symbolB': 'TNPO3'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '549328',
#   'symbolB': 'NDUFAF1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '576702',
#   'symbolB': 'USP24'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '576286',
#   'symbolB': 'VPS51'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '550782',
#   'symbolB': 'DDX20'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '560532',
#   'symbolB': 'SEC63'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '565188',
#   'symbolB': 'TFIP11'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '555224',
#   'symbolB': 'VPS18'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '548774',
#   'symbolB': 'TMEM160'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '554016',
#   'symbolB': 'EXOC1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '568212',
#   'symbolB': 'FIRRM'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '559420',
#   'symbolB': 'EIF2B3'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '557632',
#   'symbolB': 'CELSR2'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '556474',
#   'symbolB': 'RNPEP'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '587466',
#   'symbolB': 'YIPF3'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '588514',
#   'symbolB': 'TMEM70'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '549308',
#   'symbolB': 'ECSIT'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '587784',
#   'symbolB': 'SPG11'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '603074',
#   'symbolB': 'CRELD1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '553520',
#   'symbolB': 'TRIM44'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '628286',
#   'symbolB': 'EVI5L'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '565962',
#   'symbolB': 'IGSF8'},
#  {'geneA': '629374', 'symbolA': 'FZD10', 'geneB': '553380', 'symbolB': 'P3H4'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '629478',
#   'symbolB': 'SNX19'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '557614',
#   'symbolB': 'PIEZO1'},
#  ...]

# %%
class NdexGeneNodeAttributeGenerator(GeneNodeAttributeGenerator):
    """
    Creates APMS Gene Node Attributes table and edgelist table from NDEx network data (.cx)
    """

    def __init__(self, apms_edgelist=None,
                 genequery=GeneQuery(), uuid, ndexserver):
        """
        Constructor

        :param apms_edgelist: list of dict elements where each
                              dict is of format:

                              .. code-block::

                                  {'Bait': VAL,
                                   'Prey': VAL,
                                   'logOddsScore': VAL,
                                   'FoldChange.x': VAL,
                                   'BFDR.x': VAL}
        :type apms_edgelist: list
        :param genequery:
        """
        super().__init__()
        self._raw_apms_edgelist = apms_edgelist
        self._apms_edgelist = None
        self._genequery = genequery
        self.uuid = uuid
        self.ndexserver = "http://public.ndexbio.org"
        self.node_attrs_list = self.get_gene_node_attributes ()
    
    def get_gene_node_attributes(self, nice_cx):
        nodes = nice_cx.nodes
        node_attrs = nice_cx.nodeAttributes

        attr_by_node_id = defaultdict(dict)
        for node_id,attr_list in node_attrs.items():
            for attr in attr_list:
                attr_name = attr['n']
                attr_value = attr['v']
                attr_by_node_id[node_id][attr_name] = attr_value

        nodes_combined = []
        for node_id, node_data in nodes.items():
            node_id = node_id
            name = node_data.get('n')
            represents = node_data.get('r', None)
            bait_str = attr_by_node_id[node_id].get('bait', None)
            antibody = attr_by_node_id[node_id].get('antibody', None)

            if bait_str == 'true':
                bait = True
            elif bait_str == 'false':
                bait = False
            else:
                bait = None

            nodes_combined.append({
                'node_id': node_id,
                'name': name,
                'represents': represents,
                'bait': bait,
                'antibody': antibody
            })
        
        node_attrs_list = pd.DataFrame(nodes_combined)

        return node_attrs_list
    
    
    def get_apms_edgelist (self, nice_cx, node_attrs_list):

        node_attrs_by_id = {}
        for _, row in node_attrs_list.iterrows():
            node_attrs_by_id[row['node_id']] = row.to_dict()

        edges = nice_cx.edges
        edge_attrs = nice_cx.edgeAttributes

        attr_by_edge_id = defaultdict(dict)
        for edge_id, attr_list in edge_attrs.items():
            for attr in attr_list:
                attr_name = attr['n']
                attr_value = attr['v']
                if attr_name == 'name':
                    continue
                attr_by_edge_id[edge_id][attr_name] = attr_value

        edge_list = []
        for edge_id, edge_data in edges.items():
            source = edge_data.get('s')
            target = edge_data.get('t')

            source_info = node_attrs_by_id.get(source, {})
            target_info = node_attrs_by_id.get(target, {})

            ensembl1_raw = source_info.get('represents')
            ensembl1 = ensembl1_raw[len('ensembl:'):] if ensembl1_raw and ensembl1_raw.startswith('ensembl:') else ensembl1_raw

            ensembl2_raw = target_info.get('represents')
            ensembl2 = ensembl2_raw[len('ensembl:'):] if ensembl2_raw and ensembl2_raw.startswith('ensembl:') else ensembl2_raw

            edge_dict = {
                'geneA': source_info.get('node_id'), 
                'symbolA': source_info.get('name'),
                'ensemblA': ensembl1,
                'geneB': target_info.get('node_id'),
                'symbolB': target_info.get('name'),
                'ensemblB': ensembl2,
            }

            edge_dict.update(attr_by_edge_id.get(edge_id, {}))
            edge_list.append(edge_dict)
        
        edgelist = pd.DataFrame(edge_list)

        return edgelist

# %%
#original
def get_apms_baitlist_from_tsvfile(tsvfile=None,
                                       symbol_col=BAITLIST_GENE_SYMBOL,
                                       geneid_col=BAITLIST_GENE_ID,
                                       numinteractors_col=BAITLIST_NUM_INTERACTORS):
        """
        Generates list of dicts by parsing TSV file specified
        by **tsvfile** with the
        format header column and corresponding values:

        .. code-block::

            GeneSymbol\tGeneID\t# Interactors

        :param tsvfile: Path to TSV file with above format
        :type tsvfile: str
        :return: list of dicts, with each dict of format:

                 .. code-block::

                      { 'GeneSymbol': VAL,
                        'GeneID': VAL,
                        'NumIteractors': VAL }
        :rtype: list
        """
        edgelist = []
        if tsvfile is not None:
            with open(tsvfile, 'r') as f:
                reader = csv.DictReader(f, delimiter='\t')
                for row in reader:
                    edgelist.append({'GeneSymbol': row[symbol_col],
                                     'GeneID': row[geneid_col],
                                     'NumInteractors': row[numinteractors_col]})
        return edgelist

# %%
def get_baitlist(uuid=None):

    nice_cx = ndex2.create_nice_cx_from_server("http://public.ndexbio.org", uuid=uuid)
    nodes = nice_cx.nodes
    node_attrs = nice_cx.nodeAttributes
    edges = nice_cx.edges

    attr_by_node_id = defaultdict(dict)
    for node_id, attr_list in node_attrs.items():
        for attr in attr_list:
            attr_by_node_id[node_id][attr['n']] = attr['v']

    adjacency = defaultdict(set)
    for edge_id, edge_data in edges.items():
        source = edge_data['s']
        target = edge_data['t']
        adjacency[source].add(target)
        adjacency[target].add(source)

    baitlist = []

    for node_id, node_data in nodes.items():
        is_bait = attr_by_node_id[node_id].get('bait', '').lower() == 'true'
        if is_bait:
            gene_symbol = node_data.get('n')
            gene_id = str(node_id)
            num_interactors = len(adjacency[node_id])
            baitlist.append({
                'GeneSymbol': gene_symbol,
                'GeneID': gene_id,
                'NumInteractors': num_interactors
            })

    return baitlist

# %%
apms_baitlist = get_baitlist(uuid="95bc75d5-d1d1-11ee-8a40-005056ae23aa")

# %%
apms_baitlist
# Out:
# [{'GeneSymbol': 'TMEM88', 'GeneID': '635898', 'NumInteractors': 40},
#  {'GeneSymbol': 'COL10A1', 'GeneID': '635852', 'NumInteractors': 22},
#  {'GeneSymbol': 'CYCS', 'GeneID': '635680', 'NumInteractors': 4},
#  {'GeneSymbol': 'PHF20', 'GeneID': '635458', 'NumInteractors': 5},
#  {'GeneSymbol': 'ADD2', 'GeneID': '635416', 'NumInteractors': 1},
#  {'GeneSymbol': 'IMPDH1', 'GeneID': '635296', 'NumInteractors': 52},
#  {'GeneSymbol': 'VSIG1', 'GeneID': '635006', 'NumInteractors': 139},
#  {'GeneSymbol': 'SYCE3', 'GeneID': '634946', 'NumInteractors': 12},
#  {'GeneSymbol': 'P4HA3', 'GeneID': '634460', 'NumInteractors': 61},
#  {'GeneSymbol': 'DHCR24', 'GeneID': '634348', 'NumInteractors': 17},
#  {'GeneSymbol': 'ESRRG', 'GeneID': '634208', 'NumInteractors': 11},
#  {'GeneSymbol': 'FYN', 'GeneID': '634146', 'NumInteractors': 29},
#  {'GeneSymbol': 'ISX', 'GeneID': '634130', 'NumInteractors': 7},
#  {'GeneSymbol': 'TGIF2', 'GeneID': '633898', 'NumInteractors': 31},
#  {'GeneSymbol': 'PARP12', 'GeneID': '633228', 'NumInteractors': 18},
#  {'GeneSymbol': 'CD53', 'GeneID': '633170', 'NumInteractors': 26},
#  {'GeneSymbol': 'LARS2', 'GeneID': '632882', 'NumInteractors': 11},
#  {'GeneSymbol': 'RDX', 'GeneID': '632866', 'NumInteractors': 6},
#  {'GeneSymbol': 'ZNF74', 'GeneID': '632720', 'NumInteractors': 11},
#  {'GeneSymbol': 'PRDX3', 'GeneID': '632680', 'NumInteractors': 3},
#  {'GeneSymbol': 'KANK4', 'GeneID': '632650', 'NumInteractors': 12},
#  {'GeneSymbol': 'FGF17', 'GeneID': '632566', 'NumInteractors': 13},
#  {'GeneSymbol': 'BTF3L4', 'GeneID': '632546', 'NumInteractors': 6},
#  {'GeneSymbol': 'SOHLH1', 'GeneID': '632438', 'NumInteractors': 3},
#  {'GeneSymbol': 'ASIC4', 'GeneID': '632078', 'NumInteractors': 24},
#  {'GeneSymbol': 'SLC2A3', 'GeneID': '631976', 'NumInteractors': 3},
#  {'GeneSymbol': 'HOMEZ', 'GeneID': '631966', 'NumInteractors': 3},
#  {'GeneSymbol': 'SUMO1', 'GeneID': '631942', 'NumInteractors': 1},
#  {'GeneSymbol': 'TGOLN2', 'GeneID': '631694', 'NumInteractors': 16},
#  {'GeneSymbol': 'DBF4B', 'GeneID': '631678', 'NumInteractors': 7},
#  {'GeneSymbol': 'SPARC', 'GeneID': '631616', 'NumInteractors': 7},
#  {'GeneSymbol': 'ARHGEF35', 'GeneID': '631452', 'NumInteractors': 15},
#  {'GeneSymbol': 'FSD2', 'GeneID': '631108', 'NumInteractors': 41},
#  {'GeneSymbol': 'PNRC2', 'GeneID': '631060', 'NumInteractors': 4},
#  {'GeneSymbol': 'KERA', 'GeneID': '630960', 'NumInteractors': 4},
#  {'GeneSymbol': 'GNG2', 'GeneID': '630844', 'NumInteractors': 21},
#  {'GeneSymbol': 'FBLN2', 'GeneID': '630680', 'NumInteractors': 16},
#  {'GeneSymbol': 'NTN5', 'GeneID': '630660', 'NumInteractors': 28},
#  {'GeneSymbol': 'TMEM169', 'GeneID': '630428', 'NumInteractors': 67},
#  {'GeneSymbol': 'HOXD4', 'GeneID': '630388', 'NumInteractors': 6},
#  {'GeneSymbol': 'ADCY9', 'GeneID': '630360', 'NumInteractors': 17},
#  {'GeneSymbol': 'VWCE', 'GeneID': '630134', 'NumInteractors': 17},
#  {'GeneSymbol': 'EPHA1', 'GeneID': '629994', 'NumInteractors': 62},
#  {'GeneSymbol': 'KRBA1', 'GeneID': '629952', 'NumInteractors': 21},
#  {'GeneSymbol': 'NHLH2', 'GeneID': '629884', 'NumInteractors': 11},
#  {'GeneSymbol': 'GRAMD1B', 'GeneID': '629730', 'NumInteractors': 21},
#  {'GeneSymbol': 'ZC3HAV1', 'GeneID': '629704', 'NumInteractors': 1},
#  {'GeneSymbol': 'TNFSF8', 'GeneID': '629646', 'NumInteractors': 27},
#  {'GeneSymbol': 'NFE2L3', 'GeneID': '629598', 'NumInteractors': 2},
#  {'GeneSymbol': 'ZNF467', 'GeneID': '629536', 'NumInteractors': 3},
#  {'GeneSymbol': 'ACSF3', 'GeneID': '629532', 'NumInteractors': 2},
#  {'GeneSymbol': 'FZD10', 'GeneID': '629374', 'NumInteractors': 78},
#  {'GeneSymbol': 'CLEC4C', 'GeneID': '628954', 'NumInteractors': 6},
#  {'GeneSymbol': 'DUOXA2', 'GeneID': '628798', 'NumInteractors': 28},
#  {'GeneSymbol': 'LRRC52', 'GeneID': '628772', 'NumInteractors': 11},
#  {'GeneSymbol': 'LRRC73', 'GeneID': '628724', 'NumInteractors': 22},
#  {'GeneSymbol': 'FBXO16', 'GeneID': '628708', 'NumInteractors': 7},
#  {'GeneSymbol': 'CD80', 'GeneID': '628470', 'NumInteractors': 113},
#  {'GeneSymbol': 'LHFPL2', 'GeneID': '628370', 'NumInteractors': 17},
#  {'GeneSymbol': 'SLC2A12', 'GeneID': '628048', 'NumInteractors': 49},
#  {'GeneSymbol': 'TAF7L', 'GeneID': '628008', 'NumInteractors': 16},
#  {'GeneSymbol': 'FOXJ1', 'GeneID': '627982', 'NumInteractors': 7},
#  {'GeneSymbol': 'LRRC27', 'GeneID': '627656', 'NumInteractors': 8},
#  {'GeneSymbol': 'MILR1', 'GeneID': '627634', 'NumInteractors': 10},
#  {'GeneSymbol': 'LTO1', 'GeneID': '627612', 'NumInteractors': 9},
#  {'GeneSymbol': 'CD226', 'GeneID': '627242', 'NumInteractors': 78},
#  {'GeneSymbol': 'MICB', 'GeneID': '627232', 'NumInteractors': 65},
#  {'GeneSymbol': 'ZAR1L', 'GeneID': '627192', 'NumInteractors': 18},
#  {'GeneSymbol': 'HFE', 'GeneID': '627146', 'NumInteractors': 22},
#  {'GeneSymbol': 'OSTM1', 'GeneID': '626450', 'NumInteractors': 26},
#  {'GeneSymbol': 'C9orf40', 'GeneID': '626244', 'NumInteractors': 12},
#  {'GeneSymbol': 'COPG1', 'GeneID': '625900', 'NumInteractors': 4},
#  {'GeneSymbol': 'STXBP4', 'GeneID': '625880', 'NumInteractors': 2},
#  {'GeneSymbol': 'RHPN1', 'GeneID': '625842', 'NumInteractors': 6},
#  {'GeneSymbol': 'ZNF274', 'GeneID': '625732', 'NumInteractors': 2},
#  {'GeneSymbol': 'ACSF2', 'GeneID': '625710', 'NumInteractors': 1},
#  {'GeneSymbol': 'CEP72', 'GeneID': '625614', 'NumInteractors': 14},
#  {'GeneSymbol': 'SYT16', 'GeneID': '625430', 'NumInteractors': 2},
#  {'GeneSymbol': 'PARN', 'GeneID': '625338', 'NumInteractors': 1},
#  {'GeneSymbol': 'CCDC120', 'GeneID': '625124', 'NumInteractors': 41},
#  {'GeneSymbol': 'BCHE', 'GeneID': '624822', 'NumInteractors': 5},
#  {'GeneSymbol': 'TMPRSS13', 'GeneID': '624712', 'NumInteractors': 12},
#  {'GeneSymbol': 'ZNF276', 'GeneID': '624590', 'NumInteractors': 13},
#  {'GeneSymbol': 'BLMH', 'GeneID': '624586', 'NumInteractors': 1},
#  {'GeneSymbol': 'CCT8L2', 'GeneID': '624538', 'NumInteractors': 23},
#  {'GeneSymbol': 'SLC41A3', 'GeneID': '624522', 'NumInteractors': 7},
#  {'GeneSymbol': 'ABLIM2', 'GeneID': '624248', 'NumInteractors': 8},
#  {'GeneSymbol': 'IFNAR1', 'GeneID': '624242', 'NumInteractors': 2},
#  {'GeneSymbol': 'SLC1A1', 'GeneID': '623974', 'NumInteractors': 55},
#  {'GeneSymbol': 'ADGRG5', 'GeneID': '623796', 'NumInteractors': 76},
#  {'GeneSymbol': 'ZSCAN5A', 'GeneID': '623532', 'NumInteractors': 27},
#  {'GeneSymbol': 'GDF5', 'GeneID': '623528', 'NumInteractors': 1},
#  {'GeneSymbol': 'CCNJ', 'GeneID': '623486', 'NumInteractors': 3},
#  {'GeneSymbol': 'SCN2B', 'GeneID': '623170', 'NumInteractors': 153},
#  {'GeneSymbol': 'CDS1', 'GeneID': '623166', 'NumInteractors': 1},
#  {'GeneSymbol': 'CDS2', 'GeneID': '623164', 'NumInteractors': 2},
#  {'GeneSymbol': 'CHRNA3', 'GeneID': '623028', 'NumInteractors': 14},
#  {'GeneSymbol': 'ZNF223', 'GeneID': '622926', 'NumInteractors': 3},
#  {'GeneSymbol': 'SLC18A1', 'GeneID': '622902', 'NumInteractors': 11},
#  {'GeneSymbol': 'BSCL2', 'GeneID': '622604', 'NumInteractors': 78},
#  {'GeneSymbol': 'PPP2R2B', 'GeneID': '622448', 'NumInteractors': 70},
#  {'GeneSymbol': 'NTNG1', 'GeneID': '622118', 'NumInteractors': 11},
#  {'GeneSymbol': 'CHST8', 'GeneID': '622038', 'NumInteractors': 15},
#  {'GeneSymbol': 'BFSP2', 'GeneID': '621890', 'NumInteractors': 11},
#  {'GeneSymbol': 'GPR17', 'GeneID': '621650', 'NumInteractors': 119},
#  {'GeneSymbol': 'PHKG2', 'GeneID': '621630', 'NumInteractors': 8},
#  {'GeneSymbol': 'ELL3', 'GeneID': '621594', 'NumInteractors': 15},
#  {'GeneSymbol': 'ZSCAN9', 'GeneID': '621584', 'NumInteractors': 4},
#  {'GeneSymbol': 'DLK1', 'GeneID': '621220', 'NumInteractors': 104},
#  {'GeneSymbol': 'PISD', 'GeneID': '621204', 'NumInteractors': 7},
#  {'GeneSymbol': 'GNB1', 'GeneID': '621168', 'NumInteractors': 42},
#  {'GeneSymbol': 'C1QTNF9B', 'GeneID': '621044', 'NumInteractors': 92},
#  {'GeneSymbol': 'C1QTNF9', 'GeneID': '621042', 'NumInteractors': 51},
#  {'GeneSymbol': 'DKKL1', 'GeneID': '620872', 'NumInteractors': 26},
#  {'GeneSymbol': 'HAVCR2', 'GeneID': '620796', 'NumInteractors': 37},
#  {'GeneSymbol': 'TTC23L', 'GeneID': '620786', 'NumInteractors': 3},
#  {'GeneSymbol': 'CREB3', 'GeneID': '620742', 'NumInteractors': 20},
#  {'GeneSymbol': 'CD68', 'GeneID': '620628', 'NumInteractors': 31},
#  {'GeneSymbol': 'NFKBIB', 'GeneID': '620538', 'NumInteractors': 12},
#  {'GeneSymbol': 'CXCR4', 'GeneID': '620326', 'NumInteractors': 85},
#  {'GeneSymbol': 'MPPED1', 'GeneID': '620316', 'NumInteractors': 4},
#  {'GeneSymbol': 'TEAD4', 'GeneID': '620288', 'NumInteractors': 9},
#  {'GeneSymbol': 'DYNC2LI1', 'GeneID': '620282', 'NumInteractors': 2},
#  {'GeneSymbol': 'IZUMO1', 'GeneID': '620272', 'NumInteractors': 5},
#  {'GeneSymbol': 'TMEM184A', 'GeneID': '620252', 'NumInteractors': 9},
#  {'GeneSymbol': 'RAD51D', 'GeneID': '620238', 'NumInteractors': 6},
#  {'GeneSymbol': 'RAD51B', 'GeneID': '620228', 'NumInteractors': 6},
#  {'GeneSymbol': 'COQ8B', 'GeneID': '620086', 'NumInteractors': 1},
#  {'GeneSymbol': 'GYPA', 'GeneID': '619976', 'NumInteractors': 88},
#  {'GeneSymbol': 'FAM170A', 'GeneID': '619790', 'NumInteractors': 22},
#  {'GeneSymbol': 'MTCH2', 'GeneID': '619724', 'NumInteractors': 8},
#  {'GeneSymbol': 'HEY1', 'GeneID': '619694', 'NumInteractors': 14},
#  {'GeneSymbol': 'BEX5', 'GeneID': '619680', 'NumInteractors': 6},
#  {'GeneSymbol': 'ANKRD29', 'GeneID': '619666', 'NumInteractors': 4},
#  {'GeneSymbol': 'CD40', 'GeneID': '619284', 'NumInteractors': 127},
#  {'GeneSymbol': 'SAA1', 'GeneID': '619272', 'NumInteractors': 4},
#  {'GeneSymbol': 'SPIN1', 'GeneID': '619260', 'NumInteractors': 4},
#  {'GeneSymbol': 'ZNF397', 'GeneID': '619122', 'NumInteractors': 20},
#  {'GeneSymbol': 'ZMAT2', 'GeneID': '619120', 'NumInteractors': 4},
#  {'GeneSymbol': 'GTF2A2', 'GeneID': '618826', 'NumInteractors': 6},
#  {'GeneSymbol': 'IFNG', 'GeneID': '618778', 'NumInteractors': 15},
#  {'GeneSymbol': 'NPPA', 'GeneID': '618764', 'NumInteractors': 6},
#  {'GeneSymbol': 'ATP1A3', 'GeneID': '618702', 'NumInteractors': 22},
#  {'GeneSymbol': 'UBE3B', 'GeneID': '618696', 'NumInteractors': 4},
#  {'GeneSymbol': 'MYCBPAP', 'GeneID': '618686', 'NumInteractors': 4},
#  {'GeneSymbol': 'LRRC32', 'GeneID': '618538', 'NumInteractors': 39},
#  {'GeneSymbol': 'IL36A', 'GeneID': '618366', 'NumInteractors': 1},
#  {'GeneSymbol': 'PEA15', 'GeneID': '618356', 'NumInteractors': 3},
#  {'GeneSymbol': 'LYZL6', 'GeneID': '618270', 'NumInteractors': 5},
#  {'GeneSymbol': 'CFAP141', 'GeneID': '618266', 'NumInteractors': 1},
#  {'GeneSymbol': 'CDH8', 'GeneID': '618238', 'NumInteractors': 12},
#  {'GeneSymbol': 'TMEM74', 'GeneID': '618166', 'NumInteractors': 20},
#  {'GeneSymbol': 'HOXC9', 'GeneID': '618148', 'NumInteractors': 8},
#  {'GeneSymbol': 'PLGRKT', 'GeneID': '618046', 'NumInteractors': 2},
#  {'GeneSymbol': 'SPRYD4', 'GeneID': '617758', 'NumInteractors': 1},
#  {'GeneSymbol': 'C1S', 'GeneID': '617708', 'NumInteractors': 2},
#  {'GeneSymbol': 'ERP29', 'GeneID': '617654', 'NumInteractors': 4},
#  {'GeneSymbol': 'PCK2', 'GeneID': '617642', 'NumInteractors': 1},
#  {'GeneSymbol': 'FKBP2', 'GeneID': '617630', 'NumInteractors': 4},
#  {'GeneSymbol': 'SERPINE2', 'GeneID': '617342', 'NumInteractors': 2},
#  {'GeneSymbol': 'AHNAK', 'GeneID': '617330', 'NumInteractors': 2},
#  {'GeneSymbol': 'TMEM43', 'GeneID': '617288', 'NumInteractors': 5},
#  {'GeneSymbol': 'SLC25A40', 'GeneID': '617252', 'NumInteractors': 7},
#  {'GeneSymbol': 'PCDHGA5', 'GeneID': '617232', 'NumInteractors': 48},
#  {'GeneSymbol': 'RAB27B', 'GeneID': '617210', 'NumInteractors': 11},
#  {'GeneSymbol': 'DHRS2', 'GeneID': '617140', 'NumInteractors': 3},
#  {'GeneSymbol': 'CCAR2', 'GeneID': '617026', 'NumInteractors': 3},
#  {'GeneSymbol': 'RIC3', 'GeneID': '616748', 'NumInteractors': 94},
#  {'GeneSymbol': 'CSTPP1', 'GeneID': '616740', 'NumInteractors': 14},
#  {'GeneSymbol': 'OAS1', 'GeneID': '616366', 'NumInteractors': 63},
#  {'GeneSymbol': 'PPM1K', 'GeneID': '616308', 'NumInteractors': 3},
#  {'GeneSymbol': 'NXF5', 'GeneID': '616282', 'NumInteractors': 6},
#  {'GeneSymbol': 'P2RY4', 'GeneID': '616278', 'NumInteractors': 1},
#  {'GeneSymbol': 'VASH1', 'GeneID': '616270', 'NumInteractors': 3},
#  {'GeneSymbol': 'BEND7', 'GeneID': '616266', 'NumInteractors': 1},
#  {'GeneSymbol': 'CCR9', 'GeneID': '616194', 'NumInteractors': 35},
#  {'GeneSymbol': 'EPHX4', 'GeneID': '616166', 'NumInteractors': 5},
#  {'GeneSymbol': 'SYNJ2BP', 'GeneID': '616148', 'NumInteractors': 11},
#  {'GeneSymbol': 'SGMS2', 'GeneID': '616130', 'NumInteractors': 5},
#  {'GeneSymbol': 'CLINT1', 'GeneID': '615920', 'NumInteractors': 10},
#  {'GeneSymbol': 'DIABLO', 'GeneID': '615838', 'NumInteractors': 19},
#  {'GeneSymbol': 'TMEM129', 'GeneID': '615738', 'NumInteractors': 12},
#  {'GeneSymbol': 'PSRC1', 'GeneID': '615636', 'NumInteractors': 30},
#  {'GeneSymbol': 'INHA', 'GeneID': '615620', 'NumInteractors': 8},
#  {'GeneSymbol': 'DRG1', 'GeneID': '615606', 'NumInteractors': 5},
#  {'GeneSymbol': 'HTR1E', 'GeneID': '615292', 'NumInteractors': 137},
#  {'GeneSymbol': 'CCNI2', 'GeneID': '615224', 'NumInteractors': 33},
#  {'GeneSymbol': 'CNTFR', 'GeneID': '615208', 'NumInteractors': 5},
#  {'GeneSymbol': 'CDCA7', 'GeneID': '615200', 'NumInteractors': 3},
#  {'GeneSymbol': 'CXCR3', 'GeneID': '614898', 'NumInteractors': 146},
#  {'GeneSymbol': 'MAB21L3', 'GeneID': '614842', 'NumInteractors': 15},
#  {'GeneSymbol': 'CD33', 'GeneID': '614810', 'NumInteractors': 19},
#  {'GeneSymbol': 'NAA30', 'GeneID': '614780', 'NumInteractors': 15},
#  {'GeneSymbol': 'POPDC2', 'GeneID': '614714', 'NumInteractors': 22},
#  {'GeneSymbol': 'FAM187B', 'GeneID': '614690', 'NumInteractors': 12},
#  {'GeneSymbol': 'CLOCK', 'GeneID': '614582', 'NumInteractors': 2},
#  {'GeneSymbol': 'TSSK1B', 'GeneID': '614556', 'NumInteractors': 11},
#  {'GeneSymbol': 'ACKR3', 'GeneID': '614366', 'NumInteractors': 88},
#  {'GeneSymbol': 'LIAS', 'GeneID': '614348', 'NumInteractors': 7},
#  {'GeneSymbol': 'SSTR2', 'GeneID': '614278', 'NumInteractors': 32},
#  {'GeneSymbol': 'WNT9A', 'GeneID': '614190', 'NumInteractors': 43},
#  {'GeneSymbol': 'GPR85', 'GeneID': '614152', 'NumInteractors': 4},
#  {'GeneSymbol': 'COQ3', 'GeneID': '614136', 'NumInteractors': 4},
#  {'GeneSymbol': 'RNF25', 'GeneID': '614060', 'NumInteractors': 6},
#  {'GeneSymbol': 'ZNF550', 'GeneID': '614050', 'NumInteractors': 4},
#  {'GeneSymbol': 'PARVG', 'GeneID': '614024', 'NumInteractors': 5},
#  {'GeneSymbol': 'LPXN', 'GeneID': '613962', 'NumInteractors': 36},
#  {'GeneSymbol': 'SFN', 'GeneID': '613912', 'NumInteractors': 21},
#  {'GeneSymbol': 'IL5RA', 'GeneID': '613874', 'NumInteractors': 18},
#  {'GeneSymbol': 'ATP6V1H', 'GeneID': '613730', 'NumInteractors': 19},
#  {'GeneSymbol': 'SMTNL2', 'GeneID': '613664', 'NumInteractors': 20},
#  {'GeneSymbol': 'EPHX1', 'GeneID': '613108', 'NumInteractors': 1},
#  {'GeneSymbol': 'CHRM4', 'GeneID': '612886', 'NumInteractors': 70},
#  {'GeneSymbol': 'ARMC6', 'GeneID': '612634', 'NumInteractors': 125},
#  {'GeneSymbol': 'CHRNB2', 'GeneID': '612564', 'NumInteractors': 36},
#  {'GeneSymbol': 'ENTREP1', 'GeneID': '612550', 'NumInteractors': 6},
#  {'GeneSymbol': 'ZNRD2', 'GeneID': '612530', 'NumInteractors': 130},
#  {'GeneSymbol': 'ID2', 'GeneID': '612520', 'NumInteractors': 3},
#  {'GeneSymbol': 'PDK4', 'GeneID': '612474', 'NumInteractors': 3},
#  {'GeneSymbol': 'ZNF263', 'GeneID': '612336', 'NumInteractors': 2},
#  {'GeneSymbol': 'RAB27A', 'GeneID': '611834', 'NumInteractors': 16},
#  {'GeneSymbol': 'LPAR1', 'GeneID': '611640', 'NumInteractors': 330},
#  {'GeneSymbol': 'ENTPD2', 'GeneID': '611416', 'NumInteractors': 6},
#  {'GeneSymbol': 'CBLC', 'GeneID': '611230', 'NumInteractors': 6},
#  {'GeneSymbol': 'HPN', 'GeneID': '610830', 'NumInteractors': 192},
#  {'GeneSymbol': 'LINGO2', 'GeneID': '610808', 'NumInteractors': 1},
#  {'GeneSymbol': 'SLC34A2', 'GeneID': '610798', 'NumInteractors': 4},
#  {'GeneSymbol': 'GLMN', 'GeneID': '610744', 'NumInteractors': 19},
#  {'GeneSymbol': 'PTPDC1', 'GeneID': '610732', 'NumInteractors': 5},
#  {'GeneSymbol': 'SPPL2B', 'GeneID': '610614', 'NumInteractors': 54},
#  {'GeneSymbol': 'EMILIN3', 'GeneID': '610572', 'NumInteractors': 20},
#  {'GeneSymbol': 'ADARB1', 'GeneID': '610534', 'NumInteractors': 11},
#  {'GeneSymbol': 'JPH4', 'GeneID': '610502', 'NumInteractors': 15},
#  {'GeneSymbol': 'USP4', 'GeneID': '610498', 'NumInteractors': 12},
#  {'GeneSymbol': 'RPL6', 'GeneID': '610496', 'NumInteractors': 1},
#  {'GeneSymbol': 'PDGFD', 'GeneID': '610430', 'NumInteractors': 7},
#  {'GeneSymbol': 'PLD6', 'GeneID': '610424', 'NumInteractors': 2},
#  {'GeneSymbol': 'MAFK', 'GeneID': '610312', 'NumInteractors': 3},
#  {'GeneSymbol': 'AGRP', 'GeneID': '610142', 'NumInteractors': 4},
#  {'GeneSymbol': 'YBEY', 'GeneID': '610138', 'NumInteractors': 1},
#  {'GeneSymbol': 'LLGL2', 'GeneID': '610092', 'NumInteractors': 20},
#  {'GeneSymbol': 'TACR3', 'GeneID': '610012', 'NumInteractors': 3},
#  {'GeneSymbol': 'DLG3', 'GeneID': '609978', 'NumInteractors': 7},
#  {'GeneSymbol': 'ARHGAP12', 'GeneID': '609966', 'NumInteractors': 5},
#  {'GeneSymbol': 'PCDHGA6', 'GeneID': '609804', 'NumInteractors': 17},
#  {'GeneSymbol': 'ECEL1', 'GeneID': '609788', 'NumInteractors': 7},
#  {'GeneSymbol': 'KLHL11', 'GeneID': '609772', 'NumInteractors': 7},
#  {'GeneSymbol': 'FBLN5', 'GeneID': '609720', 'NumInteractors': 19},
#  {'GeneSymbol': 'WBP4', 'GeneID': '609670', 'NumInteractors': 3},
#  {'GeneSymbol': 'DPYSL4', 'GeneID': '609610', 'NumInteractors': 7},
#  {'GeneSymbol': 'IFNLR1', 'GeneID': '609602', 'NumInteractors': 3},
#  {'GeneSymbol': 'GNG8', 'GeneID': '609524', 'NumInteractors': 22},
#  {'GeneSymbol': 'TSGA10IP', 'GeneID': '609518', 'NumInteractors': 2},
#  {'GeneSymbol': 'NEFM', 'GeneID': '609412', 'NumInteractors': 12},
#  {'GeneSymbol': 'BTK', 'GeneID': '609296', 'NumInteractors': 33},
#  {'GeneSymbol': 'PRPSAP2', 'GeneID': '609284', 'NumInteractors': 5},
#  {'GeneSymbol': 'ZNF692', 'GeneID': '609234', 'NumInteractors': 22},
#  {'GeneSymbol': 'TSPYL6', 'GeneID': '609228', 'NumInteractors': 16},
#  {'GeneSymbol': 'OPCML', 'GeneID': '609220', 'NumInteractors': 1},
#  {'GeneSymbol': 'CHRND', 'GeneID': '609198', 'NumInteractors': 7},
#  {'GeneSymbol': 'FRMD1', 'GeneID': '609172', 'NumInteractors': 11},
#  {'GeneSymbol': 'CERKL', 'GeneID': '609140', 'NumInteractors': 8},
#  {'GeneSymbol': 'DFFB', 'GeneID': '609128', 'NumInteractors': 4},
#  {'GeneSymbol': 'NPAS1', 'GeneID': '609106', 'NumInteractors': 9},
#  {'GeneSymbol': 'ZIM2', 'GeneID': '609096', 'NumInteractors': 4},
#  {'GeneSymbol': 'FGF8', 'GeneID': '609082', 'NumInteractors': 5},
#  {'GeneSymbol': 'DCAF12', 'GeneID': '609076', 'NumInteractors': 2},
#  {'GeneSymbol': 'CCDC90B', 'GeneID': '609070', 'NumInteractors': 2},
#  {'GeneSymbol': 'MCUR1', 'GeneID': '609066', 'NumInteractors': 3},
#  {'GeneSymbol': 'HTR2C', 'GeneID': '608974', 'NumInteractors': 45},
#  {'GeneSymbol': 'COLQ', 'GeneID': '608946', 'NumInteractors': 6},
#  {'GeneSymbol': 'PROZ', 'GeneID': '608918', 'NumInteractors': 11},
#  {'GeneSymbol': 'VIPR1', 'GeneID': '608888', 'NumInteractors': 14},
#  {'GeneSymbol': 'FAM221B', 'GeneID': '608884', 'NumInteractors': 1},
#  {'GeneSymbol': 'ZNF704', 'GeneID': '608836', 'NumInteractors': 14},
#  {'GeneSymbol': 'PNPLA5', 'GeneID': '608832', 'NumInteractors': 1},
#  {'GeneSymbol': 'KLRG2', 'GeneID': '608796', 'NumInteractors': 12},
#  {'GeneSymbol': 'FOXD4', 'GeneID': '608788', 'NumInteractors': 10},
#  {'GeneSymbol': 'PSG8', 'GeneID': '608764', 'NumInteractors': 7},
#  {'GeneSymbol': 'NIPAL1', 'GeneID': '608712', 'NumInteractors': 25},
#  {'GeneSymbol': 'HUS1B', 'GeneID': '608662', 'NumInteractors': 9},
#  {'GeneSymbol': 'CLEC12B', 'GeneID': '608624', 'NumInteractors': 9},
#  {'GeneSymbol': 'AVIL', 'GeneID': '608614', 'NumInteractors': 3},
#  {'GeneSymbol': 'TACR1', 'GeneID': '608506', 'NumInteractors': 5},
#  {'GeneSymbol': 'P2RY1', 'GeneID': '608486', 'NumInteractors': 9},
#  {'GeneSymbol': 'TYSND1', 'GeneID': '608482', 'NumInteractors': 2},
#  {'GeneSymbol': 'UBE3D', 'GeneID': '608476', 'NumInteractors': 1},
#  {'GeneSymbol': 'AVPR2', 'GeneID': '608464', 'NumInteractors': 5},
#  {'GeneSymbol': 'GINS1', 'GeneID': '608456', 'NumInteractors': 3},
#  {'GeneSymbol': 'EFCAB11', 'GeneID': '608448', 'NumInteractors': 3},
#  {'GeneSymbol': 'BHLHE23', 'GeneID': '608434', 'NumInteractors': 5},
#  {'GeneSymbol': 'RFX3', 'GeneID': '608426', 'NumInteractors': 3},
#  {'GeneSymbol': 'GPR12', 'GeneID': '608348', 'NumInteractors': 33},
#  {'GeneSymbol': 'FGF11', 'GeneID': '608324', 'NumInteractors': 10},
#  {'GeneSymbol': 'HES6', 'GeneID': '608308', 'NumInteractors': 2},
#  {'GeneSymbol': 'ACBD6', 'GeneID': '608298', 'NumInteractors': 3},
#  {'GeneSymbol': 'RPL22', 'GeneID': '608282', 'NumInteractors': 6},
#  {'GeneSymbol': 'C19orf38', 'GeneID': '608262', 'NumInteractors': 8},
#  {'GeneSymbol': 'DNAJC25', 'GeneID': '608142', 'NumInteractors': 58},
#  {'GeneSymbol': 'CTLA4', 'GeneID': '608078', 'NumInteractors': 30},
#  {'GeneSymbol': 'FAM81A', 'GeneID': '607992', 'NumInteractors': 4},
#  {'GeneSymbol': 'PTPN4', 'GeneID': '607884', 'NumInteractors': 10},
#  {'GeneSymbol': 'COL21A1', 'GeneID': '607852', 'NumInteractors': 2},
#  {'GeneSymbol': 'CD28', 'GeneID': '607822', 'NumInteractors': 10},
#  {'GeneSymbol': 'PIWIL1', 'GeneID': '607810', 'NumInteractors': 5},
#  {'GeneSymbol': 'PIWIL4', 'GeneID': '607802', 'NumInteractors': 2},
#  {'GeneSymbol': 'SPDYC', 'GeneID': '607788', 'NumInteractors': 5},
#  {'GeneSymbol': 'IGFN1', 'GeneID': '607772', 'NumInteractors': 2},
#  {'GeneSymbol': 'C7', 'GeneID': '607760', 'NumInteractors': 2},
#  {'GeneSymbol': 'TTC16', 'GeneID': '607750', 'NumInteractors': 2},
#  {'GeneSymbol': 'RALY', 'GeneID': '607732', 'NumInteractors': 1},
#  {'GeneSymbol': 'CACNG5', 'GeneID': '607670', 'NumInteractors': 29},
#  {'GeneSymbol': 'PFKP', 'GeneID': '607666', 'NumInteractors': 1},
#  {'GeneSymbol': 'H1-7', 'GeneID': '607604', 'NumInteractors': 20},
#  {'GeneSymbol': 'IL12A', 'GeneID': '607592', 'NumInteractors': 6},
#  {'GeneSymbol': 'KIZ', 'GeneID': '607540', 'NumInteractors': 4},
#  {'GeneSymbol': 'SLC39A12', 'GeneID': '607496', 'NumInteractors': 10},
#  {'GeneSymbol': 'PMEL', 'GeneID': '607410', 'NumInteractors': 3},
#  {'GeneSymbol': 'DYNLT4', 'GeneID': '607392', 'NumInteractors': 11},
#  {'GeneSymbol': 'SPATA25', 'GeneID': '607374', 'NumInteractors': 15},
#  {'GeneSymbol': 'IFNA14', 'GeneID': '607250', 'NumInteractors': 6},
#  {'GeneSymbol': 'IFNA8', 'GeneID': '607216', 'NumInteractors': 3},
#  {'GeneSymbol': 'NAP1L5', 'GeneID': '607184', 'NumInteractors': 13},
#  {'GeneSymbol': 'ADCYAP1', 'GeneID': '607144', 'NumInteractors': 18},
#  {'GeneSymbol': 'ZNF398', 'GeneID': '607038', 'NumInteractors': 1},
#  {'GeneSymbol': 'FAM219A', 'GeneID': '606974', 'NumInteractors': 6},
#  {'GeneSymbol': 'LECT2', 'GeneID': '606966', 'NumInteractors': 3},
#  {'GeneSymbol': 'BCS1L', 'GeneID': '606810', 'NumInteractors': 8},
#  {'GeneSymbol': 'PCDH20', 'GeneID': '606738', 'NumInteractors': 24},
#  {'GeneSymbol': 'SLC6A15', 'GeneID': '606722', 'NumInteractors': 5},
#  {'GeneSymbol': 'L3MBTL1', 'GeneID': '606646', 'NumInteractors': 4},
#  {'GeneSymbol': 'LRRN2', 'GeneID': '606586', 'NumInteractors': 6},
#  {'GeneSymbol': 'NOL9', 'GeneID': '606572', 'NumInteractors': 4},
#  {'GeneSymbol': 'ALOX5', 'GeneID': '606094', 'NumInteractors': 5},
#  {'GeneSymbol': 'THEMIS', 'GeneID': '606092', 'NumInteractors': 4},
#  {'GeneSymbol': 'ESRP1', 'GeneID': '606030', 'NumInteractors': 5},
#  {'GeneSymbol': 'PRKCA', 'GeneID': '606024', 'NumInteractors': 3},
#  {'GeneSymbol': 'ACTBL2', 'GeneID': '605982', 'NumInteractors': 6},
#  {'GeneSymbol': 'CTPS2', 'GeneID': '605926', 'NumInteractors': 2},
#  {'GeneSymbol': 'MTMR7', 'GeneID': '605816', 'NumInteractors': 4},
#  {'GeneSymbol': 'TKTL2', 'GeneID': '605780', 'NumInteractors': 8},
#  {'GeneSymbol': 'CHRNA4', 'GeneID': '605612', 'NumInteractors': 54},
#  {'GeneSymbol': 'SPANXN3', 'GeneID': '605602', 'NumInteractors': 44},
#  {'GeneSymbol': 'NUAK2', 'GeneID': '605598', 'NumInteractors': 13},
#  {'GeneSymbol': 'LRRC4C', 'GeneID': '605568', 'NumInteractors': 6},
#  {'GeneSymbol': 'USP46', 'GeneID': '605482', 'NumInteractors': 42},
#  {'GeneSymbol': 'RAD21', 'GeneID': '605458', 'NumInteractors': 7},
#  {'GeneSymbol': 'RHOT2', 'GeneID': '605444', 'NumInteractors': 3},
#  {'GeneSymbol': 'ILVBL', 'GeneID': '605436', 'NumInteractors': 95},
#  {'GeneSymbol': 'RAB31', 'GeneID': '605422', 'NumInteractors': 11},
#  {'GeneSymbol': 'ACOX3', 'GeneID': '605388', 'NumInteractors': 1},
#  {'GeneSymbol': 'APLF', 'GeneID': '605300', 'NumInteractors': 21},
#  {'GeneSymbol': 'CSTF2T', 'GeneID': '605276', 'NumInteractors': 6},
#  {'GeneSymbol': 'KCNA5', 'GeneID': '605250', 'NumInteractors': 4},
#  {'GeneSymbol': 'ANKRD46', 'GeneID': '605190', 'NumInteractors': 7},
#  {'GeneSymbol': 'LINGO1', 'GeneID': '605098', 'NumInteractors': 12},
#  {'GeneSymbol': 'PCYT1A', 'GeneID': '605032', 'NumInteractors': 9},
#  {'GeneSymbol': 'BBS1', 'GeneID': '605030', 'NumInteractors': 19},
#  {'GeneSymbol': 'AMPH', 'GeneID': '605024', 'NumInteractors': 8},
#  {'GeneSymbol': 'CACNB1', 'GeneID': '605004', 'NumInteractors': 9},
#  {'GeneSymbol': 'SYN3', 'GeneID': '604980', 'NumInteractors': 4},
#  {'GeneSymbol': 'IGF2BP3', 'GeneID': '604922', 'NumInteractors': 24},
#  {'GeneSymbol': 'AMHR2', 'GeneID': '604914', 'NumInteractors': 3},
#  {'GeneSymbol': 'TMLHE', 'GeneID': '604910', 'NumInteractors': 4},
#  {'GeneSymbol': 'PPP1R16B', 'GeneID': '604870', 'NumInteractors': 3},
#  {'GeneSymbol': 'CPNE8', 'GeneID': '604864', 'NumInteractors': 1},
#  {'GeneSymbol': 'MSTO1', 'GeneID': '604854', 'NumInteractors': 6},
#  {'GeneSymbol': 'SLC22A16', 'GeneID': '604838', 'NumInteractors': 6},
#  {'GeneSymbol': 'SLU7', 'GeneID': '604726', 'NumInteractors': 3},
#  {'GeneSymbol': 'NCLN', 'GeneID': '604558', 'NumInteractors': 1},
#  {'GeneSymbol': 'NHLRC3', 'GeneID': '604514', 'NumInteractors': 4},
#  {'GeneSymbol': 'LRRTM4', 'GeneID': '604472', 'NumInteractors': 34},
#  {'GeneSymbol': 'LRRTM3', 'GeneID': '604446', 'NumInteractors': 25},
#  {'GeneSymbol': 'SMAD4', 'GeneID': '604432', 'NumInteractors': 3},
#  {'GeneSymbol': 'NUP88', 'GeneID': '604402', 'NumInteractors': 4},
#  {'GeneSymbol': 'MOGS', 'GeneID': '604316', 'NumInteractors': 8},
#  {'GeneSymbol': 'HSPA14', 'GeneID': '604248', 'NumInteractors': 2},
#  {'GeneSymbol': 'PNLIPRP2', 'GeneID': '604224', 'NumInteractors': 10},
#  {'GeneSymbol': 'MEIS2', 'GeneID': '604206', 'NumInteractors': 4},
#  {'GeneSymbol': 'TNFRSF1B', 'GeneID': '604144', 'NumInteractors': 14},
#  {'GeneSymbol': 'EDIL3', 'GeneID': '604136', 'NumInteractors': 4},
#  {'GeneSymbol': 'ZSCAN21', 'GeneID': '604122', 'NumInteractors': 6},
#  {'GeneSymbol': 'ADSS1', 'GeneID': '604116', 'NumInteractors': 3},
#  {'GeneSymbol': 'SZRD1', 'GeneID': '604086', 'NumInteractors': 8},
#  {'GeneSymbol': 'RHOC', 'GeneID': '604062', 'NumInteractors': 10},
#  {'GeneSymbol': 'CDA', 'GeneID': '603998', 'NumInteractors': 13},
#  {'GeneSymbol': 'APBA3', 'GeneID': '603990', 'NumInteractors': 13},
#  {'GeneSymbol': 'ST7L', 'GeneID': '603988', 'NumInteractors': 3},
#  {'GeneSymbol': 'TEN1', 'GeneID': '603982', 'NumInteractors': 2},
#  {'GeneSymbol': 'B2M', 'GeneID': '603964', 'NumInteractors': 7},
#  {'GeneSymbol': 'RGS3', 'GeneID': '603886', 'NumInteractors': 34},
#  {'GeneSymbol': 'RPL30', 'GeneID': '603858', 'NumInteractors': 1},
#  {'GeneSymbol': 'MVP', 'GeneID': '603848', 'NumInteractors': 4},
#  {'GeneSymbol': 'DEFA5', 'GeneID': '603792', 'NumInteractors': 26},
#  {'GeneSymbol': 'TBX18', 'GeneID': '603776', 'NumInteractors': 1},
#  {'GeneSymbol': 'HHIPL1', 'GeneID': '603748', 'NumInteractors': 14},
#  {'GeneSymbol': 'ZNF8', 'GeneID': '603734', 'NumInteractors': 5},
#  {'GeneSymbol': 'C8A', 'GeneID': '603726', 'NumInteractors': 3},
#  {'GeneSymbol': 'SGO1', 'GeneID': '603630', 'NumInteractors': 21},
#  {'GeneSymbol': 'PPP2R3A', 'GeneID': '603610', 'NumInteractors': 20},
#  {'GeneSymbol': 'MARS2', 'GeneID': '603438', 'NumInteractors': 46},
#  {'GeneSymbol': 'PLEKHN1', 'GeneID': '603424', 'NumInteractors': 6},
#  {'GeneSymbol': 'RIBC1', 'GeneID': '603262', 'NumInteractors': 15},
#  {'GeneSymbol': 'NOB1', 'GeneID': '603254', 'NumInteractors': 9},
#  {'GeneSymbol': 'FEZ1', 'GeneID': '603202', 'NumInteractors': 16},
#  {'GeneSymbol': 'CCDC89', 'GeneID': '603176', 'NumInteractors': 12},
#  {'GeneSymbol': 'RBM10', 'GeneID': '603132', 'NumInteractors': 3},
#  {'GeneSymbol': 'SPPL3', 'GeneID': '603070', 'NumInteractors': 5},
#  {'GeneSymbol': 'MMP2', 'GeneID': '603006', 'NumInteractors': 16},
#  {'GeneSymbol': 'LCOR', 'GeneID': '602950', 'NumInteractors': 2},
#  {'GeneSymbol': 'CPNE7', 'GeneID': '602822', 'NumInteractors': 7},
#  {'GeneSymbol': 'CNKSR3', 'GeneID': '602742', 'NumInteractors': 10},
#  {'GeneSymbol': 'RABGEF1', 'GeneID': '602736', 'NumInteractors': 32},
#  {'GeneSymbol': 'ZKSCAN4', 'GeneID': '602674', 'NumInteractors': 5},
#  {'GeneSymbol': 'PTH2R', 'GeneID': '602620', 'NumInteractors': 24},
#  {'GeneSymbol': 'SLC22A5', 'GeneID': '602612', 'NumInteractors': 3},
#  {'GeneSymbol': 'GPR107', 'GeneID': '602558', 'NumInteractors': 23},
#  {'GeneSymbol': 'LIN7C', 'GeneID': '602532', 'NumInteractors': 12},
#  {'GeneSymbol': 'LIN7B', 'GeneID': '602528', 'NumInteractors': 17},
#  {'GeneSymbol': 'MPP2', 'GeneID': '602512', 'NumInteractors': 9},
#  {'GeneSymbol': 'SLC22A15', 'GeneID': '602506', 'NumInteractors': 2},
#  {'GeneSymbol': 'PCCA', 'GeneID': '602502', 'NumInteractors': 5},
#  {'GeneSymbol': 'PCCB', 'GeneID': '602500', 'NumInteractors': 2},
#  {'GeneSymbol': 'RNMT', 'GeneID': '602304', 'NumInteractors': 6},
#  {'GeneSymbol': 'GK', 'GeneID': '602290', 'NumInteractors': 1},
#  {'GeneSymbol': 'DCAF12L2', 'GeneID': '602242', 'NumInteractors': 21},
#  {'GeneSymbol': 'P4HA2', 'GeneID': '602214', 'NumInteractors': 51},
#  {'GeneSymbol': 'SH2D4A', 'GeneID': '602174', 'NumInteractors': 8},
#  {'GeneSymbol': 'WRAP73', 'GeneID': '602136', 'NumInteractors': 23},
#  {'GeneSymbol': 'LRRTM1', 'GeneID': '601982', 'NumInteractors': 20},
#  {'GeneSymbol': 'TULP2', 'GeneID': '601970', 'NumInteractors': 4},
#  {'GeneSymbol': 'PLXNA4', 'GeneID': '601956', 'NumInteractors': 5},
#  {'GeneSymbol': 'LGALS3BP', 'GeneID': '601856', 'NumInteractors': 31},
#  {'GeneSymbol': 'CAMKK1', 'GeneID': '601846', 'NumInteractors': 2},
#  {'GeneSymbol': 'SCRN1', 'GeneID': '601838', 'NumInteractors': 6},
#  {'GeneSymbol': 'CYP1A1', 'GeneID': '601788', 'NumInteractors': 1},
#  {'GeneSymbol': 'OXCT2', 'GeneID': '601784', 'NumInteractors': 1},
#  {'GeneSymbol': 'HSPA2', 'GeneID': '601752', 'NumInteractors': 27},
#  {'GeneSymbol': 'SLC18A2', 'GeneID': '601640', 'NumInteractors': 35},
#  {'GeneSymbol': 'TWNK', 'GeneID': '601582', 'NumInteractors': 9},
#  {'GeneSymbol': 'CAMKV', 'GeneID': '601422', 'NumInteractors': 60},
#  {'GeneSymbol': 'SSRP1', 'GeneID': '601374', 'NumInteractors': 8},
#  {'GeneSymbol': 'NMD3', 'GeneID': '601296', 'NumInteractors': 1},
#  {'GeneSymbol': 'CSNK1G2', 'GeneID': '601198', 'NumInteractors': 4},
#  {'GeneSymbol': 'ZNF785', 'GeneID': '601132', 'NumInteractors': 21},
#  {'GeneSymbol': 'ZNF331', 'GeneID': '601114', 'NumInteractors': 8},
#  {'GeneSymbol': 'CRYAB', 'GeneID': '601064', 'NumInteractors': 7},
#  {'GeneSymbol': 'HSPBP1', 'GeneID': '601044', 'NumInteractors': 9},
#  {'GeneSymbol': 'WNT4', 'GeneID': '600998', 'NumInteractors': 8},
#  {'GeneSymbol': 'CAPNS2', 'GeneID': '600984', 'NumInteractors': 5},
#  {'GeneSymbol': 'CAPN2', 'GeneID': '600926', 'NumInteractors': 9},
#  {'GeneSymbol': 'ABI3', 'GeneID': '600840', 'NumInteractors': 28},
#  {'GeneSymbol': 'SCYL3', 'GeneID': '600772', 'NumInteractors': 11},
#  {'GeneSymbol': 'SCGB2A1', 'GeneID': '600762', 'NumInteractors': 4},
#  {'GeneSymbol': 'HCST', 'GeneID': '600746', 'NumInteractors': 7},
#  {'GeneSymbol': 'ZNF689', 'GeneID': '600676', 'NumInteractors': 4},
#  {'GeneSymbol': 'EHD2', 'GeneID': '600664', 'NumInteractors': 4},
#  {'GeneSymbol': 'SERPIND1', 'GeneID': '600656', 'NumInteractors': 3},
#  {'GeneSymbol': 'NONO', 'GeneID': '600632', 'NumInteractors': 8},
#  {'GeneSymbol': 'SPINT1', 'GeneID': '600588', 'NumInteractors': 13},
#  {'GeneSymbol': 'ZNF212', 'GeneID': '600586', 'NumInteractors': 1},
#  {'GeneSymbol': 'ARHGAP19', 'GeneID': '600468', 'NumInteractors': 3},
#  {'GeneSymbol': 'MECP2', 'GeneID': '600290', 'NumInteractors': 12},
#  {'GeneSymbol': 'SETD6', 'GeneID': '600094', 'NumInteractors': 14},
#  {'GeneSymbol': 'HTR3A', 'GeneID': '600046', 'NumInteractors': 17},
#  {'GeneSymbol': 'OLFM4', 'GeneID': '599994', 'NumInteractors': 31},
#  {'GeneSymbol': 'NECTIN2', 'GeneID': '599988', 'NumInteractors': 3},
#  {'GeneSymbol': 'FOXN3', 'GeneID': '599956', 'NumInteractors': 14},
#  {'GeneSymbol': 'EEF1A2', 'GeneID': '599840', 'NumInteractors': 12},
#  {'GeneSymbol': 'MAPK9', 'GeneID': '599752', 'NumInteractors': 3},
#  {'GeneSymbol': 'SERPINA4', 'GeneID': '599696', 'NumInteractors': 14},
#  {'GeneSymbol': 'ACVR2B', 'GeneID': '599684', 'NumInteractors': 7},
#  {'GeneSymbol': 'TIMM50', 'GeneID': '599678', 'NumInteractors': 2},
#  {'GeneSymbol': 'PIK3R3', 'GeneID': '599636', 'NumInteractors': 14},
#  {'GeneSymbol': 'TUBB3', 'GeneID': '599628', 'NumInteractors': 3},
#  {'GeneSymbol': 'PACSIN1', 'GeneID': '599588', 'NumInteractors': 15},
#  {'GeneSymbol': 'RXYLT1', 'GeneID': '599584', 'NumInteractors': 2},
#  {'GeneSymbol': 'TLNRD1', 'GeneID': '599420', 'NumInteractors': 12},
#  {'GeneSymbol': 'GPKOW', 'GeneID': '599384', 'NumInteractors': 7},
#  {'GeneSymbol': 'CCKBR', 'GeneID': '599260', 'NumInteractors': 27},
#  {'GeneSymbol': 'TUBG2', 'GeneID': '599200', 'NumInteractors': 14},
#  {'GeneSymbol': 'C10orf88', 'GeneID': '599174', 'NumInteractors': 10},
#  {'GeneSymbol': 'CLU', 'GeneID': '599156', 'NumInteractors': 10},
#  {'GeneSymbol': 'TCP11L2', 'GeneID': '599150', 'NumInteractors': 2},
#  {'GeneSymbol': 'TUBA4A', 'GeneID': '599132', 'NumInteractors': 9},
#  {'GeneSymbol': 'DCAF4L1', 'GeneID': '599062', 'NumInteractors': 18},
#  {'GeneSymbol': 'STARD3', 'GeneID': '599044', 'NumInteractors': 4},
#  {'GeneSymbol': 'GABRD', 'GeneID': '599032', 'NumInteractors': 5},
#  {'GeneSymbol': 'TUBA1C', 'GeneID': '598992', 'NumInteractors': 17},
#  {'GeneSymbol': 'PHAF1', 'GeneID': '598942', 'NumInteractors': 14},
#  {'GeneSymbol': 'FAM241A', 'GeneID': '598878', 'NumInteractors': 17},
#  {'GeneSymbol': 'VIPR2', 'GeneID': '598768', 'NumInteractors': 78},
#  {'GeneSymbol': 'P2RX6', 'GeneID': '598760', 'NumInteractors': 3},
#  {'GeneSymbol': 'MICU2', 'GeneID': '598752', 'NumInteractors': 5},
#  {'GeneSymbol': 'LILRB4', 'GeneID': '598740', 'NumInteractors': 13},
#  {'GeneSymbol': 'PLTP', 'GeneID': '598736', 'NumInteractors': 7},
#  {'GeneSymbol': 'DBNL', 'GeneID': '598722', 'NumInteractors': 6},
#  {'GeneSymbol': 'EVA1C', 'GeneID': '598530', 'NumInteractors': 33},
#  {'GeneSymbol': 'LTBR', 'GeneID': '598524', 'NumInteractors': 2},
#  {'GeneSymbol': 'WNT3A', 'GeneID': '598492', 'NumInteractors': 14},
#  {'GeneSymbol': 'ARRDC1', 'GeneID': '598460', 'NumInteractors': 16},
#  {'GeneSymbol': 'PSG3', 'GeneID': '598240', 'NumInteractors': 14},
#  {'GeneSymbol': 'TAB1', 'GeneID': '598210', 'NumInteractors': 8},
#  {'GeneSymbol': 'NICN1', 'GeneID': '598182', 'NumInteractors': 9},
#  {'GeneSymbol': 'LRRC49', 'GeneID': '598172', 'NumInteractors': 12},
#  {'GeneSymbol': 'SYT1', 'GeneID': '598034', 'NumInteractors': 34},
#  {'GeneSymbol': 'SYT2', 'GeneID': '598010', 'NumInteractors': 64},
#  {'GeneSymbol': 'PTGER3', 'GeneID': '598000', 'NumInteractors': 4},
#  {'GeneSymbol': 'TERF1', 'GeneID': '597980', 'NumInteractors': 7},
#  {'GeneSymbol': 'SKA3', 'GeneID': '597880', 'NumInteractors': 7},
#  {'GeneSymbol': 'PPP2R2C', 'GeneID': '597850', 'NumInteractors': 27},
#  {'GeneSymbol': 'CHST9', 'GeneID': '597770', 'NumInteractors': 10},
#  {'GeneSymbol': 'ISLR', 'GeneID': '597748', 'NumInteractors': 12},
#  {'GeneSymbol': 'TTLL1', 'GeneID': '597742', 'NumInteractors': 14},
#  {'GeneSymbol': 'XPA', 'GeneID': '597502', 'NumInteractors': 11},
#  {'GeneSymbol': 'FASLG', 'GeneID': '597464', 'NumInteractors': 18},
#  {'GeneSymbol': 'IVD', 'GeneID': '597454', 'NumInteractors': 1},
#  {'GeneSymbol': 'SIRT5', 'GeneID': '597450', 'NumInteractors': 4},
#  {'GeneSymbol': 'IL2RG', 'GeneID': '597398', 'NumInteractors': 14},
#  {'GeneSymbol': 'SERPINA10', 'GeneID': '597392', 'NumInteractors': 2},
#  {'GeneSymbol': 'PIM1', 'GeneID': '597032', 'NumInteractors': 48},
#  {'GeneSymbol': 'RHOBTB3', 'GeneID': '596858', 'NumInteractors': 5},
#  {'GeneSymbol': 'CHIA', 'GeneID': '596818', 'NumInteractors': 17},
#  {'GeneSymbol': 'MMP3', 'GeneID': '596676', 'NumInteractors': 14},
#  {'GeneSymbol': 'VEGFB', 'GeneID': '596650', 'NumInteractors': 12},
#  {'GeneSymbol': 'TUBB1', 'GeneID': '596600', 'NumInteractors': 6},
#  {'GeneSymbol': 'IFT70A', 'GeneID': '596300', 'NumInteractors': 15},
#  {'GeneSymbol': 'IFT57', 'GeneID': '596278', 'NumInteractors': 38},
#  {'GeneSymbol': 'B3GALT2', 'GeneID': '596166', 'NumInteractors': 5},
#  {'GeneSymbol': 'ZDHHC11', 'GeneID': '596044', 'NumInteractors': 56},
#  {'GeneSymbol': 'EDNRA', 'GeneID': '596028', 'NumInteractors': 2},
#  {'GeneSymbol': 'PRXL2A', 'GeneID': '595892', 'NumInteractors': 1},
#  {'GeneSymbol': 'GBP1', 'GeneID': '595624', 'NumInteractors': 2},
#  {'GeneSymbol': 'KNG1', 'GeneID': '595502', 'NumInteractors': 6},
#  {'GeneSymbol': 'ANXA9', 'GeneID': '595460', 'NumInteractors': 1},
#  {'GeneSymbol': 'SMPD2', 'GeneID': '595390', 'NumInteractors': 274},
#  {'GeneSymbol': 'RELT', 'GeneID': '595376', 'NumInteractors': 6},
#  {'GeneSymbol': 'WIPI2', 'GeneID': '595372', 'NumInteractors': 14},
#  {'GeneSymbol': 'TEX28', 'GeneID': '595182', 'NumInteractors': 14},
#  {'GeneSymbol': 'EMID1', 'GeneID': '595116', 'NumInteractors': 30},
#  {'GeneSymbol': 'ACTL6B', 'GeneID': '594948', 'NumInteractors': 10},
#  {'GeneSymbol': 'SLC30A4', 'GeneID': '594892', 'NumInteractors': 26},
#  {'GeneSymbol': 'ZNF764', 'GeneID': '594698', 'NumInteractors': 8},
#  {'GeneSymbol': 'PRMT2', 'GeneID': '594660', 'NumInteractors': 17},
#  {'GeneSymbol': 'ARRDC3', 'GeneID': '594570', 'NumInteractors': 19},
#  {'GeneSymbol': 'SNAP91', 'GeneID': '594550', 'NumInteractors': 12},
#  {'GeneSymbol': 'STAMBPL1', 'GeneID': '594544', 'NumInteractors': 9},
#  {'GeneSymbol': 'ARFGAP1', 'GeneID': '594520', 'NumInteractors': 11},
#  {'GeneSymbol': 'FUZ', 'GeneID': '594492', 'NumInteractors': 12},
#  {'GeneSymbol': 'SERPINF1', 'GeneID': '594484', 'NumInteractors': 3},
#  {'GeneSymbol': 'CASP5', 'GeneID': '594480', 'NumInteractors': 1},
#  {'GeneSymbol': 'KCNJ5', 'GeneID': '594468', 'NumInteractors': 3},
#  {'GeneSymbol': 'FAM110B', 'GeneID': '594368', 'NumInteractors': 15},
#  {'GeneSymbol': 'DVL2', 'GeneID': '594318', 'NumInteractors': 20},
#  {'GeneSymbol': 'PDIA6', 'GeneID': '594260', 'NumInteractors': 2},
#  {'GeneSymbol': 'RRM2', 'GeneID': '594244', 'NumInteractors': 5},
#  {'GeneSymbol': 'STK25', 'GeneID': '594218', 'NumInteractors': 26},
#  {'GeneSymbol': 'CARNMT1', 'GeneID': '594170', 'NumInteractors': 16},
#  {'GeneSymbol': 'IKZF5', 'GeneID': '594166', 'NumInteractors': 3},
#  {'GeneSymbol': 'SYT12', 'GeneID': '594152', 'NumInteractors': 7},
#  {'GeneSymbol': 'MIA2', 'GeneID': '594108', 'NumInteractors': 18},
#  {'GeneSymbol': 'CCR6', 'GeneID': '594008', 'NumInteractors': 21},
#  {'GeneSymbol': 'SDR16C5', 'GeneID': '593974', 'NumInteractors': 2},
#  {'GeneSymbol': 'BMP4', 'GeneID': '593916', 'NumInteractors': 38},
#  {'GeneSymbol': 'SEC23B', 'GeneID': '593906', 'NumInteractors': 10},
#  {'GeneSymbol': 'EIF4A3', 'GeneID': '593902', 'NumInteractors': 5},
#  {'GeneSymbol': 'RAD23B', 'GeneID': '593882', 'NumInteractors': 7},
#  {'GeneSymbol': 'WSB2', 'GeneID': '593864', 'NumInteractors': 8},
#  {'GeneSymbol': 'BMT2', 'GeneID': '593852', 'NumInteractors': 3},
#  {'GeneSymbol': 'VTN', 'GeneID': '593784', 'NumInteractors': 26},
#  {'GeneSymbol': 'FAXC', 'GeneID': '593768', 'NumInteractors': 40},
#  {'GeneSymbol': 'ARL13B', 'GeneID': '593688', 'NumInteractors': 15},
#  {'GeneSymbol': 'GPR182', 'GeneID': '593636', 'NumInteractors': 59},
#  {'GeneSymbol': 'NCEH1', 'GeneID': '593522', 'NumInteractors': 5},
#  {'GeneSymbol': 'TOR3A', 'GeneID': '593424', 'NumInteractors': 8},
#  {'GeneSymbol': 'ESS2', 'GeneID': '593406', 'NumInteractors': 22},
#  {'GeneSymbol': 'YJU2B', 'GeneID': '593384', 'NumInteractors': 16},
#  {'GeneSymbol': 'CX3CL1', 'GeneID': '593372', 'NumInteractors': 5},
#  {'GeneSymbol': 'RTCA', 'GeneID': '593362', 'NumInteractors': 6},
#  {'GeneSymbol': 'GPAT4', 'GeneID': '593272', 'NumInteractors': 3},
#  {'GeneSymbol': 'VSIG4', 'GeneID': '593188', 'NumInteractors': 80},
#  {'GeneSymbol': 'ENPP6', 'GeneID': '593150', 'NumInteractors': 12},
#  {'GeneSymbol': 'TRIM10', 'GeneID': '593090', 'NumInteractors': 19},
#  {'GeneSymbol': 'ACAA2', 'GeneID': '593086', 'NumInteractors': 3},
#  {'GeneSymbol': 'MAT1A', 'GeneID': '593078', 'NumInteractors': 2},
#  {'GeneSymbol': 'SLC35F6', 'GeneID': '592988', 'NumInteractors': 11},
#  {'GeneSymbol': 'EDA', 'GeneID': '592950', 'NumInteractors': 37},
#  {'GeneSymbol': 'ERF', 'GeneID': '592820', 'NumInteractors': 78},
#  {'GeneSymbol': 'BTBD9', 'GeneID': '592808', 'NumInteractors': 6},
#  {'GeneSymbol': 'UBXN6', 'GeneID': '592786', 'NumInteractors': 14},
#  {'GeneSymbol': 'EDEM2', 'GeneID': '592776', 'NumInteractors': 31},
#  {'GeneSymbol': 'WNT10B', 'GeneID': '592564', 'NumInteractors': 31},
#  {'GeneSymbol': 'NPRL2', 'GeneID': '592478', 'NumInteractors': 6},
#  {'GeneSymbol': 'NPRL3', 'GeneID': '592472', 'NumInteractors': 4},
#  {'GeneSymbol': 'FBLN7', 'GeneID': '592368', 'NumInteractors': 13},
#  {'GeneSymbol': 'NCK1', 'GeneID': '592336', 'NumInteractors': 42},
#  {'GeneSymbol': 'MANSC1', 'GeneID': '592288', 'NumInteractors': 6},
#  {'GeneSymbol': 'IKZF1', 'GeneID': '592274', 'NumInteractors': 28},
#  {'GeneSymbol': 'LMX1B', 'GeneID': '592266', 'NumInteractors': 6},
#  {'GeneSymbol': 'APLNR', 'GeneID': '592112', 'NumInteractors': 33},
#  {'GeneSymbol': 'CD55', 'GeneID': '592082', 'NumInteractors': 7},
#  {'GeneSymbol': 'NELFE', 'GeneID': '592046', 'NumInteractors': 5},
#  {'GeneSymbol': 'IL13RA2', 'GeneID': '592014', 'NumInteractors': 14},
#  {'GeneSymbol': 'PRELP', 'GeneID': '592006', 'NumInteractors': 3},
#  {'GeneSymbol': 'S1PR4', 'GeneID': '591968', 'NumInteractors': 17},
#  {'GeneSymbol': 'DCP2', 'GeneID': '591950', 'NumInteractors': 11},
#  {'GeneSymbol': 'SARS2', 'GeneID': '591892', 'NumInteractors': 9},
#  {'GeneSymbol': 'IL12RB1', 'GeneID': '591856', 'NumInteractors': 24},
#  {'GeneSymbol': 'RCL1', 'GeneID': '591842', 'NumInteractors': 1},
#  {'GeneSymbol': 'CMKLR1', 'GeneID': '591800', 'NumInteractors': 12},
#  {'GeneSymbol': 'PDGFRL', 'GeneID': '591778', 'NumInteractors': 11},
#  {'GeneSymbol': 'TPST2', 'GeneID': '591748', 'NumInteractors': 15},
#  {'GeneSymbol': 'WIF1', 'GeneID': '591672', 'NumInteractors': 3},
#  {'GeneSymbol': 'WDR20', 'GeneID': '591624', 'NumInteractors': 13},
#  {'GeneSymbol': 'VSX1', 'GeneID': '591600', 'NumInteractors': 17},
#  {'GeneSymbol': 'ZDHHC9', 'GeneID': '591576', 'NumInteractors': 11},
#  {'GeneSymbol': 'ARMCX3', 'GeneID': '591564', 'NumInteractors': 5},
#  {'GeneSymbol': 'CARD9', 'GeneID': '591556', 'NumInteractors': 8},
#  {'GeneSymbol': 'KCNA2', 'GeneID': '591516', 'NumInteractors': 24},
#  {'GeneSymbol': 'DNASE2B', 'GeneID': '591488', 'NumInteractors': 12},
#  {'GeneSymbol': 'MAGEB3', 'GeneID': '591368', 'NumInteractors': 9},
#  {'GeneSymbol': 'HOOK3', 'GeneID': '591350', 'NumInteractors': 8},
#  {'GeneSymbol': 'CD200R1', 'GeneID': '591322', 'NumInteractors': 20},
#  {'GeneSymbol': 'HIRIP3', 'GeneID': '591298', 'NumInteractors': 17},
#  {'GeneSymbol': 'HDGFL2', 'GeneID': '591274', 'NumInteractors': 50},
#  {'GeneSymbol': 'FXR2', 'GeneID': '591246', 'NumInteractors': 7},
#  {'GeneSymbol': 'LYPD3', 'GeneID': '591210', 'NumInteractors': 13},
#  {'GeneSymbol': 'HLA-E', 'GeneID': '591206', 'NumInteractors': 3},
#  {'GeneSymbol': 'ATXN7L3', 'GeneID': '591142', 'NumInteractors': 24},
#  {'GeneSymbol': 'DUSP16', 'GeneID': '591132', 'NumInteractors': 1},
#  {'GeneSymbol': 'MAPKAPK2', 'GeneID': '591110', 'NumInteractors': 6},
#  {'GeneSymbol': 'DTX3', 'GeneID': '591076', 'NumInteractors': 21},
#  {'GeneSymbol': 'A2M', 'GeneID': '591050', 'NumInteractors': 14},
#  {'GeneSymbol': 'ZYX', 'GeneID': '591024', 'NumInteractors': 9},
#  {'GeneSymbol': 'AGA', 'GeneID': '591004', 'NumInteractors': 1},
#  {'GeneSymbol': 'TMEM185A', 'GeneID': '591002', 'NumInteractors': 5},
#  {'GeneSymbol': 'QPCT', 'GeneID': '590996', 'NumInteractors': 2},
#  {'GeneSymbol': 'P2RY8', 'GeneID': '590884', 'NumInteractors': 52},
#  {'GeneSymbol': 'ASB4', 'GeneID': '590858', 'NumInteractors': 12},
#  {'GeneSymbol': 'SKAP1', 'GeneID': '590840', 'NumInteractors': 8},
#  {'GeneSymbol': 'MAPK13', 'GeneID': '590824', 'NumInteractors': 5},
#  {'GeneSymbol': 'SFRP4', 'GeneID': '590704', 'NumInteractors': 4},
#  {'GeneSymbol': 'KCTD9', 'GeneID': '590674', 'NumInteractors': 13},
#  {'GeneSymbol': 'MAT2B', 'GeneID': '590656', 'NumInteractors': 4},
#  {'GeneSymbol': 'LDHC', 'GeneID': '590642', 'NumInteractors': 7},
#  {'GeneSymbol': 'IFT81', 'GeneID': '590584', 'NumInteractors': 13},
#  {'GeneSymbol': 'IFT70B', 'GeneID': '590570', 'NumInteractors': 20},
#  {'GeneSymbol': 'TMEM25', 'GeneID': '590456', 'NumInteractors': 19},
#  {'GeneSymbol': 'SEPTIN11', 'GeneID': '590420', 'NumInteractors': 12},
#  {'GeneSymbol': 'ACP5', 'GeneID': '590380', 'NumInteractors': 9},
#  {'GeneSymbol': 'SSBP2', 'GeneID': '590334', 'NumInteractors': 21},
#  {'GeneSymbol': 'P2RY10', 'GeneID': '590314', 'NumInteractors': 9},
#  {'GeneSymbol': 'PRRT2', 'GeneID': '590274', 'NumInteractors': 18},
#  {'GeneSymbol': 'BCL2L12', 'GeneID': '590260', 'NumInteractors': 6},
#  {'GeneSymbol': 'ZNF24', 'GeneID': '590238', 'NumInteractors': 21},
#  {'GeneSymbol': 'ZNF396', 'GeneID': '590236', 'NumInteractors': 8},
#  {'GeneSymbol': 'STK16', 'GeneID': '590210', 'NumInteractors': 3},
#  {'GeneSymbol': 'SPRY4', 'GeneID': '590202', 'NumInteractors': 2},
#  {'GeneSymbol': 'LDLRAD4', 'GeneID': '590120', 'NumInteractors': 13},
#  {'GeneSymbol': 'GTF2E2', 'GeneID': '590112', 'NumInteractors': 3},
#  {'GeneSymbol': 'SYP', 'GeneID': '589954', 'NumInteractors': 30},
#  {'GeneSymbol': 'ANGPTL2', 'GeneID': '589856', 'NumInteractors': 9},
#  {'GeneSymbol': 'POMK', 'GeneID': '589814', 'NumInteractors': 14},
#  {'GeneSymbol': 'TCTN2', 'GeneID': '589772', 'NumInteractors': 10},
#  {'GeneSymbol': 'IL31RA', 'GeneID': '589748', 'NumInteractors': 3},
#  {'GeneSymbol': 'MINDY3', 'GeneID': '589414', 'NumInteractors': 3},
#  {'GeneSymbol': 'PRKAA1', 'GeneID': '589402', 'NumInteractors': 9},
#  {'GeneSymbol': 'NUP50', 'GeneID': '589356', 'NumInteractors': 15},
#  {'GeneSymbol': 'CD244', 'GeneID': '589322', 'NumInteractors': 15},
#  {'GeneSymbol': 'CSNK1G3', 'GeneID': '589276', 'NumInteractors': 7},
#  {'GeneSymbol': 'GTSE1', 'GeneID': '589234', 'NumInteractors': 11},
#  {'GeneSymbol': 'ARMCX1', 'GeneID': '588872', 'NumInteractors': 7},
#  {'GeneSymbol': 'PPARD', 'GeneID': '588868', 'NumInteractors': 3},
#  {'GeneSymbol': 'B3GNT3', 'GeneID': '588862', 'NumInteractors': 1},
#  {'GeneSymbol': 'MISP', 'GeneID': '588798', 'NumInteractors': 11},
#  {'GeneSymbol': 'SLC39A4', 'GeneID': '588664', 'NumInteractors': 39},
#  {'GeneSymbol': 'STBD1', 'GeneID': '588632', 'NumInteractors': 11},
#  {'GeneSymbol': 'ANTXR1', 'GeneID': '588620', 'NumInteractors': 11},
#  {'GeneSymbol': 'DCN', 'GeneID': '588606', 'NumInteractors': 5},
#  {'GeneSymbol': 'POLG2', 'GeneID': '588600', 'NumInteractors': 10},
#  {'GeneSymbol': 'SDF4', 'GeneID': '588594', 'NumInteractors': 10},
#  {'GeneSymbol': 'HAUS7', 'GeneID': '588590', 'NumInteractors': 23},
#  {'GeneSymbol': 'CDK9', 'GeneID': '588564', 'NumInteractors': 9},
#  {'GeneSymbol': 'SEPTIN7', 'GeneID': '588532', 'NumInteractors': 12},
#  {'GeneSymbol': 'CDC42EP4', 'GeneID': '588520', 'NumInteractors': 9},
#  {'GeneSymbol': 'NDRG2', 'GeneID': '588506', 'NumInteractors': 6},
#  {'GeneSymbol': 'ASH2L', 'GeneID': '588428', 'NumInteractors': 33},
#  {'GeneSymbol': 'CXXC1', 'GeneID': '588422', 'NumInteractors': 9},
#  {'GeneSymbol': 'DND1', 'GeneID': '588180', 'NumInteractors': 100},
#  {'GeneSymbol': 'CORO2B', 'GeneID': '588168', 'NumInteractors': 30},
#  {'GeneSymbol': 'DBN1', 'GeneID': '588146', 'NumInteractors': 19},
#  {'GeneSymbol': 'CNN3', 'GeneID': '588142', 'NumInteractors': 12},
#  {'GeneSymbol': 'CHST10', 'GeneID': '588122', 'NumInteractors': 3},
#  {'GeneSymbol': 'VEGFD', 'GeneID': '588074', 'NumInteractors': 5},
#  {'GeneSymbol': 'RNF146', 'GeneID': '588036', 'NumInteractors': 12},
#  {'GeneSymbol': 'BAG5', 'GeneID': '587982', 'NumInteractors': 6},
#  {'GeneSymbol': 'PRKACG', 'GeneID': '587946', 'NumInteractors': 8},
#  {'GeneSymbol': 'CEACAM8', 'GeneID': '587912', 'NumInteractors': 8},
#  {'GeneSymbol': 'PDCD2L', 'GeneID': '587902', 'NumInteractors': 9},
#  {'GeneSymbol': 'FPR2', 'GeneID': '587872', 'NumInteractors': 15},
#  {'GeneSymbol': 'STAT2', 'GeneID': '587684', 'NumInteractors': 14},
#  {'GeneSymbol': 'GFPT2', 'GeneID': '587654', 'NumInteractors': 11},
#  {'GeneSymbol': 'FPR1', 'GeneID': '587602', 'NumInteractors': 122},
#  {'GeneSymbol': 'PURG', 'GeneID': '587524', 'NumInteractors': 8},
#  {'GeneSymbol': 'MOAP1', 'GeneID': '587494', 'NumInteractors': 13},
#  {'GeneSymbol': 'KHDRBS2', 'GeneID': '587454', 'NumInteractors': 9},
#  {'GeneSymbol': 'HEXIM1', 'GeneID': '587436', 'NumInteractors': 14},
#  {'GeneSymbol': 'ZNF843', 'GeneID': '587424', 'NumInteractors': 4},
# ...
#  {'GeneSymbol': 'FNTA', 'GeneID': '584394', 'NumInteractors': 12},
#  {'GeneSymbol': 'EMC3', 'GeneID': '584348', 'NumInteractors': 15},
#  {'GeneSymbol': 'DNASE2', 'GeneID': '584188', 'NumInteractors': 8},
#  {'GeneSymbol': 'FBXO6', 'GeneID': '584182', 'NumInteractors': 84},
#  {'GeneSymbol': 'ABCF3', 'GeneID': '583994', 'NumInteractors': 20},
#  {'GeneSymbol': 'NELFA', 'GeneID': '583942', 'NumInteractors': 5},
#  {'GeneSymbol': 'NT5C', 'GeneID': '583820', 'NumInteractors': 2},
#  {'GeneSymbol': 'ARG2', 'GeneID': '583636', 'NumInteractors': 1},
#  {'GeneSymbol': 'DRG2', 'GeneID': '583608', 'NumInteractors': 3},
#  {'GeneSymbol': 'PAPOLA', 'GeneID': '583586', 'NumInteractors': 2},
#  {'GeneSymbol': 'VENTX', 'GeneID': '583364', 'NumInteractors': 329},
#  {'GeneSymbol': 'MTX2', 'GeneID': '583340', 'NumInteractors': 16},
#  {'GeneSymbol': 'SCGB1D1', 'GeneID': '583292', 'NumInteractors': 20},
#  {'GeneSymbol': 'CYB5D2', 'GeneID': '583204', 'NumInteractors': 13},
#  {'GeneSymbol': 'TRIM16L', 'GeneID': '583182', 'NumInteractors': 18},
#  {'GeneSymbol': 'CCDC96', 'GeneID': '583128', 'NumInteractors': 17},
#  {'GeneSymbol': 'CELA3A', 'GeneID': '583058', 'NumInteractors': 20},
#  {'GeneSymbol': 'INTS6', 'GeneID': '583050', 'NumInteractors': 16},
#  {'GeneSymbol': 'C6orf141', 'GeneID': '583018', 'NumInteractors': 17},
#  {'GeneSymbol': 'EIF4E2', 'GeneID': '583000', 'NumInteractors': 7},
#  {'GeneSymbol': 'CCDC103', 'GeneID': '582992', 'NumInteractors': 3},
#  {'GeneSymbol': 'TNFRSF13B', 'GeneID': '582940', 'NumInteractors': 23},
#  {'GeneSymbol': 'METTL9', 'GeneID': '582936', 'NumInteractors': 38},
#  {'GeneSymbol': 'TOR1B', 'GeneID': '582918', 'NumInteractors': 14},
#  {'GeneSymbol': 'TOR1A', 'GeneID': '582916', 'NumInteractors': 12},
#  {'GeneSymbol': 'PEX7', 'GeneID': '582908', 'NumInteractors': 182},
#  {'GeneSymbol': 'GRPEL2', 'GeneID': '582896', 'NumInteractors': 5},
#  {'GeneSymbol': 'SFRP2', 'GeneID': '582742', 'NumInteractors': 4},
#  {'GeneSymbol': 'PRR3', 'GeneID': '582668', 'NumInteractors': 70},
#  {'GeneSymbol': 'CD274', 'GeneID': '582638', 'NumInteractors': 6},
#  {'GeneSymbol': 'NOP53', 'GeneID': '582630', 'NumInteractors': 11},
#  {'GeneSymbol': 'DTNA', 'GeneID': '582584', 'NumInteractors': 5},
#  {'GeneSymbol': 'MBIP', 'GeneID': '582572', 'NumInteractors': 16},
#  {'GeneSymbol': 'LCP1', 'GeneID': '582480', 'NumInteractors': 8},
#  {'GeneSymbol': 'SPACA1', 'GeneID': '582476', 'NumInteractors': 4},
#  {'GeneSymbol': 'DOK3', 'GeneID': '582464', 'NumInteractors': 4},
#  {'GeneSymbol': 'DHDH', 'GeneID': '582444', 'NumInteractors': 9},
#  {'GeneSymbol': 'EGFL8', 'GeneID': '582320', 'NumInteractors': 23},
#  {'GeneSymbol': 'ITLN2', 'GeneID': '582306', 'NumInteractors': 7},
#  {'GeneSymbol': 'MAGEA10', 'GeneID': '582270', 'NumInteractors': 86},
#  {'GeneSymbol': 'RNF166', 'GeneID': '582232', 'NumInteractors': 18},
#  {'GeneSymbol': 'TMEM171', 'GeneID': '582214', 'NumInteractors': 22},
#  {'GeneSymbol': 'CCNDBP1', 'GeneID': '582184', 'NumInteractors': 2},
#  {'GeneSymbol': 'ACOT8', 'GeneID': '582156', 'NumInteractors': 8},
#  {'GeneSymbol': 'FAF2', 'GeneID': '582150', 'NumInteractors': 23},
#  {'GeneSymbol': 'GET3', 'GeneID': '582136', 'NumInteractors': 9},
#  {'GeneSymbol': 'NPDC1', 'GeneID': '582132', 'NumInteractors': 1},
#  {'GeneSymbol': 'UFM1', 'GeneID': '582054', 'NumInteractors': 3},
#  {'GeneSymbol': 'TSPAN15', 'GeneID': '582020', 'NumInteractors': 2},
#  {'GeneSymbol': 'TMEM231', 'GeneID': '582002', 'NumInteractors': 8},
#  {'GeneSymbol': 'KCTD13', 'GeneID': '581992', 'NumInteractors': 8},
#  {'GeneSymbol': 'ZNF414', 'GeneID': '581956', 'NumInteractors': 8},
#  {'GeneSymbol': 'TEX264', 'GeneID': '581936', 'NumInteractors': 13},
#  {'GeneSymbol': 'SLC25A11', 'GeneID': '581924', 'NumInteractors': 5},
#  {'GeneSymbol': 'UBA5', 'GeneID': '581906', 'NumInteractors': 13},
#  {'GeneSymbol': 'PTGR3', 'GeneID': '581886', 'NumInteractors': 13},
#  {'GeneSymbol': 'AMMECR1L', 'GeneID': '581878', 'NumInteractors': 6},
#  {'GeneSymbol': 'FGL1', 'GeneID': '581838', 'NumInteractors': 36},
#  {'GeneSymbol': 'THAP7', 'GeneID': '581832', 'NumInteractors': 2},
#  {'GeneSymbol': 'WDR83', 'GeneID': '581750', 'NumInteractors': 34},
#  {'GeneSymbol': 'LUC7L2', 'GeneID': '581738', 'NumInteractors': 52},
#  {'GeneSymbol': 'CCNL1', 'GeneID': '581720', 'NumInteractors': 14},
#  {'GeneSymbol': 'CCNL2', 'GeneID': '581650', 'NumInteractors': 12},
#  {'GeneSymbol': 'SRSF4', 'GeneID': '581570', 'NumInteractors': 8},
#  {'GeneSymbol': 'PIP4K2A', 'GeneID': '581534', 'NumInteractors': 63},
#  {'GeneSymbol': 'DNAJC17', 'GeneID': '581484', 'NumInteractors': 1},
#  {'GeneSymbol': 'CCDC6', 'GeneID': '581450', 'NumInteractors': 10},
#  {'GeneSymbol': 'LIME1', 'GeneID': '581414', 'NumInteractors': 5},
#  {'GeneSymbol': 'SFR1', 'GeneID': '581406', 'NumInteractors': 3},
#  {'GeneSymbol': 'SGTB', 'GeneID': '581266', 'NumInteractors': 3},
#  {'GeneSymbol': 'NMNAT2', 'GeneID': '581228', 'NumInteractors': 9},
#  {'GeneSymbol': 'DNASE1L1', 'GeneID': '581194', 'NumInteractors': 15},
#  {'GeneSymbol': 'CGREF1', 'GeneID': '581180', 'NumInteractors': 8},
#  {'GeneSymbol': 'TECR', 'GeneID': '581176', 'NumInteractors': 1},
#  {'GeneSymbol': 'CRNN', 'GeneID': '581158', 'NumInteractors': 8},
#  {'GeneSymbol': 'EPS8L1', 'GeneID': '581128', 'NumInteractors': 21},
#  {'GeneSymbol': 'ALDH3A1', 'GeneID': '581064', 'NumInteractors': 6},
#  {'GeneSymbol': 'RSRP1', 'GeneID': '580976', 'NumInteractors': 77},
#  {'GeneSymbol': 'CCND1', 'GeneID': '580902', 'NumInteractors': 7},
#  {'GeneSymbol': 'ANKRD44', 'GeneID': '580822', 'NumInteractors': 15},
#  {'GeneSymbol': 'TNFRSF6B', 'GeneID': '580750', 'NumInteractors': 11},
#  {'GeneSymbol': 'ASB9', 'GeneID': '580696', 'NumInteractors': 24},
#  {'GeneSymbol': 'CEACAM21', 'GeneID': '580688', 'NumInteractors': 3},
#  {'GeneSymbol': 'RSL1D1', 'GeneID': '580660', 'NumInteractors': 4},
#  {'GeneSymbol': 'NIFK', 'GeneID': '580658', 'NumInteractors': 13},
#  {'GeneSymbol': 'IRF2BP1', 'GeneID': '580634', 'NumInteractors': 8},
#  {'GeneSymbol': 'VGLL4', 'GeneID': '580622', 'NumInteractors': 13},
#  {'GeneSymbol': 'L3HYPDH', 'GeneID': '580498', 'NumInteractors': 9},
#  {'GeneSymbol': 'SLAMF8', 'GeneID': '580456', 'NumInteractors': 3},
#  {'GeneSymbol': 'DDAH2', 'GeneID': '580442', 'NumInteractors': 5},
#  {'GeneSymbol': 'FAM118B', 'GeneID': '580346', 'NumInteractors': 11},
#  {'GeneSymbol': 'HSPA12B', 'GeneID': '580334', 'NumInteractors': 14},
#  {'GeneSymbol': 'SFXN5', 'GeneID': '580320', 'NumInteractors': 19},
#  {'GeneSymbol': 'SNX4', 'GeneID': '580224', 'NumInteractors': 8},
#  {'GeneSymbol': 'GPM6A', 'GeneID': '580070', 'NumInteractors': 10},
#  {'GeneSymbol': 'IGFBP4', 'GeneID': '580046', 'NumInteractors': 10},
#  {'GeneSymbol': 'LRRC40', 'GeneID': '580008', 'NumInteractors': 5},
#  {'GeneSymbol': 'CNPY3', 'GeneID': '579988', 'NumInteractors': 12},
#  {'GeneSymbol': 'RBM11', 'GeneID': '579966', 'NumInteractors': 10},
#  {'GeneSymbol': 'PLOD3', 'GeneID': '579910', 'NumInteractors': 25},
#  {'GeneSymbol': 'C1QTNF1', 'GeneID': '579904', 'NumInteractors': 26},
#  {'GeneSymbol': 'BUD23', 'GeneID': '579884', 'NumInteractors': 4},
#  {'GeneSymbol': 'ATP1B3', 'GeneID': '579870', 'NumInteractors': 6},
#  {'GeneSymbol': 'ABHD14A', 'GeneID': '579852', 'NumInteractors': 8},
#  {'GeneSymbol': 'NXPH1', 'GeneID': '579828', 'NumInteractors': 5},
#  {'GeneSymbol': 'RAB6C', 'GeneID': '579820', 'NumInteractors': 2},
#  {'GeneSymbol': 'CAPN5', 'GeneID': '579760', 'NumInteractors': 7},
#  {'GeneSymbol': 'STXBP3', 'GeneID': '579728', 'NumInteractors': 9},
#  {'GeneSymbol': 'SPSB4', 'GeneID': '579606', 'NumInteractors': 45},
#  {'GeneSymbol': 'UQCRFS1', 'GeneID': '579574', 'NumInteractors': 12},
#  {'GeneSymbol': 'HOXA5', 'GeneID': '579556', 'NumInteractors': 7},
#  {'GeneSymbol': 'INPP5K', 'GeneID': '579548', 'NumInteractors': 16},
#  {'GeneSymbol': 'PDCD1LG2', 'GeneID': '579530', 'NumInteractors': 1},
#  {'GeneSymbol': 'TSSK6', 'GeneID': '579522', 'NumInteractors': 6},
#  {'GeneSymbol': 'FLAD1', 'GeneID': '579516', 'NumInteractors': 3},
#  {'GeneSymbol': 'CELA2A', 'GeneID': '579510', 'NumInteractors': 4},
#  {'GeneSymbol': 'HSPD1', 'GeneID': '579498', 'NumInteractors': 21},
#  {'GeneSymbol': 'JUNB', 'GeneID': '579456', 'NumInteractors': 15},
#  {'GeneSymbol': 'ATF2', 'GeneID': '579452', 'NumInteractors': 10},
#  {'GeneSymbol': 'PLEKHO1', 'GeneID': '579324', 'NumInteractors': 6},
#  {'GeneSymbol': 'NUBP2', 'GeneID': '579290', 'NumInteractors': 3},
#  {'GeneSymbol': 'BAG1', 'GeneID': '579286', 'NumInteractors': 1},
#  {'GeneSymbol': 'RSPO1', 'GeneID': '579260', 'NumInteractors': 10},
#  {'GeneSymbol': 'C11orf54', 'GeneID': '579254', 'NumInteractors': 6},
#  {'GeneSymbol': 'CLEC12A', 'GeneID': '579236', 'NumInteractors': 7},
#  {'GeneSymbol': 'PIK3IP1', 'GeneID': '579230', 'NumInteractors': 2},
#  {'GeneSymbol': 'RNF7', 'GeneID': '579226', 'NumInteractors': 29},
#  {'GeneSymbol': 'SPSB2', 'GeneID': '579162', 'NumInteractors': 24},
#  {'GeneSymbol': 'FOSL1', 'GeneID': '579104', 'NumInteractors': 22},
#  {'GeneSymbol': 'BSG', 'GeneID': '579032', 'NumInteractors': 29},
#  {'GeneSymbol': 'GCLM', 'GeneID': '579012', 'NumInteractors': 7},
#  {'GeneSymbol': 'RFPL4B', 'GeneID': '578932', 'NumInteractors': 6},
#  {'GeneSymbol': 'PPP2R2D', 'GeneID': '578914', 'NumInteractors': 30},
#  {'GeneSymbol': 'PPP2R1A', 'GeneID': '578908', 'NumInteractors': 64},
#  {'GeneSymbol': 'SWSAP1', 'GeneID': '578902', 'NumInteractors': 1},
#  {'GeneSymbol': 'EAF1', 'GeneID': '578804', 'NumInteractors': 34},
#  {'GeneSymbol': 'ITM2B', 'GeneID': '578798', 'NumInteractors': 2},
#  {'GeneSymbol': 'RNF151', 'GeneID': '578770', 'NumInteractors': 3},
#  {'GeneSymbol': 'AGPAT3', 'GeneID': '578764', 'NumInteractors': 6},
#  {'GeneSymbol': 'PES1', 'GeneID': '578726', 'NumInteractors': 14},
#  {'GeneSymbol': 'KLK1', 'GeneID': '578688', 'NumInteractors': 17},
#  {'GeneSymbol': 'ADIPOQ', 'GeneID': '578604', 'NumInteractors': 40},
#  {'GeneSymbol': 'GPT2', 'GeneID': '578594', 'NumInteractors': 3},
#  {'GeneSymbol': 'THEM5', 'GeneID': '578582', 'NumInteractors': 7},
#  {'GeneSymbol': 'MGARP', 'GeneID': '578536', 'NumInteractors': 11},
#  {'GeneSymbol': 'PRMT8', 'GeneID': '578526', 'NumInteractors': 14},
#  {'GeneSymbol': 'C1orf226', 'GeneID': '578506', 'NumInteractors': 4},
#  {'GeneSymbol': 'C1orf174', 'GeneID': '578396', 'NumInteractors': 49},
#  {'GeneSymbol': 'PRTN3', 'GeneID': '578382', 'NumInteractors': 8},
#  {'GeneSymbol': 'SNIP1', 'GeneID': '578368', 'NumInteractors': 34},
#  {'GeneSymbol': 'SPIN4', 'GeneID': '578364', 'NumInteractors': 6},
#  {'GeneSymbol': 'MMAB', 'GeneID': '578358', 'NumInteractors': 11},
#  {'GeneSymbol': 'GALNT9', 'GeneID': '578348', 'NumInteractors': 5},
#  {'GeneSymbol': 'BCL2L2', 'GeneID': '578334', 'NumInteractors': 5},
#  {'GeneSymbol': 'SSBP4', 'GeneID': '578242', 'NumInteractors': 9},
#  {'GeneSymbol': 'KCNAB2', 'GeneID': '578228', 'NumInteractors': 13},
#  {'GeneSymbol': 'MFAP4', 'GeneID': '578212', 'NumInteractors': 19},
#  {'GeneSymbol': 'FCER1A', 'GeneID': '578206', 'NumInteractors': 2},
#  {'GeneSymbol': 'KLK15', 'GeneID': '578180', 'NumInteractors': 12},
#  {'GeneSymbol': 'BCAM', 'GeneID': '578134', 'NumInteractors': 11},
#  {'GeneSymbol': 'CLEC4A', 'GeneID': '578118', 'NumInteractors': 26},
#  {'GeneSymbol': 'RFXANK', 'GeneID': '578104', 'NumInteractors': 5},
#  {'GeneSymbol': 'AP3M1', 'GeneID': '578100', 'NumInteractors': 10},
#  {'GeneSymbol': 'HLA-DRA', 'GeneID': '578076', 'NumInteractors': 11},
#  {'GeneSymbol': 'TMEM106A', 'GeneID': '578030', 'NumInteractors': 22},
#  {'GeneSymbol': 'CMA1', 'GeneID': '577972', 'NumInteractors': 29},
#  {'GeneSymbol': 'PI15', 'GeneID': '577964', 'NumInteractors': 3},
#  {'GeneSymbol': 'CD79A', 'GeneID': '577948', 'NumInteractors': 7},
#  {'GeneSymbol': 'MTMR9', 'GeneID': '577908', 'NumInteractors': 11},
#  {'GeneSymbol': 'BRD4', 'GeneID': '577874', 'NumInteractors': 7},
#  {'GeneSymbol': 'HSF2', 'GeneID': '577844', 'NumInteractors': 5},
#  {'GeneSymbol': 'SMARCE1', 'GeneID': '577810', 'NumInteractors': 29},
#  {'GeneSymbol': 'SMARCC2', 'GeneID': '577788', 'NumInteractors': 20},
#  {'GeneSymbol': 'ACTL6A', 'GeneID': '577724', 'NumInteractors': 5},
#  {'GeneSymbol': 'BCL7A', 'GeneID': '577714', 'NumInteractors': 34},
#  {'GeneSymbol': 'OSM', 'GeneID': '577704', 'NumInteractors': 4},
#  {'GeneSymbol': 'XXYLT1', 'GeneID': '577572', 'NumInteractors': 22},
#  {'GeneSymbol': 'NRM', 'GeneID': '577552', 'NumInteractors': 7},
#  {'GeneSymbol': 'ST3GAL1', 'GeneID': '577452', 'NumInteractors': 6},
#  {'GeneSymbol': 'PEX3', 'GeneID': '577442', 'NumInteractors': 12},
#  {'GeneSymbol': 'SCN3B', 'GeneID': '577372', 'NumInteractors': 128},
#  {'GeneSymbol': 'CSN2', 'GeneID': '577364', 'NumInteractors': 3},
#  {'GeneSymbol': 'CRYBB3', 'GeneID': '577346', 'NumInteractors': 9},
#  {'GeneSymbol': 'BPIFB1', 'GeneID': '577314', 'NumInteractors': 11},
#  {'GeneSymbol': 'PTX3', 'GeneID': '577258', 'NumInteractors': 24},
#  {'GeneSymbol': 'PRG3', 'GeneID': '577212', 'NumInteractors': 59},
#  {'GeneSymbol': 'RWDD4', 'GeneID': '577200', 'NumInteractors': 4},
#  {'GeneSymbol': 'CABCOCO1', 'GeneID': '577196', 'NumInteractors': 1},
#  {'GeneSymbol': 'NOG', 'GeneID': '577144', 'NumInteractors': 4},
#  {'GeneSymbol': 'MFGE8', 'GeneID': '577138', 'NumInteractors': 41},
#  {'GeneSymbol': 'CRP', 'GeneID': '577092', 'NumInteractors': 47},
#  {'GeneSymbol': 'RAB15', 'GeneID': '577080', 'NumInteractors': 5},
#  {'GeneSymbol': 'IL22RA2', 'GeneID': '577066', 'NumInteractors': 6},
#  {'GeneSymbol': 'PCGF6', 'GeneID': '577038', 'NumInteractors': 31},
#  {'GeneSymbol': 'L3MBTL2', 'GeneID': '577024', 'NumInteractors': 16},
#  {'GeneSymbol': 'CSNK2B', 'GeneID': '576976', 'NumInteractors': 58},
#  {'GeneSymbol': 'PCGF2', 'GeneID': '576968', 'NumInteractors': 14},
#  {'GeneSymbol': 'TP53', 'GeneID': '576958', 'NumInteractors': 7},
#  {'GeneSymbol': 'YAF2', 'GeneID': '576954', 'NumInteractors': 39},
#  {'GeneSymbol': 'RRS1', 'GeneID': '576948', 'NumInteractors': 34},
#  {'GeneSymbol': 'RPL4', 'GeneID': '576940', 'NumInteractors': 6},
#  {'GeneSymbol': 'ZNF428', 'GeneID': '576896', 'NumInteractors': 13},
#  {'GeneSymbol': 'TMEM154', 'GeneID': '576870', 'NumInteractors': 11},
#  {'GeneSymbol': 'TMEM200A', 'GeneID': '576794', 'NumInteractors': 14},
#  {'GeneSymbol': 'BMPR2', 'GeneID': '576766', 'NumInteractors': 5},
#  {'GeneSymbol': 'ACVR1', 'GeneID': '576758', 'NumInteractors': 45},
#  {'GeneSymbol': 'KCNE3', 'GeneID': '576710', 'NumInteractors': 61},
#  {'GeneSymbol': 'RETREG3', 'GeneID': '576664', 'NumInteractors': 43},
#  {'GeneSymbol': 'TYROBP', 'GeneID': '576628', 'NumInteractors': 32},
#  {'GeneSymbol': 'GPIHBP1', 'GeneID': '576536', 'NumInteractors': 39},
#  {'GeneSymbol': 'LSMEM2', 'GeneID': '576512', 'NumInteractors': 8},
#  {'GeneSymbol': 'RMDN1', 'GeneID': '576492', 'NumInteractors': 2},
#  {'GeneSymbol': 'SUOX', 'GeneID': '576442', 'NumInteractors': 5},
#  {'GeneSymbol': 'SYNCRIP', 'GeneID': '576426', 'NumInteractors': 7},
#  {'GeneSymbol': 'ERAL1', 'GeneID': '576370', 'NumInteractors': 5},
#  {'GeneSymbol': 'GREM2', 'GeneID': '576346', 'NumInteractors': 8},
#  {'GeneSymbol': 'AHSP', 'GeneID': '576330', 'NumInteractors': 8},
#  {'GeneSymbol': 'CIB2', 'GeneID': '576206', 'NumInteractors': 40},
#  {'GeneSymbol': 'CIAO3', 'GeneID': '576186', 'NumInteractors': 6},
#  {'GeneSymbol': 'RARS2', 'GeneID': '576144', 'NumInteractors': 15},
#  {'GeneSymbol': 'CIAO2A', 'GeneID': '576094', 'NumInteractors': 53},
#  {'GeneSymbol': 'HNRNPH2', 'GeneID': '576078', 'NumInteractors': 6},
#  {'GeneSymbol': 'C10orf53', 'GeneID': '576070', 'NumInteractors': 3},
#  {'GeneSymbol': 'LY86', 'GeneID': '575940', 'NumInteractors': 43},
#  {'GeneSymbol': 'OPALIN', 'GeneID': '575866', 'NumInteractors': 33},
#  {'GeneSymbol': 'CTDSP2', 'GeneID': '575852', 'NumInteractors': 6},
#  {'GeneSymbol': 'NPTN', 'GeneID': '575848', 'NumInteractors': 100},
#  {'GeneSymbol': 'ERAP1', 'GeneID': '575728', 'NumInteractors': 7},
#  {'GeneSymbol': 'EFNB2', 'GeneID': '575612', 'NumInteractors': 67},
#  {'GeneSymbol': 'STK11', 'GeneID': '575536', 'NumInteractors': 21},
#  {'GeneSymbol': 'HMCES', 'GeneID': '575504', 'NumInteractors': 5},
#  {'GeneSymbol': 'RPA2', 'GeneID': '575484', 'NumInteractors': 11},
#  {'GeneSymbol': 'THAP11', 'GeneID': '575418', 'NumInteractors': 11},
#  {'GeneSymbol': 'SRSF5', 'GeneID': '575374', 'NumInteractors': 20},
#  {'GeneSymbol': 'RPL26', 'GeneID': '575358', 'NumInteractors': 13},
#  ...]

# %%
def get_apms_edgelist(self, nice_cx):
    nodes = nice_cx.nodes
    edges = nice_cx.edges
    edge_attrs = nice_cx.edgeAttributes

    attr_by_edge_id = defaultdict(dict)
    for edge_id, attr_list in edge_attrs.items():
        for attr in attr_list:
            attr_name = attr['n']
            attr_value = attr['v']
            if attr_name == 'name':
                continue
            attr_by_edge_id[edge_id][attr_name] = attr_value

    self._apms_edgelist = []
    for edge_id, edge_data in edges.items():
        source = edge_data.get('s')
        target = edge_data.get('t')

        source_info = nodes.get(source, {})
        target_info = nodes.get(target, {})

        edge_dict = {
            'GeneID1': str(source),  
            'Symbol1': source_info.get('n'),  
            'GeneID2': str(target),
            'Symbol2': target_info.get('n'),
        }

        edge_dict.update(attr_by_edge_id.get(edge_id, {}))
        self._apms_edgelist.append(edge_dict)

    return self._apms_edgelist

# %%
get_apms_edgelist2(nice_cx)
# Out:
# [{'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '551222',
#   'symbolB': 'SLC30A1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '568644',
#   'symbolB': 'TNPO3'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '553938',
#   'symbolB': 'SLC12A4'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '552516',
#   'symbolB': 'MYO6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '551198',
#   'symbolB': 'SLC39A10'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555820',
#   'symbolB': 'SLC12A6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555224',
#   'symbolB': 'VPS18'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '548774',
#   'symbolB': 'TMEM160'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555242',
#   'symbolB': 'CUEDC1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555116',
#   'symbolB': 'CYRIB'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '562860',
#   'symbolB': 'UFSP2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '568212',
#   'symbolB': 'FIRRM'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '567094',
#   'symbolB': 'CNNM1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '582816',
#   'symbolB': 'ATP13A3'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '570926',
#   'symbolB': 'PCNX3'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '551490',
#   'symbolB': 'LRRC1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '552738',
#   'symbolB': 'OSMR'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555414',
#   'symbolB': 'CCDC115'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '610744',
#   'symbolB': 'GLMN'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '557614',
#   'symbolB': 'PIEZO1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '588718',
#   'symbolB': 'TRPM4'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '602580',
#   'symbolB': 'SLC30A5'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '594304',
#   'symbolB': 'RETREG2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555406',
#   'symbolB': 'TMEM199'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '561750',
#   'symbolB': 'ANKRD13A'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '576788',
#   'symbolB': 'LAPTM4B'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '559728',
#   'symbolB': 'TOM1L2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '610658',
#   'symbolB': 'SLC30A6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560984',
#   'symbolB': 'TWF2'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '556314',
#   'symbolB': 'ODR4'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '555742',
#   'symbolB': 'ANO6'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '549416',
#   'symbolB': 'ATP6V1F'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '547914',
#   'symbolB': 'RAD23A'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560288',
#   'symbolB': 'ADGRE5'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560284',
#   'symbolB': 'HRH1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '557406',
#   'symbolB': 'PTPRF'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560254',
#   'symbolB': 'ABHD16A'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '567158',
#   'symbolB': 'MLYCD'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '560220',
#   'symbolB': 'FADS1'},
#  {'geneA': '635898',
#   'symbolA': 'TMEM88',
#   'geneB': '548290',
#   'symbolB': 'COX7A2L'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '552878',
#   'symbolB': 'IL36G'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548284',
#   'symbolB': 'BIRC6'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '579254',
#   'symbolB': 'C11orf54'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548160',
#   'symbolB': 'SDR9C7'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548156',
#   'symbolB': 'SERPINA12'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '558074',
#   'symbolB': 'P3H2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '567360',
#   'symbolB': 'C1QL4'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548148',
#   'symbolB': 'NCCRP1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '576520',
#   'symbolB': 'PLBD1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '551042',
#   'symbolB': 'KLHL22'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548124',
#   'symbolB': 'ECM1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548272',
#   'symbolB': 'BIRC2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '566024',
#   'symbolB': 'TRAF1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548268',
#   'symbolB': 'TRAF2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548080',
#   'symbolB': 'HAL'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '549486',
#   'symbolB': 'COL8A1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '567320',
#   'symbolB': 'COL5A1'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '548052',
#   'symbolB': 'IL1RN'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '554794',
#   'symbolB': 'SERPINB2'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '547984',
#   'symbolB': 'ALOX12B'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '595416',
#   'symbolB': 'TGM5'},
#  {'geneA': '635852',
#   'symbolA': 'COL10A1',
#   'geneB': '602214',
#   'symbolB': 'P4HA2'},
#  {'geneA': '635680', 'symbolA': 'CYCS', 'geneB': '556120', 'symbolB': 'SIRT1'},
#  {'geneA': '635680', 'symbolA': 'CYCS', 'geneB': '564802', 'symbolB': 'FANCB'},
#  {'geneA': '635680', 'symbolA': 'CYCS', 'geneB': '564840', 'symbolB': 'ATAD2'},
#  {'geneA': '635680',
#   'symbolA': 'CYCS',
#   'geneB': '564798',
#   'symbolB': 'FAAP100'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '552470',
#   'symbolB': 'KANSL3'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '555294',
#   'symbolB': 'KANSL2'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '611544',
#   'symbolB': 'RSRC1'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '555288',
#   'symbolB': 'MCRS1'},
#  {'geneA': '635458',
#   'symbolA': 'PHF20',
#   'geneB': '555276',
#   'symbolB': 'KANSL1'},
#  {'geneA': '635416', 'symbolA': 'ADD2', 'geneB': '619670', 'symbolB': 'ADD1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '579900',
#   'symbolB': 'AMDHD2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '577664',
#   'symbolB': 'MTCH1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562472',
#   'symbolB': 'SMARCAL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559142',
#   'symbolB': 'FBXL12'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553498',
#   'symbolB': 'ABHD10'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553228',
#   'symbolB': 'ABCB10'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '580860',
#   'symbolB': 'WDR54'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '547654',
#   'symbolB': 'WDR76'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '585488',
#   'symbolB': 'SLC25A32'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '619066',
#   'symbolB': 'TRIM6'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635392',
#   'symbolB': 'SLC25A39'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635388',
#   'symbolB': 'DPH1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562382',
#   'symbolB': 'ST6GALNAC5'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '588514',
#   'symbolB': 'TMEM70'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '561326',
#   'symbolB': 'TSEN34'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '596670',
#   'symbolB': 'NUDT16L1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562302',
#   'symbolB': 'AURKB'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559112',
#   'symbolB': 'FBXO17'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '596934',
#   'symbolB': 'MTMR8'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635370',
#   'symbolB': 'ANKRD9'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '558136',
#   'symbolB': 'NXPE3'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559328',
#   'symbolB': 'DCAKD'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '547228',
#   'symbolB': 'DCAF4'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562268',
#   'symbolB': 'SMCR8'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '577896',
#   'symbolB': 'CFAP251'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '618996',
#   'symbolB': 'ENDOV'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562232',
#   'symbolB': 'ARHGEF39'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553118',
#   'symbolB': 'GALNT16'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '556360',
#   'symbolB': 'PUSL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '596916',
#   'symbolB': 'KLHDC8B'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '568760',
#   'symbolB': 'MAP4K3'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '558430',
#   'symbolB': 'CTU1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '584710',
#   'symbolB': 'MAVS'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '572324',
#   'symbolB': 'SH2D5'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '624248',
#   'symbolB': 'ABLIM2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635336',
#   'symbolB': 'B3GNTL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635332',
#   'symbolB': 'WDR25'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '565496',
#   'symbolB': 'IBA57'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562094',
#   'symbolB': 'ZRANB3'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '561378',
#   'symbolB': 'HSDL1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '560320',
#   'symbolB': 'PGS1'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '553330',
#   'symbolB': 'TAF1C'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '583700',
#   'symbolB': 'HLTF'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '559006',
#   'symbolB': 'SKP2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '562020',
#   'symbolB': 'DNAH14'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635312',
#   'symbolB': 'STK19'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '550834',
#   'symbolB': 'PRKACB'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '635306',
#   'symbolB': 'IMPDH2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '549242',
#   'symbolB': 'NDUFC2'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '552912',
#   'symbolB': 'DUSP14'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '549248',
#   'symbolB': 'NDUFB5'},
#  {'geneA': '635296',
#   'symbolA': 'IMPDH1',
#   'geneB': '560576',
#   'symbolB': 'BCAT2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '558708',
#   'symbolB': 'MAP3K4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '593022', 'symbolB': 'ALG5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568644',
#   'symbolB': 'TNPO3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '557672',
#   'symbolB': 'PLXND1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559338',
#   'symbolB': 'PTRH2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553294', 'symbolB': 'COG6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559434',
#   'symbolB': 'EXOC6B'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '565196',
#   'symbolB': 'EXOC7'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553288', 'symbolB': 'COG5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '576286',
#   'symbolB': 'VPS51'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577682', 'symbolB': 'XPO7'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568228',
#   'symbolB': 'TUBGCP4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '555668', 'symbolB': 'NCDN'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559424',
#   'symbolB': 'ATXN10'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '575732', 'symbolB': 'SACS'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '562994',
#   'symbolB': 'ACTR10'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '548774',
#   'symbolB': 'TMEM160'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '562860',
#   'symbolB': 'UFSP2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '561852', 'symbolB': 'MDN1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '628676',
#   'symbolB': 'TBC1D22B'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '572694', 'symbolB': 'EPG5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '554336', 'symbolB': 'NEK6'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '579248', 'symbolB': 'XPO5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553280', 'symbolB': 'COG4'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '561842',
#   'symbolB': 'ZWILCH'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635242',
#   'symbolB': 'TTC12'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568200',
#   'symbolB': 'HEATR1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553206',
#   'symbolB': 'GHITM'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559332',
#   'symbolB': 'SLC25A51'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '612176',
#   'symbolB': 'CYRIA'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568196',
#   'symbolB': 'INTS2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '559416', 'symbolB': 'XPO4'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568626',
#   'symbolB': 'NUP85'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635224',
#   'symbolB': 'DCUN1D5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '616894',
#   'symbolB': 'NCAPG'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577612', 'symbolB': 'XPO6'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '580340', 'symbolB': 'SMG1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553276', 'symbolB': 'COG8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568794',
#   'symbolB': 'ELMO2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553272', 'symbolB': 'COG3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568612',
#   'symbolB': 'INTS4'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559408',
#   'symbolB': 'SAAL1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '583860',
#   'symbolB': 'ISOC1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '561410',
#   'symbolB': 'TBRG4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577602', 'symbolB': 'MUL1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '610744', 'symbolB': 'GLMN'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568598',
#   'symbolB': 'SYMPK'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635194',
#   'symbolB': 'IP6K1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '572664', 'symbolB': 'GBF1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '550736',
#   'symbolB': 'GEMIN6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572918',
#   'symbolB': 'RUFY2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553268', 'symbolB': 'COG1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580320',
#   'symbolB': 'SFXN5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580314',
#   'symbolB': 'EXOC6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '575692',
#   'symbolB': 'MROH1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '571766', 'symbolB': 'CCNY'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '558102', 'symbolB': 'SMG8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '599250',
#   'symbolB': 'DAGLB'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553000',
#   'symbolB': 'GOLM1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '571758',
#   'symbolB': 'CCNYL1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553118',
#   'symbolB': 'GALNT16'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '610962',
#   'symbolB': 'ARMC10'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '557240',
#   'symbolB': 'SLC39A11'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '557234',
#   'symbolB': 'WDFY3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '592154',
#   'symbolB': 'FAM200C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559398',
#   'symbolB': 'EXOC8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '622712',
#   'symbolB': 'SLC35F2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577548',
#   'symbolB': 'DNAAF5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '569786',
#   'symbolB': 'NLRX1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559392',
#   'symbolB': 'HEATR3'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '568578', 'symbolB': 'MON2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '567446', 'symbolB': 'SETX'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '569880', 'symbolB': 'DYM'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572634',
#   'symbolB': 'USP34'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580290',
#   'symbolB': 'NBEAL1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568166',
#   'symbolB': 'THADA'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '551840',
#   'symbolB': 'SLC30A9'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '572626', 'symbolB': 'TTI2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '558026',
#   'symbolB': 'MYORG'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '624248',
#   'symbolB': 'ABLIM2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '567964',
#   'symbolB': 'HEATR6'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '564836', 'symbolB': 'RIF1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '571612', 'symbolB': 'FRY'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '564394', 'symbolB': 'COQ5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '567786',
#   'symbolB': 'YIF1B'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572612',
#   'symbolB': 'PDS5A'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '594726',
#   'symbolB': 'PPP2R5E'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '549412',
#   'symbolB': 'ATP6AP1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '585448',
#   'symbolB': 'MSMO1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568150',
#   'symbolB': 'UBE3C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559388',
#   'symbolB': 'PPP2R5A'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '551834',
#   'symbolB': 'KIF14'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553256', 'symbolB': 'COG2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580260',
#   'symbolB': 'PPP2R5D'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568744',
#   'symbolB': 'DOCK1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '570684',
#   'symbolB': 'UBE4A'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577462', 'symbolB': 'ATR'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '593680', 'symbolB': 'MTX1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '591496',
#   'symbolB': 'PPP2R5C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580252',
#   'symbolB': 'NUP160'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '563868',
#   'symbolB': 'WASHC5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '576642', 'symbolB': 'KDSR'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '553262', 'symbolB': 'COG7'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '550666',
#   'symbolB': 'GEMIN4'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '577442', 'symbolB': 'PEX3'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '547442', 'symbolB': 'RRP1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '572592',
#   'symbolB': 'KNTC1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '568874', 'symbolB': 'MTOR'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '564380',
#   'symbolB': 'FDFT1'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '556654', 'symbolB': 'ARL2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '549392',
#   'symbolB': 'ATP6V0C'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '555692',
#   'symbolB': 'LGALS1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577412',
#   'symbolB': 'PEX11B'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '623164', 'symbolB': 'CDS2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '560246',
#   'symbolB': 'GOSR1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580888',
#   'symbolB': 'CCNB2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '559288',
#   'symbolB': 'TSPAN9'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577392',
#   'symbolB': 'ZMPSTE24'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '551802',
#   'symbolB': 'ATP6AP2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '555532',
#   'symbolB': 'CAND2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '574636',
#   'symbolB': 'HIP1R'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '635044', 'symbolB': 'HUS1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '553988',
#   'symbolB': 'EXOC3'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568096',
#   'symbolB': 'RANBP6'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568536',
#   'symbolB': 'GSDME'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '547422', 'symbolB': 'URB1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '554480',
#   'symbolB': 'SPAG9'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '577382',
#   'symbolB': 'SLC25A17'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '620230',
#   'symbolB': 'RAD51C'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '554368', 'symbolB': 'ZW10'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '568532', 'symbolB': 'TTI1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '548464',
#   'symbolB': 'PLXNB2'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '568524',
#   'symbolB': 'TNPO2'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '565984', 'symbolB': 'ENC1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580192',
#   'symbolB': 'EXOC5'},
#  {'geneA': '635006', 'symbolA': 'VSIG1', 'geneB': '559360', 'symbolB': 'IPO5'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '561348',
#   'symbolB': 'LGALS8'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '635010',
#   'symbolB': 'KCNK1'},
#  {'geneA': '635006',
#   'symbolA': 'VSIG1',
#   'geneB': '580184',
#   'symbolB': 'RIMOC1'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '548208',
#   'symbolB': 'KNSTRN'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '568452',
#   'symbolB': 'COMMD3'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '587466',
#   'symbolB': 'YIPF3'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '573642',
#   'symbolB': 'KIFC3'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '548180',
#   'symbolB': 'SPAG5'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '551576',
#   'symbolB': 'COPS6'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '564840',
#   'symbolB': 'ATAD2'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '634956',
#   'symbolB': 'CENPE'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '553070',
#   'symbolB': 'SOAT1'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '549334',
#   'symbolB': 'SNAPIN'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '569410',
#   'symbolB': 'ZWINT'},
#  {'geneA': '634946',
#   'symbolA': 'SYCE3',
#   'geneB': '565032',
#   'symbolB': 'CCDC22'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '549234',
#   'symbolB': 'MTCL1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '552478',
#   'symbolB': 'AGAP1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548798',
#   'symbolB': 'CEP131'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '578378',
#   'symbolB': 'KMT2B'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '557016',
#   'symbolB': 'ZMYND8'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '573874',
#   'symbolB': 'ZDHHC8'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '565348',
#   'symbolB': 'TRPS1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '564866',
#   'symbolB': 'ARHGAP23'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548778',
#   'symbolB': 'UGGT2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '555720',
#   'symbolB': 'DMAP1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '577044', 'symbolB': 'FBRS'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '553210',
#   'symbolB': 'PTGES2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562412',
#   'symbolB': 'PLEKHG2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '629264',
#   'symbolB': 'AIFM2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '571828',
#   'symbolB': 'ARHGEF17'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '552436',
#   'symbolB': 'AGAP3'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '582972',
#   'symbolB': 'SCARF2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '592418',
#   'symbolB': 'CASKIN2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '573550',
#   'symbolB': 'ARHGEF40'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '549104', 'symbolB': 'DLG5'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '561818',
#   'symbolB': 'GDAP1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '553140', 'symbolB': 'UXS1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '568768',
#   'symbolB': 'SYNPO'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '571098',
#   'symbolB': 'ZNF687'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '575218',
#   'symbolB': 'STK11IP'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '548720', 'symbolB': 'CHPF'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '555990',
#   'symbolB': 'CHSY1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '634530',
#   'symbolB': 'KIF21A'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '581606',
#   'symbolB': 'RSRC2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '558050',
#   'symbolB': 'CHSY3'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562144',
#   'symbolB': 'SRCAP'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '549004',
#   'symbolB': 'FAM171A1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '550236',
#   'symbolB': 'SYDE2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '553482',
#   'symbolB': 'DCAF10'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562090',
#   'symbolB': 'TIGD5'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '571582',
#   'symbolB': 'SHROOM1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '548664', 'symbolB': 'EXT1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '562682',
#   'symbolB': 'VPS72'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '579994',
#   'symbolB': 'SCRIB'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '554420', 'symbolB': 'PLD1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '557970', 'symbolB': 'SCAP'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '563030',
#   'symbolB': 'DENND2B'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548940',
#   'symbolB': 'DCAF7'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '571448', 'symbolB': 'TSC2'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '584412', 'symbolB': 'HELZ'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '551920', 'symbolB': 'ETV6'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '551266',
#   'symbolB': 'TIMP3'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '568120', 'symbolB': 'NF1'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '624162', 'symbolB': 'P4HB'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '548500',
#   'symbolB': 'ITGAV'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '558354',
#   'symbolB': 'CEP43'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '548488', 'symbolB': 'UBR5'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '593204',
#   'symbolB': 'ADGRL1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '559628',
#   'symbolB': 'RPS6KA4'},
#  {'geneA': '634460', 'symbolA': 'P4HA3', 'geneB': '557366', 'symbolB': 'LRP6'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '554410',
#   'symbolB': 'PEX14'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '615874',
#   'symbolB': 'NUAK1'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '634468',
#   'symbolB': 'ZBTB7B'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '554612',
#   'symbolB': 'FAM171A2'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '559618',
#   'symbolB': 'PLEKHG3'},
#  {'geneA': '634460',
#   'symbolA': 'P4HA3',
#   'geneB': '564036',
#   'symbolB': 'ARHGAP10'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '575728',
#   'symbolB': 'ERAP1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '582816',
#   'symbolB': 'ATP13A3'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '563838',
#   'symbolB': 'C1orf198'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '592808',
#   'symbolB': 'BTBD9'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '564678',
#   'symbolB': 'ITCH'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '561062',
#   'symbolB': 'WBP2'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '588718',
#   'symbolB': 'TRPM4'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '553450',
#   'symbolB': 'NPLOC4'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '555196',
#   'symbolB': 'VPS8'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '580290',
#   'symbolB': 'NBEAL1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '570370',
#   'symbolB': 'DAZAP2'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '549404',
#   'symbolB': 'ATP6V0D1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '553446',
#   'symbolB': 'PPM1A'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '548288',
#   'symbolB': 'UQCRB'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '550158',
#   'symbolB': 'ENDOD1'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '548290',
#   'symbolB': 'COX7A2L'},
#  {'geneA': '634348',
#   'symbolA': 'DHCR24',
#   'geneB': '548264',
#   'symbolB': 'PDE2A'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '588494',
#   'symbolB': 'CGGBP1'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '634232',
#   'symbolB': 'TRPM3'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '632920',
#   'symbolB': 'PCMTD1'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '575566',
#   'symbolB': 'ARK2N'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '634224',
#   'symbolB': 'PPARGC1B'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '555352', 'symbolB': 'MRM1'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '555696', 'symbolB': 'KGD4'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '615894',
#   'symbolB': 'NRIP1'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '555602', 'symbolB': 'CKB'},
#  {'geneA': '634208',
#   'symbolA': 'ESRRG',
#   'geneB': '634212',
#   'symbolB': 'ESRRA'},
#  {'geneA': '634208', 'symbolA': 'ESRRG', 'geneB': '551440', 'symbolB': 'TTR'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '566312', 'symbolB': 'MYRF'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '568840', 'symbolB': 'ASAP1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '634200', 'symbolB': 'MAGEL2'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '559266', 'symbolB': 'TNS1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '576838',
#   'symbolB': 'MARCHF7'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '570926', 'symbolB': 'PCNX3'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '574262', 'symbolB': 'MYADM'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '582972', 'symbolB': 'SCARF2'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '576794',
#   'symbolB': 'TMEM200A'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '563834', 'symbolB': 'DAAM2'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '549004',
#   'symbolB': 'FAM171A1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '552942', 'symbolB': 'CDC37'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '550424', 'symbolB': 'ITSN1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '574690',
#   'symbolB': 'RPS6KA1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '562876', 'symbolB': 'CBFB'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '580556', 'symbolB': 'RUNX2'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '577992', 'symbolB': 'FKBP5'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '551464', 'symbolB': 'PTPRS'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '567956', 'symbolB': 'RUNX1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '563030',
#   'symbolB': 'DENND2B'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '611852', 'symbolB': 'BCAR1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '569530',
#   'symbolB': 'RPS6KA3'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '576748', 'symbolB': 'TGFBR2'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '596066', 'symbolB': 'JAK1'},
#  {'geneA': '634146',
#   'symbolA': 'FYN',
#   'geneB': '614410',
#   'symbolB': 'TNFRSF1A'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '557406', 'symbolB': 'PTPRF'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '564376', 'symbolB': 'YES1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '567288', 'symbolB': 'F13A1'},
#  {'geneA': '634146', 'symbolA': 'FYN', 'geneB': '551410', 'symbolB': 'MYCBP2'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '556320', 'symbolB': 'ZYG11B'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '555280', 'symbolB': 'NHLRC2'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '552072', 'symbolB': 'CCDC80'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '555696', 'symbolB': 'KGD4'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '555886', 'symbolB': 'SEPHS1'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '550662', 'symbolB': 'COIL'},
#  {'geneA': '634130', 'symbolA': 'ISX', 'geneB': '551226', 'symbolB': 'MOCS3'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '579900',
#   'symbolB': 'AMDHD2'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '550982',
#   'symbolB': 'RCOR1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '549202',
#   'symbolB': 'ZMYM2'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '562486',
#   'symbolB': 'EIF2AK4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '549194',
#   'symbolB': 'RCOR3'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '590256',
#   'symbolB': 'ZNF446'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '549162', 'symbolB': 'GPHN'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '607660', 'symbolB': 'EML4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '550114',
#   'symbolB': 'SAP130'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '566980',
#   'symbolB': 'SIN3A'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633946',
#   'symbolB': 'ZSCAN31'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '554438',
#   'symbolB': 'PGBD1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '566278',
#   'symbolB': 'ZNF496'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '590248',
#   'symbolB': 'ZSCAN18'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '565306',
#   'symbolB': 'EPM2AIP1'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '550174', 'symbolB': 'GET4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '559870',
#   'symbolB': 'ZSCAN25'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '549010',
#   'symbolB': 'ZMYM4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '566258',
#   'symbolB': 'TMTC4'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '556856',
#   'symbolB': 'ZKSCAN8'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '562564',
#   'symbolB': 'ZNF174'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633922',
#   'symbolB': 'TGIF1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '548434',
#   'symbolB': 'ZMYM3'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '602682',
#   'symbolB': 'SCAND1'},
#  {'geneA': '633898', 'symbolA': 'TGIF2', 'geneB': '550162', 'symbolB': 'BAG6'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633912',
#   'symbolB': 'ZSCAN20'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '559642',
#   'symbolB': 'ZKSCAN1'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '590238',
#   'symbolB': 'ZNF24'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '548908',
#   'symbolB': 'KDM1A'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '633902',
#   'symbolB': 'ZNF500'},
#  {'geneA': '633898',
#   'symbolA': 'TGIF2',
#   'geneB': '619544',
#   'symbolB': 'ZNF213'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '568514',
#   'symbolB': 'RNF114'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '598222',
#   'symbolB': 'MKRN2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '550752',
#   'symbolB': 'CRNKL1'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '552798',
#   'symbolB': 'ATXN2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '547768',
#   'symbolB': 'FYTTD1'},
#  {'geneA': '633228', 'symbolA': 'PARP12', 'geneB': '565428', 'symbolB': 'QKI'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '633252',
#   'symbolB': 'PPWD1'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '582232',
#   'symbolB': 'RNF166'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '562248',
#   'symbolB': 'DTX3L'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '562204',
#   'symbolB': 'PARP9'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '564438',
#   'symbolB': 'DTX2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '552072',
#   'symbolB': 'CCDC80'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '547752',
#   'symbolB': 'ZC3H14'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '593890',
#   'symbolB': 'DDI2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '568962',
#   'symbolB': 'NCBP3'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '566246',
#   'symbolB': 'ELAVL2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '570942',
#   'symbolB': 'SYF2'},
#  {'geneA': '633228',
#   'symbolA': 'PARP12',
#   'geneB': '547736',
#   'symbolB': 'CASC3'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '576642', 'symbolB': 'KDSR'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '554566', 'symbolB': 'RRAS2'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '560740', 'symbolB': 'GPX4'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '621272',
#   'symbolB': 'BMPR1A'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '611790', 'symbolB': 'COMT'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '555802',
#   'symbolB': 'LGALS3'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '551532', 'symbolB': 'RRAS'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '561348',
#   'symbolB': 'LGALS8'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '554612',
#   'symbolB': 'FAM171A2'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '554610',
#   'symbolB': 'PCDHGB1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '605576',
#   'symbolB': 'LRRC4B'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '601202',
#   'symbolB': 'CSNK1G1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '549676',
#   'symbolB': 'EPB41L5'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '633198', 'symbolB': 'RBM38'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '548450',
#   'symbolB': 'TMEM120A'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '553170',
#   'symbolB': 'FAM210B'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '561554',
#   'symbolB': 'TMEM186'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '552210', 'symbolB': 'RAB2B'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '633186',
#   'symbolB': 'NDUFAF2'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '576664',
#   'symbolB': 'RETREG3'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '549052',
#   'symbolB': 'TAX1BP1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '551518',
#   'symbolB': 'MBLAC2'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '592590', 'symbolB': 'WLS'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '547274', 'symbolB': 'GNA13'},
#  {'geneA': '633170', 'symbolA': 'CD53', 'geneB': '548108', 'symbolB': 'ASAH1'},
#  {'geneA': '633170',
#   'symbolA': 'CD53',
#   'geneB': '563658',
#   'symbolB': 'CALCOCO2'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '633198',
#   'symbolB': 'RBM38'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '573992',
#   'symbolB': 'GNPNAT1'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '584988', 'symbolB': 'AMZ2'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '566734',
#   'symbolB': 'PDE12'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '552050', 'symbolB': 'SAFB'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '560934', 'symbolB': 'EEA1'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '559460',
#   'symbolB': 'SAFB2'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '548952',
#   'symbolB': 'TP53BP1'},
#  {'geneA': '632882', 'symbolA': 'LARS2', 'geneB': '555424', 'symbolB': 'UBTF'},
#  {'geneA': '632882',
#   'symbolA': 'LARS2',
#   'geneB': '607648',
#   'symbolB': 'CREB1'},
#  {'geneA': '632866',
#   'symbolA': 'RDX',
#   'geneB': '571828',
#   'symbolB': 'ARHGEF17'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632882', 'symbolB': 'LARS2'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632878', 'symbolB': 'NF2'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632874', 'symbolB': 'MSN'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '632870', 'symbolB': 'EZR'},
#  {'geneA': '632866', 'symbolA': 'RDX', 'geneB': '551520', 'symbolB': 'RFPL4A'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '562998',
#   'symbolB': 'DCTN4'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '575298',
#   'symbolB': 'LTBP4'},
#  {'geneA': '632720', 'symbolA': 'ZNF74', 'geneB': '558074', 'symbolB': 'P3H2'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '548716',
#   'symbolB': 'FRAS1'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '548660',
#   'symbolB': 'LTBP2'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '579994',
#   'symbolB': 'SCRIB'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '594704',
#   'symbolB': 'TRIM28'},
#  {'geneA': '632720', 'symbolA': 'ZNF74', 'geneB': '548580', 'symbolB': 'FBN2'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '557476',
#   'symbolB': 'LAMA1'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '553526',
#   'symbolB': 'TRIM27'},
#  {'geneA': '632720',
#   'symbolA': 'ZNF74',
#   'geneB': '562970',
#   'symbolB': 'DCTN6'},
#  {'geneA': '632680',
#   'symbolA': 'PRDX3',
#   'geneB': '632686',
#   'symbolB': 'PRDX1'},
#  {'geneA': '632680',
#   'symbolA': 'PRDX3',
#   'geneB': '550102',
#   'symbolB': 'HERC2'},
#  {'geneA': '632680', 'symbolA': 'PRDX3', 'geneB': '587634', 'symbolB': 'OPA1'},
#  {'geneA': '632650', 'symbolA': 'KANK4', 'geneB': '632676', 'symbolB': 'TLN2'},
#  {'geneA': '632650', 'symbolA': 'KANK4', 'geneB': '632672', 'symbolB': 'TLN1'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '561536',
#   'symbolB': 'TRAPPC4'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '556956',
#   'symbolB': 'PIP5K1A'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '559736',
#   'symbolB': 'TRAPPC9'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '561514',
#   'symbolB': 'TRAPPC14'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '596312',
#   'symbolB': 'EHBP1'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '562222',
#   'symbolB': 'PLCD3'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '555746',
#   'symbolB': 'EHBP1L1'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '554300',
#   'symbolB': 'TRAPPC5'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '561490',
#   'symbolB': 'TRAPPC10'},
#  {'geneA': '632650',
#   'symbolA': 'KANK4',
#   'geneB': '559710',
#   'symbolB': 'TRAPPC3'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '547722',
#   'symbolB': 'RRP7A'},
#  {'geneA': '632566', 'symbolA': 'FGF17', 'geneB': '552482', 'symbolB': 'HPSE'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '557010',
#   'symbolB': 'NOL12'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '615596',
#   'symbolB': 'ANKFY1'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '549676',
#   'symbolB': 'EPB41L5'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '547626',
#   'symbolB': 'NUSAP1'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '556956',
#   'symbolB': 'PIP5K1A'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '559890',
#   'symbolB': 'ASCC3'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '566362',
#   'symbolB': 'ANKHD1-EIF4EBP3'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '556876',
#   'symbolB': 'DHX57'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '564514',
#   'symbolB': 'TRIP4'},
#  {'geneA': '632566', 'symbolA': 'FGF17', 'geneB': '609082', 'symbolB': 'FGF8'},
#  {'geneA': '632566',
#   'symbolA': 'FGF17',
#   'geneB': '551428',
#   'symbolB': 'ANKRD17'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '632562',
#   'symbolB': 'TXLNG'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '632558',
#   'symbolB': 'NACA2'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '553476',
#   'symbolB': 'METAP1'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '551284',
#   'symbolB': 'PRIM2'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '550212',
#   'symbolB': 'PRIM1'},
#  {'geneA': '632546',
#   'symbolA': 'BTF3L4',
#   'geneB': '632548',
#   'symbolB': 'TXLNA'},
#  {'geneA': '632438',
#   'symbolA': 'SOHLH1',
#   'geneB': '557132',
#   'symbolB': 'KCTD12'},
#  {'geneA': '632438',
#   'symbolA': 'SOHLH1',
#   'geneB': '571680',
#   'symbolB': 'KCTD8'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '557676',
#   'symbolB': 'ROBO1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '551990',
#   'symbolB': 'MAN1B1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '559150',
#   'symbolB': 'FBXO2'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '600078',
#   'symbolB': 'SEL1L'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '562860',
#   'symbolB': 'UFSP2'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '562850',
#   'symbolB': 'ATP13A1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '561138',
#   'symbolB': 'ACBD3'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '560468',
#   'symbolB': 'LMAN2L'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '619890',
#   'symbolB': 'SERAC1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '569814',
#   'symbolB': 'KIRREL1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '555902',
#   'symbolB': 'NGLY1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '572972',
#   'symbolB': 'PMEPA1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '560432',
#   'symbolB': 'POMGNT1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '575680',
#   'symbolB': 'ITPRIP'},
#  {'geneA': '632078', 'symbolA': 'ASIC4', 'geneB': '564660', 'symbolB': 'LSR'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '567970',
#   'symbolB': 'NFXL1'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '551354',
#   'symbolB': 'ASPHD2'},
#  {'geneA': '632078', 'symbolA': 'ASIC4', 'geneB': '556314', 'symbolB': 'ODR4'},
#  {'geneA': '632078',
#   'symbolA': 'ASIC4',
#   'geneB': '600280',
# ...
#   'symbolB': 'METTL17'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '630154', 'symbolB': 'ITFG2'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '570612', 'symbolB': 'TNIP2'},
#  {'geneA': '630134',
#   'symbolA': 'VWCE',
#   'geneB': '554230',
#   'symbolB': 'NUFIP2'},
#  {'geneA': '630134',
#   'symbolA': 'VWCE',
#   'geneB': '567778',
#   'symbolB': 'ITPRIPL2'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '555738', 'symbolB': 'LAGE3'},
#  {'geneA': '630134',
#   'symbolA': 'VWCE',
#   'geneB': '600058',
#   'symbolB': 'SQSTM1'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '551266', 'symbolB': 'TIMP3'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '548568', 'symbolB': 'CCN2'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '548032', 'symbolB': 'IDE'},
#  {'geneA': '630134', 'symbolA': 'VWCE', 'geneB': '604300', 'symbolB': 'HSPA5'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '578100',
#   'symbolB': 'AP3M1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568236',
#   'symbolB': 'DNAJC16'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559430',
#   'symbolB': 'MAPK8IP3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559424',
#   'symbolB': 'ATXN10'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '549186',
#   'symbolB': 'RELCH'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '555312',
#   'symbolB': 'TOR4A'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '630108',
#   'symbolB': 'ZDHHC7'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '628676',
#   'symbolB': 'TBC1D22B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '547902',
#   'symbolB': 'DIAPH3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '552966',
#   'symbolB': 'SMYD3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '555210',
#   'symbolB': 'VPS16'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '549142',
#   'symbolB': 'WDR13'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '579080', 'symbolB': 'SMG9'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '559416', 'symbolB': 'XPO4'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '551490',
#   'symbolB': 'LRRC1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '579548',
#   'symbolB': 'INPP5K'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '616894',
#   'symbolB': 'NCAPG'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568804',
#   'symbolB': 'TSG101'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '580340', 'symbolB': 'SMG1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568612',
#   'symbolB': 'INTS4'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '608274', 'symbolB': 'SNF8'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '560158',
#   'symbolB': 'HOOK2'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '555202',
#   'symbolB': 'VPS33A'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '553018',
#   'symbolB': 'PBXIP1'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '552866', 'symbolB': 'EXT2'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '572668', 'symbolB': 'RGP1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '569804',
#   'symbolB': 'TBC1D22A'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '554042',
#   'symbolB': 'TRPC4AP'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '571766', 'symbolB': 'CCNY'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '558102', 'symbolB': 'SMG8'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '557240',
#   'symbolB': 'SLC39A11'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '569884',
#   'symbolB': 'CAMK1D'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568386',
#   'symbolB': 'COMMD2'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '551382', 'symbolB': 'WAPL'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559392',
#   'symbolB': 'HEATR3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '594912',
#   'symbolB': 'ARMC9'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '567446', 'symbolB': 'SETX'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '572634',
#   'symbolB': 'USP34'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '570714',
#   'symbolB': 'NBEAL2'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '564400',
#   'symbolB': 'INTS3'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '553996',
#   'symbolB': 'TBC1D9B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '550548',
#   'symbolB': 'PPP4R3B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '561806',
#   'symbolB': 'AARS2'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '572616', 'symbolB': 'RIC1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '556108',
#   'symbolB': 'ERCC6L'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '551834',
#   'symbolB': 'KIF14'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '559016', 'symbolB': 'CUL7'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '554530', 'symbolB': 'RIN1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '610870',
#   'symbolB': 'IFRD2'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '630020',
#   'symbolB': 'PRKDC'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '560826',
#   'symbolB': 'GSDMD'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '560774',
#   'symbolB': 'HSPA13'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '559376',
#   'symbolB': 'PEX19'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '568120', 'symbolB': 'NF1'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '569326', 'symbolB': 'RB1'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '616772',
#   'symbolB': 'TBC1D8'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '556090', 'symbolB': 'FRYL'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '587248',
#   'symbolB': 'STK17B'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '574636',
#   'symbolB': 'HIP1R'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '568536',
#   'symbolB': 'GSDME'},
#  {'geneA': '629994',
#   'symbolA': 'EPHA1',
#   'geneB': '554480',
#   'symbolB': 'SPAG9'},
#  {'geneA': '629994', 'symbolA': 'EPHA1', 'geneB': '565984', 'symbolB': 'ENC1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '550356',
#   'symbolB': 'DCAF1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '551194',
#   'symbolB': 'MKLN1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '551794',
#   'symbolB': 'CRIM1'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '554256', 'symbolB': 'WDR6'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '565828',
#   'symbolB': 'RMND5A'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '549742',
#   'symbolB': 'UBE2O'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '617228',
#   'symbolB': 'AP1M1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '569678',
#   'symbolB': 'ZMYND19'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '570612',
#   'symbolB': 'TNIP2'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '575298',
#   'symbolB': 'LTBP4'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '561814',
#   'symbolB': 'RPTOR'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '562212', 'symbolB': 'ASPM'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '558074', 'symbolB': 'P3H2'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '564588',
#   'symbolB': 'FAM83H'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '554554', 'symbolB': 'ABL2'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '565742', 'symbolB': 'TYK2'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '557476',
#   'symbolB': 'LAMA1'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '553526',
#   'symbolB': 'TRIM27'},
#  {'geneA': '629952',
#   'symbolA': 'KRBA1',
#   'geneB': '554236',
#   'symbolB': 'TOMM40'},
#  {'geneA': '629952', 'symbolA': 'KRBA1', 'geneB': '554008', 'symbolB': 'TRIO'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '548216',
#   'symbolB': 'ARFGEF1'},
#  {'geneA': '629884', 'symbolA': 'NHLH2', 'geneB': '553244', 'symbolB': 'EXOG'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '555242',
#   'symbolB': 'CUEDC1'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '549742',
#   'symbolB': 'UBE2O'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '566282',
#   'symbolB': 'TCF12'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '586182',
#   'symbolB': 'ARL10'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '563822',
#   'symbolB': 'RAP1GDS1'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '563330',
#   'symbolB': 'CENPF'},
#  {'geneA': '629884', 'symbolA': 'NHLH2', 'geneB': '566236', 'symbolB': 'TCF3'},
#  {'geneA': '629884', 'symbolA': 'NHLH2', 'geneB': '566232', 'symbolB': 'TCF4'},
#  {'geneA': '629884',
#   'symbolA': 'NHLH2',
#   'geneB': '550098',
#   'symbolB': 'AP3B1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '564364',
#   'symbolB': 'TBL2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '568236',
#   'symbolB': 'DNAJC16'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '568208',
#   'symbolB': 'ST7'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '554442',
#   'symbolB': 'SYT11'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '587902',
#   'symbolB': 'PDCD2L'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '557250',
#   'symbolB': 'DNAJC1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '600070',
#   'symbolB': 'GRAMD1A'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '599930',
#   'symbolB': 'MIB2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '554888',
#   'symbolB': 'CSNK2A3'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '553122',
#   'symbolB': 'MACO1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '550178',
#   'symbolB': 'FRMD5'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '551378',
#   'symbolB': 'MAEA'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '557224',
#   'symbolB': 'ILDR2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '567356',
#   'symbolB': 'CCBE1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '570878',
#   'symbolB': 'CSNK2A1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '576976',
#   'symbolB': 'CSNK2B'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '550794',
#   'symbolB': 'DYNLL1'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '551300',
#   'symbolB': 'YPEL5'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '554872',
#   'symbolB': 'CSNK2A2'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '578818',
#   'symbolB': 'ERCC3'},
#  {'geneA': '629730',
#   'symbolA': 'GRAMD1B',
#   'geneB': '551410',
#   'symbolB': 'MYCBP2'},
#  {'geneA': '629704',
#   'symbolA': 'ZC3HAV1',
#   'geneB': '571066',
#   'symbolB': 'TJP1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '554698',
#   'symbolB': 'PCDHB13'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '627048',
#   'symbolB': 'PROCR'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '565584',
#   'symbolB': 'ITM2C'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558180',
#   'symbolB': 'CNNM2'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '629692',
#   'symbolB': 'ULBP3'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558158',
#   'symbolB': 'LRFN3'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '554328',
#   'symbolB': 'MXRA8'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '583204',
#   'symbolB': 'CYB5D2'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '554652',
#   'symbolB': 'ITFG1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558086',
#   'symbolB': 'DCBLD1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '563700',
#   'symbolB': 'DHRS13'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '567770',
#   'symbolB': 'OCLN'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '577462', 'symbolB': 'ATR'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '557550',
#   'symbolB': 'PTK7'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '563654',
#   'symbolB': 'HYAL2'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '575640',
#   'symbolB': 'EPHB4'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '560288',
#   'symbolB': 'ADGRE5'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '593958', 'symbolB': 'NMU'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '572952',
#   'symbolB': 'TNFSF9'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '548584',
#   'symbolB': 'TGFBR1'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '558526',
#   'symbolB': 'PTPN2'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '557432', 'symbolB': 'PVR'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '593916',
#   'symbolB': 'BMP4'},
#  {'geneA': '629646', 'symbolA': 'TNFSF8', 'geneB': '548520', 'symbolB': 'MET'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '580220',
#   'symbolB': 'HAUS5'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '582918',
#   'symbolB': 'TOR1B'},
#  {'geneA': '629646',
#   'symbolA': 'TNFSF8',
#   'geneB': '561348',
#   'symbolB': 'LGALS8'},
#  {'geneA': '629598',
#   'symbolA': 'NFE2L3',
#   'geneB': '553472',
#   'symbolB': 'HCFC2'},
#  {'geneA': '629598', 'symbolA': 'NFE2L3', 'geneB': '557872', 'symbolB': 'C4A'},
#  {'geneA': '629536',
#   'symbolA': 'ZNF467',
#   'geneB': '629532',
#   'symbolB': 'ACSF3'},
#  {'geneA': '629536',
#   'symbolA': 'ZNF467',
#   'geneB': '556852',
#   'symbolB': 'OASL'},
#  {'geneA': '629536',
#   'symbolA': 'ZNF467',
#   'geneB': '547482',
#   'symbolB': 'TARBP2'},
#  {'geneA': '629532',
#   'symbolA': 'ACSF3',
#   'geneB': '553338',
#   'symbolB': 'LONP1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '558708',
#   'symbolB': 'MAP3K4'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '557676',
#   'symbolB': 'ROBO1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '568644',
#   'symbolB': 'TNPO3'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '549328',
#   'symbolB': 'NDUFAF1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '576702',
#   'symbolB': 'USP24'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '576286',
#   'symbolB': 'VPS51'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '550782',
#   'symbolB': 'DDX20'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '560532',
#   'symbolB': 'SEC63'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '565188',
#   'symbolB': 'TFIP11'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '555224',
#   'symbolB': 'VPS18'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '548774',
#   'symbolB': 'TMEM160'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '554016',
#   'symbolB': 'EXOC1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '568212',
#   'symbolB': 'FIRRM'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '559420',
#   'symbolB': 'EIF2B3'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '557632',
#   'symbolB': 'CELSR2'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '556474',
#   'symbolB': 'RNPEP'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '587466',
#   'symbolB': 'YIPF3'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '588514',
#   'symbolB': 'TMEM70'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '549308',
#   'symbolB': 'ECSIT'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '587784',
#   'symbolB': 'SPG11'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '603074',
#   'symbolB': 'CRELD1'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '553520',
#   'symbolB': 'TRIM44'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '628286',
#   'symbolB': 'EVI5L'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '565962',
#   'symbolB': 'IGSF8'},
#  {'geneA': '629374', 'symbolA': 'FZD10', 'geneB': '553380', 'symbolB': 'P3H4'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '629478',
#   'symbolB': 'SNX19'},
#  {'geneA': '629374',
#   'symbolA': 'FZD10',
#   'geneB': '557614',
#   'symbolB': 'PIEZO1'},
#  ...]
